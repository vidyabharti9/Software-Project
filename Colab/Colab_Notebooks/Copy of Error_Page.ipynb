# %% [markdown]
# Dependent on Number of Permalinks.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

def check_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 404:
            print(f"404 Error: {url}")
        elif response.status_code == 500:
            print(f"500 Error: {url}")
        else:
            print(f"{response.status_code}: {url}")
    except requests.exceptions.RequestException as e:
        print(f"Error accessing {url}: {e}")

def get_all_links(base_url):
    try:
        response = requests.get(base_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error accessing {base_url}: {e}")
        return []

def is_valid_url(url):
    parsed = urlparse(url)
    return bool(parsed.scheme) and bool(parsed.netloc)

base_url = 'https://wikipedia.org'
links = get_all_links(base_url)

for link in links:
    if link.startswith('#'):
        # Skip fragment identifiers
        continue
    if not is_valid_url(link):
        # Convert relative URLs to absolute URLs
        link = urljoin(base_url, link)
    if link.startswith('http'):
        check_url(link)
    else:
        print(f"Skipping non-HTTP URL: {link}")
# Out:
# 200: https://en.wikipedia.org/
# 200: https://ja.wikipedia.org/
# 200: https://ru.wikipedia.org/
# 200: https://es.wikipedia.org/
# 200: https://de.wikipedia.org/
# 200: https://fr.wikipedia.org/
# 200: https://it.wikipedia.org/
# 200: https://zh.wikipedia.org/
# 200: https://pt.wikipedia.org/
# 200: https://fa.wikipedia.org/
# 200: https://ar.wikipedia.org/
# 200: https://de.wikipedia.org/
# 200: https://en.wikipedia.org/
# 200: https://es.wikipedia.org/
# 200: https://fa.wikipedia.org/
# 200: https://fr.wikipedia.org/
# 200: https://it.wikipedia.org/
# 200: https://arz.wikipedia.org/
# 200: https://nl.wikipedia.org/
# 200: https://ja.wikipedia.org/
# 200: https://pl.wikipedia.org/
# 200: https://pt.wikipedia.org/
# 200: https://ceb.wikipedia.org/
# 200: https://sv.wikipedia.org/
# 200: https://uk.wikipedia.org/
# 200: https://vi.wikipedia.org/
# 200: https://war.wikipedia.org/
# 200: https://zh.wikipedia.org/
# 200: https://ru.wikipedia.org/
# 200: https://af.wikipedia.org/
# 200: https://ast.wikipedia.org/
# 200: https://az.wikipedia.org/
# 200: https://bg.wikipedia.org/
# 200: https://zh-min-nan.wikipedia.org/
# 200: https://bn.wikipedia.org/
# 200: https://be.wikipedia.org/
# 200: https://ca.wikipedia.org/
# 200: https://cs.wikipedia.org/
# 200: https://cy.wikipedia.org/
# 200: https://da.wikipedia.org/
# 200: https://et.wikipedia.org/
# 200: https://el.wikipedia.org/
# 200: https://eo.wikipedia.org/
# 200: https://eu.wikipedia.org/
# 200: https://gl.wikipedia.org/
# 200: https://ko.wikipedia.org/
# 200: https://hy.wikipedia.org/
# 200: https://hi.wikipedia.org/
# 200: https://hr.wikipedia.org/
# 200: https://id.wikipedia.org/
# 200: https://he.wikipedia.org/
# 200: https://ka.wikipedia.org/
# 200: https://lld.wikipedia.org/
# 200: https://la.wikipedia.org/
# 200: https://lv.wikipedia.org/
# 200: https://lt.wikipedia.org/
# 200: https://hu.wikipedia.org/
# 200: https://mk.wikipedia.org/
# 200: https://ms.wikipedia.org/
# 200: https://min.wikipedia.org/
# 200: https://my.wikipedia.org/
# 200: https://no.wikipedia.org/
# 200: https://nn.wikipedia.org/
# 200: https://ce.wikipedia.org/
# 200: https://uz.wikipedia.org/
# 200: https://kk.wikipedia.org/
# 200: https://ro.wikipedia.org/
# 200: https://simple.wikipedia.org/
# 200: https://sk.wikipedia.org/
# 200: https://sl.wikipedia.org/
# 200: https://sr.wikipedia.org/
# 200: https://sh.wikipedia.org/
# 200: https://fi.wikipedia.org/
# 200: https://ta.wikipedia.org/
# 200: https://tt.wikipedia.org/
# 200: https://th.wikipedia.org/
# 200: https://tg.wikipedia.org/
# 200: https://azb.wikipedia.org/
# 200: https://tr.wikipedia.org/
# 200: https://ur.wikipedia.org/
# 200: https://zh-yue.wikipedia.org/
# 200: https://ace.wikipedia.org/
# 200: https://als.wikipedia.org/
# 200: https://am.wikipedia.org/
# 200: https://an.wikipedia.org/
# 200: https://hyw.wikipedia.org/
# 200: https://gor.wikipedia.org/
# 200: https://ban.wikipedia.org/
# 200: https://bjn.wikipedia.org/
# 200: https://map-bms.wikipedia.org/
# 200: https://ba.wikipedia.org/
# 200: https://be-tarask.wikipedia.org/
# 200: https://bcl.wikipedia.org/
# 200: https://bpy.wikipedia.org/
# 200: https://bar.wikipedia.org/
# 200: https://bs.wikipedia.org/
# 200: https://br.wikipedia.org/
# 200: https://cv.wikipedia.org/
# 200: https://dag.wikipedia.org/
# 200: https://ary.wikipedia.org/
# 200: https://nv.wikipedia.org/
# 200: https://eml.wikipedia.org/
# 200: https://hif.wikipedia.org/
# 200: https://fo.wikipedia.org/
# 200: https://fy.wikipedia.org/
# 200: https://ga.wikipedia.org/
# 200: https://gd.wikipedia.org/
# 200: https://glk.wikipedia.org/
# 200: https://gu.wikipedia.org/
# 200: https://hak.wikipedia.org/
# 200: https://ha.wikipedia.org/
# 200: https://hsb.wikipedia.org/
# 200: https://io.wikipedia.org/
# 200: https://ig.wikipedia.org/
# 200: https://ilo.wikipedia.org/
# 200: https://ia.wikipedia.org/
# 200: https://ie.wikipedia.org/
# 200: https://os.wikipedia.org/
# 200: https://is.wikipedia.org/
# 200: https://jv.wikipedia.org/
# 200: https://kn.wikipedia.org/
# 200: https://km.wikipedia.org/
# 200: https://avk.wikipedia.org/
# 200: https://ht.wikipedia.org/
# 200: https://ku.wikipedia.org/
# 200: https://ckb.wikipedia.org/
# 200: https://ky.wikipedia.org/
# 200: https://mrj.wikipedia.org/
# 200: https://lb.wikipedia.org/
# 200: https://lij.wikipedia.org/
# 200: https://li.wikipedia.org/
# 200: https://lmo.wikipedia.org/
# 200: https://mai.wikipedia.org/
# 200: https://mg.wikipedia.org/
# 200: https://ml.wikipedia.org/
# 200: https://mr.wikipedia.org/
# 200: https://xmf.wikipedia.org/
# 200: https://mzn.wikipedia.org/
# 200: https://cdo.wikipedia.org/
# 200: https://mn.wikipedia.org/
# 200: https://nap.wikipedia.org/
# 200: https://new.wikipedia.org/
# 200: https://ne.wikipedia.org/
# 200: https://frr.wikipedia.org/
# 200: https://oc.wikipedia.org/
# 200: https://mhr.wikipedia.org/
# 200: https://or.wikipedia.org/
# 200: https://as.wikipedia.org/
# 200: https://pa.wikipedia.org/
# 200: https://pnb.wikipedia.org/
# 200: https://ps.wikipedia.org/
# 200: https://pms.wikipedia.org/
# 200: https://nds.wikipedia.org/
# 200: https://crh.wikipedia.org/
# 200: https://qu.wikipedia.org/
# 200: https://sa.wikipedia.org/
# 200: https://sat.wikipedia.org/
# 200: https://sah.wikipedia.org/
# 200: https://sco.wikipedia.org/
# 200: https://sn.wikipedia.org/
# 200: https://sq.wikipedia.org/
# 200: https://scn.wikipedia.org/
# 200: https://si.wikipedia.org/
# 200: https://sd.wikipedia.org/
# 200: https://szl.wikipedia.org/
# 200: https://su.wikipedia.org/
# 200: https://sw.wikipedia.org/
# 200: https://tl.wikipedia.org/
# 200: https://shn.wikipedia.org/
# 200: https://te.wikipedia.org/
# 200: https://tum.wikipedia.org/
# 200: https://bug.wikipedia.org/
# 200: https://vec.wikipedia.org/
# 200: https://vo.wikipedia.org/
# 200: https://wa.wikipedia.org/
# 200: https://zh-classical.wikipedia.org/
# 200: https://wuu.wikipedia.org/
# 200: https://yi.wikipedia.org/
# 200: https://yo.wikipedia.org/
# 200: https://diq.wikipedia.org/
# 200: https://bat-smg.wikipedia.org/
# 200: https://zu.wikipedia.org/
# 200: https://mni.wikipedia.org/
# 200: https://lad.wikipedia.org/
# 200: https://kbd.wikipedia.org/
# 200: https://ang.wikipedia.org/
# 200: https://smn.wikipedia.org/
# 200: https://anp.wikipedia.org/
# 200: https://ab.wikipedia.org/
# 200: https://roa-rup.wikipedia.org/
# 200: https://frp.wikipedia.org/
# 200: https://atj.wikipedia.org/
# 200: https://arc.wikipedia.org/
# 200: https://gn.wikipedia.org/
# 200: https://av.wikipedia.org/
# 200: https://ay.wikipedia.org/
# 200: https://bew.wikipedia.org/
# 200: https://bh.wikipedia.org/
# 200: https://bi.wikipedia.org/
# 200: https://bo.wikipedia.org/
# 200: https://bxr.wikipedia.org/
# 200: https://cbk-zam.wikipedia.org/
# 200: https://ny.wikipedia.org/
# 200: https://co.wikipedia.org/
# 200: https://za.wikipedia.org/
# 200: https://dga.wikipedia.org/
# 200: https://se.wikipedia.org/
# 200: https://pdc.wikipedia.org/
# 200: https://dv.wikipedia.org/
# 200: https://dsb.wikipedia.org/
# 200: https://myv.wikipedia.org/
# 200: https://ext.wikipedia.org/
# 200: https://fon.wikipedia.org/
# 200: https://ff.wikipedia.org/
# 200: https://fur.wikipedia.org/
# 200: https://gv.wikipedia.org/
# 200: https://gag.wikipedia.org/
# 200: https://inh.wikipedia.org/
# 200: https://gpe.wikipedia.org/
# 200: https://ki.wikipedia.org/
# 200: https://gan.wikipedia.org/
# 200: https://guw.wikipedia.org/
# 200: https://xal.wikipedia.org/
# 200: https://haw.wikipedia.org/
# 200: https://rw.wikipedia.org/
# 200: https://kbp.wikipedia.org/
# 200: https://pam.wikipedia.org/
# 200: https://csb.wikipedia.org/
# 200: https://kw.wikipedia.org/
# 200: https://kv.wikipedia.org/
# 200: https://koi.wikipedia.org/
# 200: https://kg.wikipedia.org/
# 200: https://gom.wikipedia.org/
# 200: https://ks.wikipedia.org/
# 200: https://gcr.wikipedia.org/
# 200: https://lo.wikipedia.org/
# 200: https://lbe.wikipedia.org/
# 200: https://ltg.wikipedia.org/
# 200: https://lez.wikipedia.org/
# 200: https://nia.wikipedia.org/
# 200: https://ln.wikipedia.org/
# 200: https://lfn.wikipedia.org/
# 200: https://olo.wikipedia.org/
# 200: https://jbo.wikipedia.org/
# 200: https://lg.wikipedia.org/
# 200: https://mad.wikipedia.org/
# 200: https://mt.wikipedia.org/
# 200: https://btm.wikipedia.org/
# 200: https://mi.wikipedia.org/
# 200: https://tw.wikipedia.org/
# 200: https://mwl.wikipedia.org/
# 200: https://mdf.wikipedia.org/
# 200: https://mnw.wikipedia.org/
# 200: https://nqo.wikipedia.org/
# 200: https://fj.wikipedia.org/
# 200: https://nah.wikipedia.org/
# 200: https://pcm.wikipedia.org/
# 200: https://nds-nl.wikipedia.org/
# 200: https://nrm.wikipedia.org/
# 200: https://nov.wikipedia.org/
# 200: https://om.wikipedia.org/
# 200: https://blk.wikipedia.org/
# 200: https://pi.wikipedia.org/
# 200: https://pag.wikipedia.org/
# 200: https://ami.wikipedia.org/
# 200: https://pap.wikipedia.org/
# 200: https://jam.wikipedia.org/
# 200: https://pfl.wikipedia.org/
# 200: https://pcd.wikipedia.org/
# 200: https://krc.wikipedia.org/
# 200: https://kaa.wikipedia.org/
# 200: https://ksh.wikipedia.org/
# 200: https://rm.wikipedia.org/
# 200: https://rue.wikipedia.org/
# 200: https://szy.wikipedia.org/
# 200: https://sm.wikipedia.org/
# 200: https://skr.wikipedia.org/
# 200: https://sc.wikipedia.org/
# 200: https://trv.wikipedia.org/
# 200: https://stq.wikipedia.org/
# 200: https://st.wikipedia.org/
# 200: https://nso.wikipedia.org/
# 200: https://tn.wikipedia.org/
# 200: https://cu.wikipedia.org/
# 200: https://so.wikipedia.org/
# 200: https://srn.wikipedia.org/
# 200: https://shi.wikipedia.org/
# 200: https://ty.wikipedia.org/
# 200: https://zgh.wikipedia.org/
# 200: https://kab.wikipedia.org/
# 200: https://roa-tara.wikipedia.org/
# 200: https://tay.wikipedia.org/
# 200: https://tet.wikipedia.org/
# 200: https://tpi.wikipedia.org/
# 200: https://tly.wikipedia.org/
# 200: https://to.wikipedia.org/
# 200: https://chr.wikipedia.org/
# 200: https://tk.wikipedia.org/
# 200: https://kcg.wikipedia.org/
# 200: https://tyv.wikipedia.org/
# 200: https://udm.wikipedia.org/
# 200: https://ug.wikipedia.org/
# 200: https://vep.wikipedia.org/
# 200: https://fiu-vro.wikipedia.org/
# 200: https://vls.wikipedia.org/
# 200: https://wo.wikipedia.org/
# 200: https://xh.wikipedia.org/
# 200: https://zea.wikipedia.org/
# 200: https://alt.wikipedia.org/
# 200: https://awa.wikipedia.org/
# 200: https://dty.wikipedia.org/
# 200: https://tcy.wikipedia.org/
# 200: https://bm.wikipedia.org/
# 200: https://bbc.wikipedia.org/
# 200: https://ch.wikipedia.org/
# 200: https://dtp.wikipedia.org/
# 200: https://dz.wikipedia.org/
# 200: https://ee.wikipedia.org/
# 200: https://gur.wikipedia.org/
# 200: https://got.wikipedia.org/
# 200: https://igl.wikipedia.org/
# 200: https://iu.wikipedia.org/
# 200: https://ik.wikipedia.org/
# 200: https://kl.wikipedia.org/
# 200: https://kus.wikipedia.org/
# 200: https://fat.wikipedia.org/
# 200: https://pih.wikipedia.org/
# 200: https://pwn.wikipedia.org/
# 200: https://pnt.wikipedia.org/
# 200: https://rmy.wikipedia.org/
# 200: https://rn.wikipedia.org/
# 200: https://sg.wikipedia.org/
# 200: https://ss.wikipedia.org/
# 200: https://ti.wikipedia.org/
# 200: https://din.wikipedia.org/
# 200: https://chy.wikipedia.org/
# 200: https://ts.wikipedia.org/
# 200: https://ve.wikipedia.org/
# 200: https://guc.wikipedia.org/
# 200: https://ady.wikipedia.org/
# 200: https://meta.wikimedia.org/wiki/Special:MyLanguage/List_of_Wikipedias
# 200: https://donate.wikimedia.org/?wmf_medium=portal&wmf_campaign=portalFooter&wmf_source=portalFooter
# 200: https://en.wikipedia.org/wiki/List_of_Wikipedia_mobile_applications
# 200: https://play.google.com/store/apps/details?id=org.wikipedia&referrer=utm_source%3Dportal%26utm_medium%3Dbutton%26anid%3Dadmob
# 200: https://itunes.apple.com/app/apple-store/id324715238?pt=208305&ct=portal&mt=8
# 200: https://commons.wikimedia.org/
# 200: https://www.wikivoyage.org/
# 200: https://www.wiktionary.org/
# 200: https://www.wikibooks.org/
# 200: https://www.wikinews.org/
# 200: https://www.wikidata.org/
# 200: https://www.wikiversity.org/
# 200: https://www.wikiquote.org/
# 200: https://www.mediawiki.org/
# 200: https://www.wikisource.org/
# 200: https://species.wikimedia.org/
# 200: https://www.wikifunctions.org/
# 200: https://meta.wikimedia.org/
# 200: https://creativecommons.org/licenses/by-sa/4.0/
# 200: https://meta.wikimedia.org/wiki/Terms_of_use
# 200: https://meta.wikimedia.org/wiki/Privacy_policy

# %%
import nest_asyncio
import aiohttp
import asyncio
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

nest_asyncio.apply()

async def fetch(session, url):
    try:
        async with session.get(url) as response:
            status = response.status
            if status == 404:
                print(f"404 Error: {url}")
            elif status == 500:
                print(f"500 Error: {url}")
            else:
                print(f"{status}: {url}")
    except Exception as e:
        print(f"Error accessing {url}: {e}")

async def main(base_url):
    async with aiohttp.ClientSession() as session:
        response = await session.get(base_url)
        soup = BeautifulSoup(await response.text(), 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True)]
        tasks = []
        for link in links:
            if link.startswith('#'):
                continue
            if not urlparse(link).scheme:
                link = urljoin(base_url, link)
            if link.startswith('http'):
                tasks.append(fetch(session, link))
            else:
                print(f"Skipping non-HTTP URL: {link}")
        await asyncio.gather(*tasks)

base_url = 'https://bekushal.com'
asyncio.run(main(base_url))
# Out:
# 200: https://bootstrapmade.com/
# 200: https://www.youtube.com/c/bekushal
# 200: https://www.bekushal.com
# 200: https://www.bekushal.com/mbmentor
# 200: https://www.bekushal.com/shweta
# 200: https://www.bekushal.com/kushal
# 200: https://sitare.org/univ
# 404 Error: https://bekushal.com/index.html
# 200: https://chat.whatsapp.com/EnUniRPl4iQA6skAmKBhlT
# 200: https://chat.whatsapp.com/EnUniRPl4iQA6skAmKBhlT
# 200: https://www.bekushal.com/pyp
# 200: https://github.com/atmabodha/Vedanta_Datasets
# 200: https://simplescribblings.blogspot.com/
