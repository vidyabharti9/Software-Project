# %%
! pip install cssutils
# Out:
# Collecting cssutils
#   Downloading cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cssutils) (10.5.0)
# Downloading cssutils-2.11.1-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: cssutils
# Successfully installed cssutils-2.11.1

# %%
import requests
from bs4 import BeautifulSoup
import cssutils

def extract_typography_properties(element, css_rules):
    style = element.get('style', '')
    properties = {
        'font-family': None,
        'font-size': None,
        'font-style': None,
        'font-weight': None
    }

    # Extract inline styles
    for prop in properties.keys():
        if prop in style:
            start = style.find(prop) + len(prop) + 1
            end = style.find(';', start)
            properties[prop] = style[start:end].strip()

    # Extract styles from CSS rules
    for rule in css_rules:
        if element.name in rule.selectorText:
            for prop in properties.keys():
                if properties[prop] is None and rule.style.getPropertyValue(prop):
                    properties[prop] = rule.style.getPropertyValue(prop)

    return properties

def get_css_rules(url):
    response = requests.get(url)
    css = response.text
    sheet = cssutils.parseString(css)
    return sheet.cssRules

def scrape_elements(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Get CSS rules from external stylesheets
    css_rules = []
    for link in soup.find_all('link', rel='stylesheet'):
        css_url = link['href']
        if not css_url.startswith('http'):
            css_url = url + css_url
        css_rules.extend(get_css_rules(css_url))

    elements = {
        'headers': soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6']),
        'paragraphs': soup.find_all('p'),
        'images': soup.find_all('img'),
        'containers': soup.find_all(['div', 'section', 'article']),
        'lists': soup.find_all(['ul', 'ol', 'li']),
        'navigation': soup.find_all(['nav', 'ul', 'li'])
    }

    typography = {}
    for key, elems in elements.items():
        typography[key] = [extract_typography_properties(elem, css_rules) for elem in elems]

    return elements, typography

url = 'https://bekushal.com'
elements, typography = scrape_elements(url)
print(typography)
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING	Property: Unknown Property name. [5:159965: --bs-aspect-ratio]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:159965: --bs-aspect-ratio]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160136: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160136: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160160: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160160: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160210: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160210: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160234: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160234: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160312: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160312: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160336: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160336: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160389: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160389: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160413: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160413: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160492: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160492: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160516: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160516: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160569: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160569: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160593: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160593: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160672: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160672: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160696: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160696: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160749: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160749: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160773: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160773: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160853: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160853: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160877: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160877: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160930: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160930: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160954: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160954: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161035: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161035: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:161059: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:161059: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161113: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161113: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:161137: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:161137: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:161184: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:161184: display]
# WARNING	Property: Unknown Property name. [5:161197: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161197: flex-direction]
# WARNING	Property: Unknown Property name. [5:161216: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161216: align-items]
# WARNING	Property: Unknown Property name. [5:161235: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161235: align-self]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:161262: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:161262: display]
# WARNING	Property: Unknown Property name. [5:161275: flex]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161275: flex]
# WARNING	Property: Unknown Property name. [5:161289: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161289: flex-direction]
# WARNING	Property: Unknown Property name. [5:161311: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161311: align-self]
# WARNING	Property: Unknown Property name. [5:161843: text-overflow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161843: text-overflow]
# WARNING	Property: Unknown Property name. [5:161910: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161910: align-self]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--bs-border-width) [5:161929: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--bs-border-width) [5:161929: width]
# WARNING	Property: Unknown Property name. [5:162423: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162423: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162455: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162455: object-fit]
# WARNING	Property: Unknown Property name. [5:162502: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162502: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162532: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162532: object-fit]
# WARNING	Property: Unknown Property name. [5:162576: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162576: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162605: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162605: object-fit]
# WARNING	Property: Unknown Property name. [5:162649: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162649: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162684: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162684: object-fit]
# WARNING	Property: Unknown Property name. [5:162733: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162733: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162762: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162762: object-fit]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: grid [5:163618: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: grid [5:163618: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: inline-grid [5:163656: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: inline-grid [5:163656: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:163811: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:163811: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: inline-flex [5:163849: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: inline-flex [5:163849: display]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow) [5:163918: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow) [5:163918: box-shadow]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-sm) [5:163971: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-sm) [5:163971: box-shadow]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-lg) [5:164027: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-lg) [5:164027: box-shadow]
# WARNING	Property: Unknown Property name. [5:164131: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164131: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164158)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164158)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164178)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164178)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164233: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164233: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164260)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164260)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164282)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164282)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164335: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164335: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164362)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164362)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164382)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164382)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164432: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164432: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164459)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164459)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164476)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164476)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164529: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164529: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164556)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164556)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164576)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164576)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164628: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164628: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164655)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164655)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164674)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164674)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164725: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164725: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164752)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164752)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164770)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164770)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164820: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164820: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164847)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164847)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164864)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164864)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:165092: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:165092: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:165126: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:165126: position]
# WARNING	Property: Unknown Property name. [5:165511: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165511: transform]
# WARNING	Property: Unknown Property name. [5:165572: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165572: transform]
# WARNING	Property: Unknown Property name. [5:165629: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165629: transform]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165674: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165674: border]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165801: border-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165801: border-top]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165940: border-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165940: border-right]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166086: border-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166086: border-bottom]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166236: border-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166236: border-left]
# WARNING	Property: Unknown Property name. [5:166383: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166383: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166423)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166423)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166443)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166443)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-primary-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-primary-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166499: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166499: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166539)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166539)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166561)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166561)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166615: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166615: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166655)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166655)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166675)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166675)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-success-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-success-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166726: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166726: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166766)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166766)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166783)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166783)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-info-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-info-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166837: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166837: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166877)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166877)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166897)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166897)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-warning-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-warning-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166950: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166950: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166990)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166990)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167009)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167009)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-danger-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-danger-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167061: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167061: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167101)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167101)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167119)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167119)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-light-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-light-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167170: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167170: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167210)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167210)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167227)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167227)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-dark-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-dark-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167279: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167279: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167319)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167319)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167337)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167337)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-black-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-black-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-black-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-black-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167389: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167389: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167429)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167429)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167447)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167447)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-white-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-white-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-white-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-white-rgb),var(--bs-border-opacity))!important
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-primary-border-subtle) [5:167508: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-primary-border-subtle) [5:167508: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-secondary-border-subtle) [5:167588: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-secondary-border-subtle) [5:167588: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-success-border-subtle) [5:167668: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-success-border-subtle) [5:167668: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-info-border-subtle) [5:167743: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-info-border-subtle) [5:167743: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-warning-border-subtle) [5:167818: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-warning-border-subtle) [5:167818: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-danger-border-subtle) [5:167895: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-danger-border-subtle) [5:167895: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-light-border-subtle) [5:167970: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-light-border-subtle) [5:167970: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-dark-border-subtle) [5:168043: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-dark-border-subtle) [5:168043: border-color]
# WARNING	Property: Unknown Property name. [5:168299: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168299: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168342: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168342: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168386: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168386: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168429: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168429: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168474: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168474: --bs-border-opacity]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168672: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168672: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168706: min-width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168706: min-width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168914: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168914: height]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168949: min-height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168949: min-height]
# WARNING	Property: Unknown Property name. [5:168987: flex]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168987: flex]
# WARNING	Property: Unknown Property name. [5:169021: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169021: flex-direction]
# WARNING	Property: Unknown Property name. [5:169063: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169063: flex-direction]
# WARNING	Property: Unknown Property name. [5:169113: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169113: flex-direction]
# WARNING	Property: Unknown Property name. [5:169171: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169171: flex-direction]
# WARNING	Property: Unknown Property name. [5:169224: flex-grow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169224: flex-grow]
# WARNING	Property: Unknown Property name. [5:169259: flex-grow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169259: flex-grow]
# WARNING	Property: Unknown Property name. [5:169296: flex-shrink]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169296: flex-shrink]
# WARNING	Property: Unknown Property name. [5:169335: flex-shrink]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169335: flex-shrink]
# WARNING	Property: Unknown Property name. [5:169370: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169370: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169408: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169408: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169454: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169454: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169510: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169510: justify-content]
# WARNING	Property: Unknown Property name. [5:169568: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169568: justify-content]
# WARNING	Property: Unknown Property name. [5:169627: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169627: justify-content]
# WARNING	Property: Unknown Property name. [5:169685: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169685: justify-content]
# WARNING	Property: Unknown Property name. [5:169749: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169749: justify-content]
# WARNING	Property: Unknown Property name. [5:169812: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169812: justify-content]
# WARNING	Property: Unknown Property name. [5:169870: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169870: align-items]
# WARNING	Property: Unknown Property name. [5:169920: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169920: align-items]
# WARNING	Property: Unknown Property name. [5:169971: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169971: align-items]
# WARNING	Property: Unknown Property name. [5:170022: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170022: align-items]
# WARNING	Property: Unknown Property name. [5:170074: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170074: align-items]
# WARNING	Property: Unknown Property name. [5:170125: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170125: align-content]
# WARNING	Property: Unknown Property name. [5:170179: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170179: align-content]
# WARNING	Property: Unknown Property name. [5:170234: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170234: align-content]
# WARNING	Property: Unknown Property name. [5:170288: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170288: align-content]
# WARNING	Property: Unknown Property name. [5:170348: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170348: align-content]
# WARNING	Property: Unknown Property name. [5:170408: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170408: align-content]
# WARNING	Property: Unknown Property name. [5:170457: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170457: align-self]
# WARNING	Property: Unknown Property name. [5:170501: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170501: align-self]
# WARNING	Property: Unknown Property name. [5:170549: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170549: align-self]
# WARNING	Property: Unknown Property name. [5:170598: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170598: align-self]
# WARNING	Property: Unknown Property name. [5:170647: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170647: align-self]
# WARNING	Property: Unknown Property name. [5:170697: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170697: align-self]
# WARNING	Property: Unknown Property name. [5:170739: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170739: order]
# WARNING	Property: Unknown Property name. [5:170767: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170767: order]
# WARNING	Property: Unknown Property name. [5:170794: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170794: order]
# WARNING	Property: Unknown Property name. [5:170821: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170821: order]
# WARNING	Property: Unknown Property name. [5:170848: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170848: order]
# WARNING	Property: Unknown Property name. [5:170875: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170875: order]
# WARNING	Property: Unknown Property name. [5:170902: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170902: order]
# WARNING	Property: Unknown Property name. [5:170932: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170932: order]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:170979: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:170979: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171008: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171008: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171036: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171036: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171063: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171063: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171092: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171092: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171205: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171205: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171235: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171235: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171270: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171270: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171299: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171299: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171333: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171333: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171361: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171361: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171394: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171394: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171424: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171424: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171459: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171459: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171487: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171487: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171639: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171639: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171667: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171667: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171704: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171704: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171731: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171731: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171767: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171767: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171793: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171793: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171828: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171828: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171856: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171856: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171893: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171893: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171919: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171919: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:172047: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:172047: margin-top]
# ...
# WARNING	Property: Unknown Property name. [1558:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1558:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1562:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1562:3: background]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 3px solid var(--color-primary) [1568:3: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 3px solid var(--color-primary) [1568:3: border]
# WARNING	Property: Unknown Property name. [1573:5: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1573:5: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1617:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1617:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1628:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1628:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1632:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1632:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1683:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1683:3: color]
# WARNING	Property: Unknown Property name. [1684:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1684:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1688:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1688:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1712:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1712:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1739:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1739:3: display]
# WARNING	Property: Unknown Property name. [1740:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1740:3: justify-content]
# WARNING	Property: Unknown Property name. [1741:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1741:3: align-items]
# WARNING	Property: Unknown Property name. [1743:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1743:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1762:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1762:3: color]
# WARNING	Property: Unknown Property name. [1816:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [1816:3: animation]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--color-primary) [1835:3: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--color-primary) [1835:3: border-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1843:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1843:3: background]
# WARNING	Property: Unknown Property name. [1847:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1847:3: transition]
# WARNING	CSSStylesheet: Unknown @rule found. [1855:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [1855:1: @keyframes]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1871:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1871:3: background]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1895:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1895:3: font-family]
# WARNING	Property: Unknown Property name. [1902:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1902:3: transition]
# WARNING	Property: Unknown Property name. [1915:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1915:3: transition]
# WARNING	Property: Unknown Property name. [1924:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1924:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1955:5: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1955:5: height]
# WARNING	Property: Unknown Property name. [1966:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1966:3: transition]
# WARNING	Property: Unknown Property name. [1982:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1982:3: transition]
# WARNING	Property: Unknown Property name. [1989:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1989:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2013:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2013:3: display]
# WARNING	Property: Unknown Property name. [2021:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2021:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2026:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2026:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2028:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2028:3: display]
# WARNING	Property: Unknown Property name. [2029:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2029:3: align-items]
# WARNING	Property: Unknown Property name. [2030:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2030:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2035:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2035:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [2041:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [2041:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2075:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2075:3: color]
# WARNING	Property: Unknown Property name. [2076:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2076:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2080:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2080:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2120:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2120:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2143:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2143:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2158:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2158:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2169:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2169:3: display]
# WARNING	Property: Unknown Property name. [2170:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [2170:3: flex-wrap]
# WARNING	Property: Unknown Property name. [2172:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2172:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2185:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2185:3: color]
# WARNING	Property: Unknown Property name. [2207:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2207:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2211:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2211:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2238:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2238:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2267:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2267:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2299:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2299:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2318:3: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2318:3: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2335:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2335:3: background]
# WARNING	Property: Unknown Property name. [2337:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2337:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2360:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2360:3: color]
# WARNING	Property: Unknown Property name. [2361:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2361:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2365:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2365:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2390:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2390:3: color]
# WARNING	Property: Unknown Property name. [2391:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2391:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2395:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2395:3: color]
# WARNING	Property: Unknown Property name. [2426:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2426:3: transition]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 1px solid var(--color-primary) [2432:3: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 1px solid var(--color-primary) [2432:3: border]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2433:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2433:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2473:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2473:3: color]
# WARNING	Property: Unknown Property name. [2474:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2474:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2478:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2478:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2483:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2483:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2547:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2547:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2559:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2559:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2579:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2579:3: font-family]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2584:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2584:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2588:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2588:3: display]
# WARNING	Property: Unknown Property name. [2589:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2589:3: align-items]
# WARNING	Property: Unknown Property name. [2590:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2590:3: justify-content]
# WARNING	Property: Unknown Property name. [2598:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2598:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2632:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2632:3: display]
# WARNING	Property: Unknown Property name. [2633:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2633:3: align-items]
# WARNING	Property: Unknown Property name. [2642:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2642:3: transition]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-961b6213c2d3> in <cell line: 64>()
#      62
#      63 url = 'https://bekushal.com'
# ---> 64 elements, typography = scrape_elements(url)
#      65 print(typography)
#
# <ipython-input-3-961b6213c2d3> in scrape_elements(url)
#      57     typography = {}
#      58     for key, elems in elements.items():
# ---> 59         typography[key] = [extract_typography_properties(elem, css_rules) for elem in elems]
#      60
#      61     return elements, typography
#
# <ipython-input-3-961b6213c2d3> in <listcomp>(.0)
#      57     typography = {}
#      58     for key, elems in elements.items():
# ---> 59         typography[key] = [extract_typography_properties(elem, css_rules) for elem in elems]
#      60
#      61     return elements, typography
#
# <ipython-input-3-961b6213c2d3> in extract_typography_properties(element, css_rules)
#      21     # Extract styles from CSS rules
#      22     for rule in css_rules:
# ---> 23         if element.name in rule.selectorText:
#      24             for prop in properties.keys():
#      25                 if properties[prop] is None and rule.style.getPropertyValue(prop):
#
# AttributeError: 'CSSFontFaceRule' object has no attribute 'selectorText'

# %%
import urllib.parse
from typing import Optional

import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> tuple[list[str], list[str], list[dict]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: list[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: list[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: list[dict] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

# %%
url = 'https://bekushal.com'

# Call the function
css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url, verbose=True)

# Print the results
print("External Stylesheets:")
for css in css_from_external_stylesheets:
    print(css)  # Print the first 500 characters for brevity

print("\nStyle Tags:")
for css in css_from_style_tags:
    print(css)  # Print the first 500 characters for brevity

print("\nInline CSS:")
for css in inline_css:
    print(f"Tag: {css['tag']}")
    print(f"CSS: {css['css']}\n")
# Out:
# downloading external CSS stylesheet https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,500;0,600;0,700;1,300;1,400;1,600;1,700&family=Montserrat:ital,wght@0,300;0,400;0,500;0,600;0,700;1,300;1,400;1,500;1,600;1,700&family=Raleway:ital,wght@0,300;0,400;0,500;0,600;0,700;1,300;1,400;1,500;1,600;1,700&display=swap
# downloading external CSS stylesheet https://bekushal.com/data/assets/vendor/bootstrap/css/bootstrap.min.css
# downloading external CSS stylesheet https://bekushal.com/data/assets/vendor/bootstrap-icons/bootstrap-icons.css
# downloading external CSS stylesheet https://bekushal.com/data/assets/vendor/aos/aos.css
# downloading external CSS stylesheet https://bekushal.com/data/assets/vendor/glightbox/css/glightbox.min.css
# downloading external CSS stylesheet https://bekushal.com/data/assets/vendor/swiper/swiper-bundle.min.css
# downloading external CSS stylesheet https://bekushal.com/data/assets/css/main.css
# Extracted the following CSS from [https://bekushal.com]:
#     1. 7 external stylesheets (total 449,274 characters of text)
#     2. 0 style tags (total 0 characters of text)
#     3. 0 tags with inline CSS (total 0 characters of text)
#
#
# External Stylesheets:
# @font-face {
#   font-family: 'Montserrat';
#   font-style: italic;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUFjIg1_i6t8kCHKm459Wx7xQYXK0vOoz6jq_p9aX8.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: italic;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUFjIg1_i6t8kCHKm459Wx7xQYXK0vOoz6jq6R9aX8.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: italic;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUFjIg1_i6t8kCHKm459Wx7xQYXK0vOoz6jq5Z9aX8.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: italic;
#   font-weight: 600;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUFjIg1_i6t8kCHKm459Wx7xQYXK0vOoz6jq3p6aX8.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: italic;
#   font-weight: 700;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUFjIg1_i6t8kCHKm459Wx7xQYXK0vOoz6jq0N6aX8.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUHjIg1_i6t8kCHKm4532VJOt5-QNFgpCs16Ew-.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUHjIg1_i6t8kCHKm4532VJOt5-QNFgpCtr6Ew-.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUHjIg1_i6t8kCHKm4532VJOt5-QNFgpCtZ6Ew-.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: normal;
#   font-weight: 600;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUHjIg1_i6t8kCHKm4532VJOt5-QNFgpCu170w-.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Montserrat';
#   font-style: normal;
#   font-weight: 700;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/montserrat/v26/JTUHjIg1_i6t8kCHKm4532VJOt5-QNFgpCuM70w-.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: italic;
#   font-weight: 300;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memQYaGs126MiZpBA-UFUIcVXSCEkx2cmqvXlWq8tWZ0Pw86hd0Rk5hkaVc.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: italic;
#   font-weight: 400;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memQYaGs126MiZpBA-UFUIcVXSCEkx2cmqvXlWq8tWZ0Pw86hd0Rk8ZkaVc.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: italic;
#   font-weight: 600;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memQYaGs126MiZpBA-UFUIcVXSCEkx2cmqvXlWq8tWZ0Pw86hd0RkxhjaVc.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: italic;
#   font-weight: 700;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memQYaGs126MiZpBA-UFUIcVXSCEkx2cmqvXlWq8tWZ0Pw86hd0RkyFjaVc.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 300;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsiH0C4n.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsjZ0C4n.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 500;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsjr0C4n.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 600;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsgH1y4n.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 700;
#   font-stretch: normal;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/opensans/v40/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsg-1y4n.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: italic;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Pt_g8zYS_SKggPNyCgSQamb1W0lwk4S4TbMPrQ.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: italic;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Pt_g8zYS_SKggPNyCgSQamb1W0lwk4S4WjMPrQ.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: italic;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Pt_g8zYS_SKggPNyCgSQamb1W0lwk4S4VrMPrQ.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: italic;
#   font-weight: 600;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Pt_g8zYS_SKggPNyCgSQamb1W0lwk4S4bbLPrQ.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: italic;
#   font-weight: 700;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Pt_g8zYS_SKggPNyCgSQamb1W0lwk4S4Y_LPrQ.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Ptxg8zYS_SKggPN4iEgvnHyvveLxVuEooCP.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Ptxg8zYS_SKggPN4iEgvnHyvveLxVvaooCP.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Ptxg8zYS_SKggPN4iEgvnHyvveLxVvoooCP.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: normal;
#   font-weight: 600;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Ptxg8zYS_SKggPN4iEgvnHyvveLxVsEpYCP.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Raleway';
#   font-style: normal;
#   font-weight: 700;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/raleway/v34/1Ptxg8zYS_SKggPN4iEgvnHyvveLxVs9pYCP.ttf) format('truetype');
# }
#
# @charset "UTF-8";/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,"Segoe UI",Roboto,"Helvetica Neue","Noto Sans","Liberation Sans",Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji";--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:255,255,255;--bs-secondary-color:rgba(222, 226, 230, 0.75);--bs-secondary-color-rgb:222,226,230;--bs- ...
# /*# sourceMappingURL=bootstrap.min.css.map */
# /*!
#  * Bootstrap Icons v1.11.3 (https://icons.getbootstrap.com/)
#  * Copyright 2019-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/icons/blob/main/LICENSE)
#  */
#
# @font-face {
#   font-display: block;
#   font-family: "bootstrap-icons";
#   src: url("./fonts/bootstrap-icons.woff2?dd67030699838ea613ee6dbda90effa6") format("woff2"),
# url("./fonts/bootstrap-icons.woff?dd67030699838ea613ee6dbda90effa6") format("woff");
# }
#
# .bi::before,
# [class^="bi-"]::before,
# [class*=" bi-"]::before {
#   display: inline-block;
#   font-family: bootstrap-icons !important;
#   font-style: normal;
#   font-weight: normal !important;
#   font-variant: normal;
#   text-transform: none;
#   line-height: 1;
#   vertical-align: -.125em;
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# .bi-123::before { content: "\f67f"; }
# .bi-alarm-fill::before { content: "\f101"; }
# .bi-alarm::before { content: "\f102"; }
# .bi-align-bottom::before { content: "\f103"; }
# .bi-align-center::before { content: "\f104"; }
# .bi-align-end::before { content: "\f105"; }
# .bi-align-middle::before { content: "\f106"; }
# .bi-align-start::before { content: "\f107"; }
# .bi-align-top::before { content: "\f108"; }
# .bi-alt::before { content: "\f109"; }
# .bi-app-indicator::before { content: "\f10a"; }
# .bi-app::before { content: "\f10b"; }
# .bi-archive-fill::before { content: "\f10c"; }
# .bi-archive::before { content: "\f10d"; }
# .bi-arrow-90deg-down::before { content: "\f10e"; }
# .bi-arrow-90deg-left::before { content: "\f10f"; }
# .bi-arrow-90deg-right::before { content: "\f110"; }
# .bi-arrow-90deg-up::before { content: "\f111"; }
# .bi-arrow-bar-down::before { content: "\f112"; }
# .bi-arrow-bar-left::before { content: "\f113"; }
# .bi-arrow-bar-right::before { content: "\f114"; }
# .bi-arrow-bar-up::before { content: "\f115"; }
# .bi-arrow-clockwise::before { content: "\f116"; }
# .bi-arrow-counterclockwise::before { content: "\f117"; }
# .bi-arrow-down-circle-fill::before { content: "\f118"; }
# .bi-arrow-down-circle::before { content: "\f119"; }
# .bi-arrow-down-left-circle-fill::before { content: "\f11a"; }
# .bi-arrow-down-left-circle::before { content: "\f11b"; }
# .bi-arrow-down-left-square-fill::before { content: "\f11c"; }
# .bi-arrow-down-left-square::before { content: "\f11d"; }
# .bi-arrow-down-left::before { content: "\f11e"; }
# .bi-arrow-down-right-circle-fill::before { content: "\f11f"; }
# .bi-arrow-down-right-circle::before { content: "\f120"; }
# .bi-arrow-down-right-square-fill::before { content: "\f121"; }
# .bi-arrow-down-right-square::before { content: "\f122"; }
# .bi-arrow-down-right::before { content: "\f123"; }
# .bi-arrow-down-short::before { content: "\f124"; }
# .bi-arrow-down-square-fill::before { content: "\f125"; }
# .bi-arrow-down-square::before { content: "\f126"; }
# .bi-arrow-down-up::before { content: "\f127"; }
# .bi-arrow-down::before { content: "\f128"; }
# .bi-arrow-left-circle-fill::before { content: "\f129"; }
# .bi-arrow-left-circle::before { content: "\f12a"; }
# .bi-arrow-left-right::before { content: "\f12b"; }
# .bi-arrow-left-short::before { content: "\f12c"; }
# .bi-arrow-left-square-fill::before { content: "\f12d"; }
# .bi-arrow-left-square::before { content: "\f12e"; }
# .bi-arrow-left::before { content: "\f12f"; }
# .bi-arrow-repeat::before { content: "\f130"; }
# .bi-arrow-return-left::before { content: "\f131"; }
# .bi-arrow-return-right::before { content: "\f132"; }
# .bi-arrow-right-circle-fill::before { content: "\f133"; }
# .bi-arrow-right-circle::before { content: "\f134"; }
# .bi-arrow-right-short::before { content: "\f135"; }
# .bi-arrow-right-square-fill::before { content: "\f136"; }
# .bi-arrow-right-square::before { content: "\f137"; }
# .bi-arrow-right::before { content: "\f138"; }
# .bi-arrow-up-circle-fill::before { content: "\f139"; }
# .bi-arrow-up-circle::before { content: "\f13a"; }
# .bi-arrow-up-left-circle-fill::before { content: "\f13b"; }
# .bi-arrow-up-left-circle::before { content: "\f13c"; }
# .bi-arrow-up-left-square-fill::before { content: "\f13d"; }
# .bi-arrow-up-left-square::before { content: "\f13e"; }
# .bi-arrow-up-left::before { content: "\f13f"; }
# .bi-arrow-up-right-circle-fill::before { content: "\f140"; }
# .bi-arrow-up-right-circle::before { content: "\f141"; }
# .bi-arrow-up-right-square-fill::before { content: "\f142"; }
# .bi-arrow-up-right-square::before { content: "\f143"; }
# .bi-arrow-up-right::before { content: "\f144"; }
# .bi-arrow-up-short::before { content: "\f145"; }
# .bi-arrow-up-square-fill::before { content: "\f146"; }
# .bi-arrow-up-square::before { content: "\f147"; }
# .bi-arrow-up::before { content: "\f148"; }
# .bi-arrows-angle-contract::before { content: "\f149"; }
# .bi-arrows-angle-expand::before { content: "\f14a"; }
# .bi-arrows-collapse::before { content: "\f14b"; }
# .bi-arrows-expand::before { content: "\f14c"; }
# .bi-arrows-fullscreen::before { content: "\f14d"; }
# .bi-arrows-move::before { content: "\f14e"; }
# .bi-aspect-ratio-fill::before { content: "\f14f"; }
# .bi-aspect-ratio::before { content: "\f150"; }
# .bi-asterisk::before { content: "\f151"; }
# .bi-at::before { content: "\f152"; }
# .bi-award-fill::before { content: "\f153"; }
# .bi-award::before { content: "\f154"; }
# .bi-back::before { content: "\f155"; }
# .bi-backspace-fill::before { content: "\f156"; }
# .bi-backspace-reverse-fill::before { content: "\f157"; }
# .bi-backspace-reverse::before { content: "\f158"; }
# .bi-backspace::before { content: "\f159"; }
# .bi-badge-3d-fill::before { content: "\f15a"; }
# .bi-badge-3d::before { content: "\f15b"; }
# .bi-badge-4k-fill::before { content: "\f15c"; }
# .bi-badge-4k::before { content: "\f15d"; }
# .bi-badge-8k-fill::before { content: "\f15e"; }
# .bi-badge-8k::before { content: "\f15f"; }
# .bi-badge-ad-fill::before { content: "\f160"; }
# .bi-badge-ad::before { content: "\f161"; }
# .bi-badge-ar-fill::before { content: "\f162"; }
# .bi-badge-ar::before { content: "\f163"; }
# .bi-badge-cc-fill::before { content: "\f164"; }
# .bi-badge-cc::before { content: "\f165"; }
# .bi-badge-hd-fill::before { content: "\f166"; }
# .bi-badge-hd::before { content: "\f167"; }
# .bi-badge-tm-fill::before { content: "\f168"; }
# .bi-badge-tm::before { content: "\f169"; }
# .bi-badge-vo-fill::before { content: "\f16a"; }
# .bi-badge-vo::before { content: "\f16b"; }
# .bi-badge-vr-fill::before { content: "\f16c"; }
# .bi-badge-vr::before { content: "\f16d"; }
# .bi-badge-wc-fill::before { content: "\f16e"; }
# .bi-badge-wc::before { content: "\f16f"; }
# .bi-bag-check-fill::before { content: "\f170"; }
# .bi-bag-check::before { content: "\f171"; }
# .bi-bag-dash-fill::before { content: "\f172"; }
# .bi-bag-dash::before { content: "\f173"; }
# .bi-bag-fill::before { content: "\f174"; }
# .bi-bag-plus-fill::before { content: "\f175"; }
# .bi-bag-plus::before { content: "\f176"; }
# .bi-bag-x-fill::before { content: "\f177"; }
# .bi-bag-x::before { content: "\f178"; }
# .bi-bag::before { content: "\f179"; }
# .bi-bar-chart-fill::before { content: "\f17a"; }
# .bi-bar-chart-line-fill::before { content: "\f17b"; }
# .bi-bar-chart-line::before { content: "\f17c"; }
# .bi-bar-chart-steps::before { content: "\f17d"; }
# .bi-bar-chart::before { content: "\f17e"; }
# .bi-basket-fill::before { content: "\f17f"; }
# .bi-basket::before { content: "\f180"; }
# .bi-basket2-fill::before { content: "\f181"; }
# .bi-basket2::before { content: "\f182"; }
# .bi-basket3-fill::before { content: "\f183"; }
# .bi-basket3::before { content: "\f184"; }
# .bi-battery-charging::before { content: "\f185"; }
# .bi-battery-full::before { content: "\f186"; }
# .bi-battery-half::before { content: "\f187"; }
# .bi-battery::before { content: "\f188"; }
# .bi-bell-fill::before { content: "\f189"; }
# .bi-bell::before { content: "\f18a"; }
# .bi-bezier::before { content: "\f18b"; }
# .bi-bezier2::before { content: "\f18c"; }
# .bi-bicycle::before { content: "\f18d"; }
# .bi-binoculars-fill::before { content: "\f18e"; }
# .bi-binoculars::before { content: "\f18f"; }
# .bi-blockquote-left::before { content: "\f190"; }
# .bi-blockquote-right::before { content: "\f191"; }
# .bi-book-fill::before { content: "\f192"; }
# .bi-book-half::before { content: "\f193"; }
# .bi-book::before { content: "\f194"; }
# .bi-bookmark-check-fill::before { content: "\f195"; }
# .bi-bookmark-check::before { content: "\f196"; }
# .bi-bookmark-dash-fill::before { content: "\f197"; }
# .bi-bookmark-dash::before { content: "\f198"; }
# .bi-bookmark-fill::before { content: "\f199"; }
# .bi-bookmark-heart-fill::before { content: "\f19a"; }
# .bi-bookmark-heart::before { content: "\f19b"; }
# .bi-bookmark-plus-fill::before { content: "\f19c"; }
# .bi-bookmark-plus::before { content: "\f19d"; }
# .bi-bookmark-star-fill::before { content: "\f19e"; }
# .bi-bookmark-star::before { content: "\f19f"; }
# .bi-bookmark-x-fill::before { content: "\f1a0"; }
# .bi-bookmark-x::before { content: "\f1a1"; }
# .bi-bookmark::before { content: "\f1a2"; }
# .bi-bookmarks-fill::before { content: "\f1a3"; }
# .bi-bookmarks::before { content: "\f1a4"; }
# .bi-bookshelf::before { content: "\f1a5"; }
# .bi-bootstrap-fill::before { content: "\f1a6"; }
# .bi-bootstrap-reboot::before { content: "\f1a7"; }
# .bi-bootstrap::before { content: "\f1a8"; }
# .bi-border-all::before { content: "\f1a9"; }
# .bi-border-bottom::before { content: "\f1aa"; }
# .bi-border-center::before { content: "\f1ab"; }
# .bi-border-inner::before { content: "\f1ac"; }
# .bi-border-left::before { content: "\f1ad"; }
# .bi-border-middle::before { content: "\f1ae"; }
# .bi-border-outer::before { content: "\f1af"; }
# .bi-border-right::before { content: "\f1b0"; }
# .bi-border-style::before { content: "\f1b1"; }
# .bi-border-top::before { content: "\f1b2"; }
# .bi-border-width::before { content: "\f1b3"; }
# .bi-border::before { content: "\f1b4"; }
# .bi-bounding-box-circles::before { content: "\f1b5"; }
# .bi-bounding-box::before { content: "\f1b6"; }
# .bi-box-arrow-down-left::before { content: "\f1b7"; }
# .bi-box-arrow-down-right::before { content: "\f1b8"; }
# .bi-box-arrow-down::before { content: "\f1b9"; }
# .bi-box-arrow-in-down-left::before { content: "\f1ba"; }
# .bi-box-arrow-in-down-right::before { content: "\f1bb"; }
# .bi-box-arrow-in-down::before { content: "\f1bc"; }
# .bi-box-arrow-in-left::before { content: "\f1bd"; }
# .bi-box-arrow-in-right::before { content: "\f1be"; }
# .bi-box-arrow-in-up-left::before { content: "\f1bf"; }
# .bi-box-arrow-in-up-right::before { content: "\f1c0"; }
# .bi-box-arrow-in-up::before { content: "\f1c1"; }
# .bi-box-arrow-left::before { content: "\f1c2"; }
# .bi-box-arrow-right::before { content: "\f1c3"; }
# .bi-box-arrow-up-left::before { content: "\f1c4"; }
# .bi-box-arrow-up-right::before { content: "\f1c5"; }
# .bi-box-arrow-up::before { content: "\f1c6"; }
# .bi-box-seam::before { content: "\f1c7"; }
# .bi-box::before { content: "\f1c8"; }
# .bi-braces::before { content: "\f1c9"; }
# .bi-bricks::before { content: "\f1ca"; }
# .bi-briefcase-fill::before { content: "\f1cb"; }
# .bi-briefcase::before { content: "\f1cc"; }
# .bi-brightness-alt-high-fill::before { content: "\f1cd"; }
# .bi-brightness-alt-high::before { content: "\f1ce"; }
# .bi-brightness-alt-low-fill::before { content: "\f1cf"; }
# .bi-brightness-alt-low::before { content: "\f1d0"; }
# .bi-brightness-high-fill::before { content: "\f1d1"; }
# .bi-brightness-high::before { content: "\f1d2"; }
# .bi-brightness-low-fill::before { content: "\f1d3"; }
# .bi-brightness-low::before { content: "\f1d4"; }
# .bi-broadcast-pin::before { content: "\f1d5"; }
# .bi-broadcast::before { content: "\f1d6"; }
# .bi-brush-fill::before { content: "\f1d7"; }
# .bi-brush::before { content: "\f1d8"; }
# .bi-bucket-fill::before { content: "\f1d9"; }
# .bi-bucket::before { content: "\f1da"; }
# .bi-bug-fill::before { content: "\f1db"; }
# .bi-bug::before { content: "\f1dc"; }
# .bi-building::before { content: "\f1dd"; }
# .bi-bullseye::before { content: "\f1de"; }
# .bi-calculator-fill::before { content: "\f1df"; }
# .bi-calculator::before { content: "\f1e0"; }
# .bi-calendar-check-fill::before { content: "\f1e1"; }
# .bi-calendar-check::before { content: "\f1e2"; }
# .bi-calendar-date-fill::before { content: "\f1e3"; }
# .bi-calendar-date::before { content: "\f1e4"; }
# .bi-calendar-day-fill::before { content: "\f1e5"; }
# .bi-calendar-day::before { content: "\f1e6"; }
# .bi-calendar-event-fill::before { content: "\f1e7"; }
# .bi-calendar-event::before { content: "\f1e8"; }
# .bi-calendar-fill::before { content: "\f1e9"; }
# .bi-calendar-minus-fill::before { content: "\f1ea"; }
# .bi-calendar-minus::before { content: "\f1eb"; }
# .bi-calendar-month-fill::before { content: "\f1ec"; }
# .bi-calendar-month::before { content: "\f1ed"; }
# .bi-calendar-plus-fill::before { content: "\f1ee"; }
# .bi-calendar-plus::before { content: "\f1ef"; }
# .bi-calendar-range-fill::before { content: "\f1f0"; }
# .bi-calendar-range::before { content: "\f1f1"; }
# .bi-calendar-week-fill::before { content: "\f1f2"; }
# .bi-calendar-week::before { content: "\f1f3"; }
# .bi-calendar-x-fill::before { content: "\f1f4"; }
# .bi-calendar-x::before { content: "\f1f5"; }
# .bi-calendar::before { content: "\f1f6"; }
# .bi-calendar2-check-fill::before { content: "\f1f7"; }
# .bi-calendar2-check::before { content: "\f1f8"; }
# .bi-calendar2-date-fill::before { content: "\f1f9"; }
# .bi-calendar2-date::before { content: "\f1fa"; }
# .bi-calendar2-day-fill::before { content: "\f1fb"; }
# .bi-calendar2-day::before { content: "\f1fc"; }
# .bi-calendar2-event-fill::before { content: "\f1fd"; }
# .bi-calendar2-event::before { content: "\f1fe"; }
# .bi-calendar2-fill::before { content: "\f1ff"; }
# .bi-calendar2-minus-fill::before { content: "\f200"; }
# .bi-calendar2-minus::before { content: "\f201"; }
# .bi-calendar2-month-fill::before { content: "\f202"; }
# .bi-calendar2-month::before { content: "\f203"; }
# .bi-calendar2-plus-fill::before { content: "\f204"; }
# .bi-calendar2-plus::before { content: "\f205"; }
# .bi-calendar2-range-fill::before { content: "\f206"; }
# .bi-calendar2-range::before { content: "\f207"; }
# .bi-calendar2-week-fill::before { content: "\f208"; }
# .bi-calendar2-week::before { content: "\f209"; }
# .bi-calendar2-x-fill::before { content: "\f20a"; }
# .bi-calendar2-x::before { content: "\f20b"; }
# .bi-calendar2::before { content: "\f20c"; }
# .bi-calendar3-event-fill::before { content: "\f20d"; }
# .bi-calendar3-event::before { content: "\f20e"; }
# .bi-calendar3-fill::before { content: "\f20f"; }
# .bi-calendar3-range-fill::before { content: "\f210"; }
# .bi-calendar3-range::before { content: "\f211"; }
# .bi-calendar3-week-fill::before { content: "\f212"; }
# .bi-calendar3-week::before { content: "\f213"; }
# .bi-calendar3::before { content: "\f214"; }
# .bi-calendar4-event::before { content: "\f215"; }
# .bi-calendar4-range::before { content: "\f216"; }
# .bi-calendar4-week::before { content: "\f217"; }
# .bi-calendar4::before { content: "\f218"; }
# .bi-camera-fill::before { content: "\f219"; }
# .bi-camera-reels-fill::before { content: "\f21a"; }
# .bi-camera-reels::before { content: "\f21b"; }
# .bi-camera-video-fill::before { content: "\f21c"; }
# .bi-camera-video-off-fill::before { content: "\f21d"; }
# .bi-camera-video-off::before { content: "\f21e"; }
# .bi-camera-video::before { content: "\f21f"; }
# .bi-camera::before { content: "\f220"; }
# .bi-camera2::before { content: "\f221"; }
# .bi-capslock-fill::before { content: "\f222"; }
# .bi-capslock::before { content: "\f223"; }
# .bi-card-checklist::before { content: "\f224"; }
# .bi-card-heading::before { content: "\f225"; }
# .bi-card-image::before { content: "\f226"; }
# .bi-card-list::before { content: "\f227"; }
# .bi-card-text::before { content: "\f228"; }
# .bi-caret-down-fill::before { content: "\f229"; }
# .bi-caret-down-square-fill::before { content: "\f22a"; }
# .bi-caret-down-square::before { content: "\f22b"; }
# .bi-caret-down::before { content: "\f22c"; }
# .bi-caret-left-fill::before { content: "\f22d"; }
# .bi-caret-left-square-fill::before { content: "\f22e"; }
# .bi-caret-left-square::before { content: "\f22f"; }
# .bi-caret-left::before { content: "\f230"; }
# .bi-caret-right-fill::before { content: "\f231"; }
# .bi-caret-right-square-fill::before { content: "\f232"; }
# .bi-caret-right-square::before { content: "\f233"; }
# .bi-caret-right::before { content: "\f234"; }
# .bi-caret-up-fill::before { content: "\f235"; }
# .bi-caret-up-square-fill::before { content: "\f236"; }
# .bi-caret-up-square::before { content: "\f237"; }
# .bi-caret-up::before { content: "\f238"; }
# .bi-cart-check-fill::before { content: "\f239"; }
# .bi-cart-check::before { content: "\f23a"; }
# .bi-cart-dash-fill::before { content: "\f23b"; }
# .bi-cart-dash::before { content: "\f23c"; }
# .bi-cart-fill::before { content: "\f23d"; }
# .bi-cart-plus-fill::before { content: "\f23e"; }
# .bi-cart-plus::before { content: "\f23f"; }
# .bi-cart-x-fill::before { content: "\f240"; }
# .bi-cart-x::before { content: "\f241"; }
# .bi-cart::before { content: "\f242"; }
# .bi-cart2::before { content: "\f243"; }
# .bi-cart3::before { content: "\f244"; }
# .bi-cart4::before { content: "\f245"; }
# .bi-cash-stack::before { content: "\f246"; }
# .bi-cash::before { content: "\f247"; }
# .bi-cast::before { content: "\f248"; }
# .bi-chat-dots-fill::before { content: "\f249"; }
# .bi-chat-dots::before { content: "\f24a"; }
# .bi-chat-fill::before { content: "\f24b"; }
# .bi-chat-left-dots-fill::before { content: "\f24c"; }
# .bi-chat-left-dots::before { content: "\f24d"; }
# .bi-chat-left-fill::before { content: "\f24e"; }
# .bi-chat-left-quote-fill::before { content: "\f24f"; }
# .bi-chat-left-quote::before { content: "\f250"; }
# .bi-chat-left-text-fill::before { content: "\f251"; }
# .bi-chat-left-text::before { content: "\f252"; }
# .bi-chat-left::before { content: "\f253"; }
# .bi-chat-quote-fill::before { content: "\f254"; }
# .bi-chat-quote::before { content: "\f255"; }
# .bi-chat-right-dots-fill::before { content: "\f256"; }
# .bi-chat-right-dots::before { content: "\f257"; }
# .bi-chat-right-fill::before { content: "\f258"; }
# .bi-chat-right-quote-fill::before { content: "\f259"; }
# .bi-chat-right-quote::before { content: "\f25a"; }
# .bi-chat-right-text-fill::before { content: "\f25b"; }
# .bi-chat-right-text::before { content: "\f25c"; }
# .bi-chat-right::before { content: "\f25d"; }
# .bi-chat-square-dots-fill::before { content: "\f25e"; }
# .bi-chat-square-dots::before { content: "\f25f"; }
# .bi-chat-square-fill::before { content: "\f260"; }
# .bi-chat-square-quote-fill::before { content: "\f261"; }
# .bi-chat-square-quote::before { content: "\f262"; }
# .bi-chat-square-text-fill::before { content: "\f263"; }
# .bi-chat-square-text::before { content: "\f264"; }
# .bi-chat-square::before { content: "\f265"; }
# .bi-chat-text-fill::before { content: "\f266"; }
# .bi-chat-text::before { content: "\f267"; }
# .bi-chat::before { content: "\f268"; }
# .bi-check-all::before { content: "\f269"; }
# .bi-check-circle-fill::before { content: "\f26a"; }
# .bi-check-circle::before { content: "\f26b"; }
# .bi-check-square-fill::before { content: "\f26c"; }
# .bi-check-square::before { content: "\f26d"; }
# .bi-check::before { content: "\f26e"; }
# .bi-check2-all::before { content: "\f26f"; }
# .bi-check2-circle::before { content: "\f270"; }
# .bi-check2-square::before { content: "\f271"; }
# .bi-check2::before { content: "\f272"; }
# .bi-chevron-bar-contract::before { content: "\f273"; }
# .bi-chevron-bar-down::before { content: "\f274"; }
# .bi-chevron-bar-expand::before { content: "\f275"; }
# .bi-chevron-bar-left::before { content: "\f276"; }
# .bi-chevron-bar-right::before { content: "\f277"; }
# .bi-chevron-bar-up::before { content: "\f278"; }
# .bi-chevron-compact-down::before { content: "\f279"; }
# .bi-chevron-compact-left::before { content: "\f27a"; }
# .bi-chevron-compact-right::before { content: "\f27b"; }
# .bi-chevron-compact-up::before { content: "\f27c"; }
# .bi-chevron-contract::before { content: "\f27d"; }
# .bi-chevron-double-down::before { content: "\f27e"; }
# .bi-chevron-double-left::before { content: "\f27f"; }
# .bi-chevron-double-right::before { content: "\f280"; }
# .bi-chevron-double-up::before { content: "\f281"; }
# .bi-chevron-down::before { content: "\f282"; }
# .bi-chevron-expand::before { content: "\f283"; }
# .bi-chevron-left::before { content: "\f284"; }
# .bi-chevron-right::before { content: "\f285"; }
# .bi-chevron-up::before { content: "\f286"; }
# .bi-circle-fill::before { content: "\f287"; }
# .bi-circle-half::before { content: "\f288"; }
# .bi-circle-square::before { content: "\f289"; }
# .bi-circle::before { content: "\f28a"; }
# .bi-clipboard-check::before { content: "\f28b"; }
# .bi-clipboard-data::before { content: "\f28c"; }
# .bi-clipboard-minus::before { content: "\f28d"; }
# .bi-clipboard-plus::before { content: "\f28e"; }
# .bi-clipboard-x::before { content: "\f28f"; }
# .bi-clipboard::before { content: "\f290"; }
# .bi-clock-fill::before { content: "\f291"; }
# .bi-clock-history::before { content: "\f292"; }
# .bi-clock::before { content: "\f293"; }
# .bi-cloud-arrow-down-fill::before { content: "\f294"; }
# .bi-cloud-arrow-down::before { content: "\f295"; }
# .bi-cloud-arrow-up-fill::before { content: "\f296"; }
# .bi-cloud-arrow-up::before { content: "\f297"; }
# .bi-cloud-check-fill::before { content: "\f298"; }
# .bi-cloud-check::before { content: "\f299"; }
# .bi-cloud-download-fill::before { content: "\f29a"; }
# .bi-cloud-download::before { content: "\f29b"; }
# .bi-cloud-drizzle-fill::before { content: "\f29c"; }
# .bi-cloud-drizzle::before { content: "\f29d"; }
# .bi-cloud-fill::before { content: "\f29e"; }
# .bi-cloud-fog-fill::before { content: "\f29f"; }
# .bi-cloud-fog::before { content: "\f2a0"; }
# .bi-cloud-fog2-fill::before { content: "\f2a1"; }
# .bi-cloud-fog2::before { content: "\f2a2"; }
# .bi-cloud-hail-fill::before { content: "\f2a3"; }
# .bi-cloud-hail::before { content: "\f2a4"; }
# .bi-cloud-haze-fill::before { content: "\f2a6"; }
# .bi-cloud-haze::before { content: "\f2a7"; }
# .bi-cloud-haze2-fill::before { content: "\f2a8"; }
# .bi-cloud-lightning-fill::before { content: "\f2a9"; }
# .bi-cloud-lightning-rain-fill::before { content: "\f2aa"; }
# .bi-cloud-lightning-rain::before { content: "\f2ab"; }
# .bi-cloud-lightning::before { content: "\f2ac"; }
# .bi-cloud-minus-fill::before { content: "\f2ad"; }
# .bi-cloud-minus::before { content: "\f2ae"; }
# .bi-cloud-moon-fill::before { content: "\f2af"; }
# .bi-cloud-moon::before { content: "\f2b0"; }
# .bi-cloud-plus-fill::before { content: "\f2b1"; }
# .bi-cloud-plus::before { content: "\f2b2"; }
# .bi-cloud-rain-fill::before { content: "\f2b3"; }
# .bi-cloud-rain-heavy-fill::before { content: "\f2b4"; }
# .bi-cloud-rain-heavy::before { content: "\f2b5"; }
# .bi-cloud-rain::before { content: "\f2b6"; }
# .bi-cloud-slash-fill::before { content: "\f2b7"; }
# .bi-cloud-slash::before { content: "\f2b8"; }
# .bi-cloud-sleet-fill::before { content: "\f2b9"; }
# .bi-cloud-sleet::before { content: "\f2ba"; }
# .bi-cloud-snow-fill::before { content: "\f2bb"; }
# .bi-cloud-snow::before { content: "\f2bc"; }
# .bi-cloud-sun-fill::before { content: "\f2bd"; }
# .bi-cloud-sun::before { content: "\f2be"; }
# .bi-cloud-upload-fill::before { content: "\f2bf"; }
# .bi-cloud-upload::before { content: "\f2c0"; }
# .bi-cloud::before { content: "\f2c1"; }
# .bi-clouds-fill::before { content: "\f2c2"; }
# .bi-clouds::before { content: "\f2c3"; }
# .bi-cloudy-fill::before { content: "\f2c4"; }
# .bi-cloudy::before { content: "\f2c5"; }
# .bi-code-slash::before { content: "\f2c6"; }
# .bi-code-square::before { content: "\f2c7"; }
# .bi-code::before { content: "\f2c8"; }
# .bi-collection-fill::before { content: "\f2c9"; }
# .bi-collection-play-fill::before { content: "\f2ca"; }
# .bi-collection-play::before { content: "\f2cb"; }
# .bi-collection::before { content: "\f2cc"; }
# .bi-columns-gap::before { content: "\f2cd"; }
# .bi-columns::before { content: "\f2ce"; }
# .bi-command::before { content: "\f2cf"; }
# .bi-compass-fill::before { content: "\f2d0"; }
# .bi-compass::before { content: "\f2d1"; }
# .bi-cone-striped::before { content: "\f2d2"; }
# .bi-cone::before { content: "\f2d3"; }
# .bi-controller::before { content: "\f2d4"; }
# .bi-cpu-fill::before { content: "\f2d5"; }
# .bi-cpu::before { content: "\f2d6"; }
# .bi-credit-card-2-back-fill::before { content: "\f2d7"; }
# .bi-credit-card-2-back::before { content: "\f2d8"; }
# .bi-credit-card-2-front-fill::before { content: "\f2d9"; }
# .bi-credit-card-2-front::before { content: "\f2da"; }
# .bi-credit-card-fill::before { content: "\f2db"; }
# .bi-credit-card::before { content: "\f2dc"; }
# .bi-crop::before { content: "\f2dd"; }
# .bi-cup-fill::before { content: "\f2de"; }
# .bi-cup-straw::before { content: "\f2df"; }
# .bi-cup::before { content: "\f2e0"; }
# .bi-cursor-fill::before { content: "\f2e1"; }
# .bi-cursor-text::before { content: "\f2e2"; }
# .bi-cursor::before { content: "\f2e3"; }
# .bi-dash-circle-dotted::before { content: "\f2e4"; }
# .bi-dash-circle-fill::before { content: "\f2e5"; }
# .bi-dash-circle::before { content: "\f2e6"; }
# .bi-dash-square-dotted::before { content: "\f2e7"; }
# .bi-dash-square-fill::before { content: "\f2e8"; }
# .bi-dash-square::before { content: "\f2e9"; }
# .bi-dash::before { content: "\f2ea"; }
# .bi-diagram-2-fill::before { content: "\f2eb"; }
# .bi-diagram-2::before { content: "\f2ec"; }
# .bi-diagram-3-fill::before { content: "\f2ed"; }
# .bi-diagram-3::before { content: "\f2ee"; }
# .bi-diamond-fill::before { content: "\f2ef"; }
# .bi-diamond-half::before { content: "\f2f0"; }
# .bi-diamond::before { content: "\f2f1"; }
# .bi-dice-1-fill::before { content: "\f2f2"; }
# .bi-dice-1::before { content: "\f2f3"; }
# .bi-dice-2-fill::before { content: "\f2f4"; }
# .bi-dice-2::before { content: "\f2f5"; }
# .bi-dice-3-fill::before { content: "\f2f6"; }
# .bi-dice-3::before { content: "\f2f7"; }
# .bi-dice-4-fill::before { content: "\f2f8"; }
# .bi-dice-4::before { content: "\f2f9"; }
# .bi-dice-5-fill::before { content: "\f2fa"; }
# .bi-dice-5::before { content: "\f2fb"; }
# .bi-dice-6-fill::before { content: "\f2fc"; }
# .bi-dice-6::before { content: "\f2fd"; }
# .bi-disc-fill::before { content: "\f2fe"; }
# .bi-disc::before { content: "\f2ff"; }
# .bi-discord::before { content: "\f300"; }
# .bi-display-fill::before { content: "\f301"; }
# .bi-display::before { content: "\f302"; }
# .bi-distribute-horizontal::before { content: "\f303"; }
# .bi-distribute-vertical::before { content: "\f304"; }
# .bi-door-closed-fill::before { content: "\f305"; }
# .bi-door-closed::before { content: "\f306"; }
# .bi-door-open-fill::before { content: "\f307"; }
# .bi-door-open::before { content: "\f308"; }
# .bi-dot::before { content: "\f309"; }
# .bi-download::before { content: "\f30a"; }
# .bi-droplet-fill::before { content: "\f30b"; }
# .bi-droplet-half::before { content: "\f30c"; }
# .bi-droplet::before { content: "\f30d"; }
# .bi-earbuds::before { content: "\f30e"; }
# .bi-easel-fill::before { content: "\f30f"; }
# .bi-easel::before { content: "\f310"; }
# .bi-egg-fill::before { content: "\f311"; }
# .bi-egg-fried::before { content: "\f312"; }
# .bi-egg::before { content: "\f313"; }
# .bi-eject-fill::before { content: "\f314"; }
# .bi-eject::before { content: "\f315"; }
# .bi-emoji-angry-fill::before { content: "\f316"; }
# .bi-emoji-angry::before { content: "\f317"; }
# .bi-emoji-dizzy-fill::before { content: "\f318"; }
# .bi-emoji-dizzy::before { content: "\f319"; }
# .bi-emoji-expressionless-fill::before { content: "\f31a"; }
# .bi-emoji-expressionless::before { content: "\f31b"; }
# .bi-emoji-frown-fill::before { content: "\f31c"; }
# .bi-emoji-frown::before { content: "\f31d"; }
# .bi-emoji-heart-eyes-fill::before { content: "\f31e"; }
# .bi-emoji-heart-eyes::before { content: "\f31f"; }
# .bi-emoji-laughing-fill::before { content: "\f320"; }
# .bi-emoji-laughing::before { content: "\f321"; }
# .bi-emoji-neutral-fill::before { content: "\f322"; }
# .bi-emoji-neutral::before { content: "\f323"; }
# .bi-emoji-smile-fill::before { content: "\f324"; }
# .bi-emoji-smile-upside-down-fill::before { content: "\f325"; }
# .bi-emoji-smile-upside-down::before { content: "\f326"; }
# .bi-emoji-smile::before { content: "\f327"; }
# .bi-emoji-sunglasses-fill::before { content: "\f328"; }
# .bi-emoji-sunglasses::before { content: "\f329"; }
# .bi-emoji-wink-fill::before { content: "\f32a"; }
# .bi-emoji-wink::before { content: "\f32b"; }
# .bi-envelope-fill::before { content: "\f32c"; }
# .bi-envelope-open-fill::before { content: "\f32d"; }
# .bi-envelope-open::before { content: "\f32e"; }
# .bi-envelope::before { content: "\f32f"; }
# .bi-eraser-fill::before { content: "\f330"; }
# .bi-eraser::before { content: "\f331"; }
# .bi-exclamation-circle-fill::before { content: "\f332"; }
# .bi-exclamation-circle::before { content: "\f333"; }
# .bi-exclamation-diamond-fill::before { content: "\f334"; }
# .bi-exclamation-diamond::before { content: "\f335"; }
# .bi-exclamation-octagon-fill::before { content: "\f336"; }
# .bi-exclamation-octagon::before { content: "\f337"; }
# .bi-exclamation-square-fill::before { content: "\f338"; }
# .bi-exclamation-square::before { content: "\f339"; }
# .bi-exclamation-triangle-fill::before { content: "\f33a"; }
# .bi-exclamation-triangle::before { content: "\f33b"; }
# .bi-exclamation::before { content: "\f33c"; }
# .bi-exclude::before { content: "\f33d"; }
# .bi-eye-fill::before { content: "\f33e"; }
# .bi-eye-slash-fill::before { content: "\f33f"; }
# .bi-eye-slash::before { content: "\f340"; }
# .bi-eye::before { content: "\f341"; }
# .bi-eyedropper::before { content: "\f342"; }
# .bi-eyeglasses::before { content: "\f343"; }
# .bi-facebook::before { content: "\f344"; }
# .bi-file-arrow-down-fill::before { content: "\f345"; }
# .bi-file-arrow-down::before { content: "\f346"; }
# .bi-file-arrow-up-fill::before { content: "\f347"; }
# .bi-file-arrow-up::before { content: "\f348"; }
# .bi-file-bar-graph-fill::before { content: "\f349"; }
# .bi-file-bar-graph::before { content: "\f34a"; }
# .bi-file-binary-fill::before { content: "\f34b"; }
# .bi-file-binary::before { content: "\f34c"; }
# .bi-file-break-fill::before { content: "\f34d"; }
# .bi-file-break::before { content: "\f34e"; }
# .bi-file-check-fill::before { content: "\f34f"; }
# .bi-file-check::before { content: "\f350"; }
# .bi-file-code-fill::before { content: "\f351"; }
# .bi-file-code::before { content: "\f352"; }
# .bi-file-diff-fill::before { content: "\f353"; }
# .bi-file-diff::before { content: "\f354"; }
# .bi-file-earmark-arrow-down-fill::before { content: "\f355"; }
# .bi-file-earmark-arrow-down::before { content: "\f356"; }
# .bi-file-earmark-arrow-up-fill::before { content: "\f357"; }
# .bi-file-earmark-arrow-up::before { content: "\f358"; }
# .bi-file-earmark-bar-graph-fill::before { content: "\f359"; }
# .bi-file-earmark-bar-graph::before { content: "\f35a"; }
# .bi-file-earmark-binary-fill::before { content: "\f35b"; }
# .bi-file-earmark-binary::before { content: "\f35c"; }
# .bi-file-earmark-break-fill::before { content: "\f35d"; }
# .bi-file-earmark-break::before { content: "\f35e"; }
# .bi-file-earmark-check-fill::before { content: "\f35f"; }
# .bi-file-earmark-check::before { content: "\f360"; }
# .bi-file-earmark-code-fill::before { content: "\f361"; }
# .bi-file-earmark-code::before { content: "\f362"; }
# .bi-file-earmark-diff-fill::before { content: "\f363"; }
# .bi-file-earmark-diff::before { content: "\f364"; }
# .bi-file-earmark-easel-fill::before { content: "\f365"; }
# .bi-file-earmark-easel::before { content: "\f366"; }
# .bi-file-earmark-excel-fill::before { content: "\f367"; }
# .bi-file-earmark-excel::before { content: "\f368"; }
# .bi-file-earmark-fill::before { content: "\f369"; }
# .bi-file-earmark-font-fill::before { content: "\f36a"; }
# .bi-file-earmark-font::before { content: "\f36b"; }
# .bi-file-earmark-image-fill::before { content: "\f36c"; }
# .bi-file-earmark-image::before { content: "\f36d"; }
# .bi-file-earmark-lock-fill::before { content: "\f36e"; }
# .bi-file-earmark-lock::before { content: "\f36f"; }
# .bi-file-earmark-lock2-fill::before { content: "\f370"; }
# .bi-file-earmark-lock2::before { content: "\f371"; }
# .bi-file-earmark-medical-fill::before { content: "\f372"; }
# .bi-file-earmark-medical::before { content: "\f373"; }
# .bi-file-earmark-minus-fill::before { content: "\f374"; }
# .bi-file-earmark-minus::before { content: "\f375"; }
# .bi-file-earmark-music-fill::before { content: "\f376"; }
# .bi-file-earmark-music::before { content: "\f377"; }
# .bi-file-earmark-person-fill::before { content: "\f378"; }
# .bi-file-earmark-person::before { content: "\f379"; }
# .bi-file-earmark-play-fill::before { content: "\f37a"; }
# .bi-file-earmark-play::before { content: "\f37b"; }
# .bi-file-earmark-plus-fill::before { content: "\f37c"; }
# .bi-file-earmark-plus::before { content: "\f37d"; }
# .bi-file-earmark-post-fill::before { content: "\f37e"; }
# .bi-file-earmark-post::before { content: "\f37f"; }
# .bi-file-earmark-ppt-fill::before { content: "\f380"; }
# .bi-file-earmark-ppt::before { content: "\f381"; }
# .bi-file-earmark-richtext-fill::before { content: "\f382"; }
# .bi-file-earmark-richtext::before { content: "\f383"; }
# .bi-file-earmark-ruled-fill::before { content: "\f384"; }
# .bi-file-earmark-ruled::before { content: "\f385"; }
# .bi-file-earmark-slides-fill::before { content: "\f386"; }
# .bi-file-earmark-slides::before { content: "\f387"; }
# .bi-file-earmark-spreadsheet-fill::before { content: "\f388"; }
# .bi-file-earmark-spreadsheet::before { content: "\f389"; }
# .bi-file-earmark-text-fill::before { content: "\f38a"; }
# .bi-file-earmark-text::before { content: "\f38b"; }
# .bi-file-earmark-word-fill::before { content: "\f38c"; }
# .bi-file-earmark-word::before { content: "\f38d"; }
# .bi-file-earmark-x-fill::before { content: "\f38e"; }
# .bi-file-earmark-x::before { content: "\f38f"; }
# .bi-file-earmark-zip-fill::before { content: "\f390"; }
# .bi-file-earmark-zip::before { content: "\f391"; }
# .bi-file-earmark::before { content: "\f392"; }
# .bi-file-easel-fill::before { content: "\f393"; }
# .bi-file-easel::before { content: "\f394"; }
# .bi-file-excel-fill::before { content: "\f395"; }
# .bi-file-excel::before { content: "\f396"; }
# .bi-file-fill::before { content: "\f397"; }
# .bi-file-font-fill::before { content: "\f398"; }
# .bi-file-font::before { content: "\f399"; }
# .bi-file-image-fill::before { content: "\f39a"; }
# .bi-file-image::before { content: "\f39b"; }
# .bi-file-lock-fill::before { content: "\f39c"; }
# .bi-file-lock::before { content: "\f39d"; }
# .bi-file-lock2-fill::before { content: "\f39e"; }
# .bi-file-lock2::before { content: "\f39f"; }
# .bi-file-medical-fill::before { content: "\f3a0"; }
# .bi-file-medical::before { content: "\f3a1"; }
# .bi-file-minus-fill::before { content: "\f3a2"; }
# .bi-file-minus::before { content: "\f3a3"; }
# .bi-file-music-fill::before { content: "\f3a4"; }
# .bi-file-music::before { content: "\f3a5"; }
# .bi-file-person-fill::before { content: "\f3a6"; }
# .bi-file-person::before { content: "\f3a7"; }
# .bi-file-play-fill::before { content: "\f3a8"; }
# .bi-file-play::before { content: "\f3a9"; }
# .bi-file-plus-fill::before { content: "\f3aa"; }
# .bi-file-plus::before { content: "\f3ab"; }
# .bi-file-post-fill::before { content: "\f3ac"; }
# .bi-file-post::before { content: "\f3ad"; }
# .bi-file-ppt-fill::before { content: "\f3ae"; }
# .bi-file-ppt::before { content: "\f3af"; }
# .bi-file-richtext-fill::before { content: "\f3b0"; }
# .bi-file-richtext::before { content: "\f3b1"; }
# .bi-file-ruled-fill::before { content: "\f3b2"; }
# .bi-file-ruled::before { content: "\f3b3"; }
# .bi-file-slides-fill::before { content: "\f3b4"; }
# .bi-file-slides::before { content: "\f3b5"; }
# .bi-file-spreadsheet-fill::before { content: "\f3b6"; }
# .bi-file-spreadsheet::before { content: "\f3b7"; }
# .bi-file-text-fill::before { content: "\f3b8"; }
# .bi-file-text::before { content: "\f3b9"; }
# .bi-file-word-fill::before { content: "\f3ba"; }
# .bi-file-word::before { content: "\f3bb"; }
# .bi-file-x-fill::before { content: "\f3bc"; }
# .bi-file-x::before { content: "\f3bd"; }
# .bi-file-zip-fill::before { content: "\f3be"; }
# .bi-file-zip::before { content: "\f3bf"; }
# .bi-file::before { content: "\f3c0"; }
# .bi-files-alt::before { content: "\f3c1"; }
# .bi-files::before { content: "\f3c2"; }
# .bi-film::before { content: "\f3c3"; }
# .bi-filter-circle-fill::before { content: "\f3c4"; }
# .bi-filter-circle::before { content: "\f3c5"; }
# .bi-filter-left::before { content: "\f3c6"; }
# .bi-filter-right::before { content: "\f3c7"; }
# .bi-filter-square-fill::before { content: "\f3c8"; }
# ...
#   font-weight: 600;
# }
#
# .contact .php-email-form .error-message br+br {
#   margin-top: 25px;
# }
#
# .contact .php-email-form .sent-message {
#   display: none;
#   color: #fff;
#   background: #059652;
#   text-align: center;
#   padding: 15px;
#   font-weight: 600;
# }
#
# .contact .php-email-form .loading {
#   display: none;
#   background: #fff;
#   text-align: center;
#   padding: 15px;
# }
#
# .contact .php-email-form .loading:before {
#   content: "";
#   display: inline-block;
#   border-radius: 50%;
#   width: 24px;
#   height: 24px;
#   margin: 0 10px -6px 0;
#   border: 3px solid #059652;
#   border-top-color: #fff;
#   animation: animate-loading 1s linear infinite;
# }
#
# .contact .php-email-form input,
# .contact .php-email-form textarea {
#   border-radius: 0;
#   box-shadow: none;
#   font-size: 14px;
# }
#
# .contact .php-email-form input[type=text],
# .contact .php-email-form input[type=email],
# .contact .php-email-form textarea {
#   padding: 12px 15px;
# }
#
# .contact .php-email-form input[type=text]:focus,
# .contact .php-email-form input[type=email]:focus,
# .contact .php-email-form textarea:focus {
#   border-color: var(--color-primary);
# }
#
# .contact .php-email-form textarea {
#   padding: 10px 12px;
# }
#
# .contact .php-email-form button[type=submit] {
#   background: var(--color-primary);
#   border: 0;
#   padding: 14px 45px;
#   color: #fff;
#   transition: 0.4s;
#   border-radius: 50px;
# }
#
# .contact .php-email-form button[type=submit]:hover {
#   background: rgba(0, 131, 116, 0.8);
# }
#
# @keyframes animate-loading {
#   0% {
#     transform: rotate(0deg);
#   }
#
#   100% {
#     transform: rotate(360deg);
#   }
# }
#
# /*--------------------------------------------------------------
# # Hero Section
# --------------------------------------------------------------*/
# .hero {
#   width: 100%;
#   position: relative;
#   background: var(--color-primary);
#   padding: 60px 0 0 0;
# }
#
# @media (min-width: 1365px) {
#   .hero {
#     background-attachment: fixed;
#   }
# }
#
# .hero h2 {
#   font-size: 48px;
#   font-weight: 700;
#   margin-bottom: 20px;
#   color: #fff;
# }
#
# .hero p {
#   color: rgba(255, 255, 255, 0.6);
#   font-weight: 400;
#   margin-bottom: 30px;
# }
#
# .hero .btn-get-started {
#   font-family: var(--font-primary);
#   font-weight: 500;
#   font-size: 15px;
#   letter-spacing: 1px;
#   display: inline-block;
#   padding: 14px 40px;
#   border-radius: 50px;
#   transition: 0.3s;
#   color: #fff;
#   background: rgba(255, 255, 255, 0.1);
#   box-shadow: 0 0 15px rgba(0, 0, 0, 0.08);
#   border: 2px solid rgba(255, 255, 255, 0.1);
# }
#
# .hero .btn-get-started:hover {
#   border-color: rgba(255, 255, 255, 0.5);
# }
#
# .hero .btn-watch-video {
#   font-size: 16px;
#   transition: 0.5s;
#   margin-left: 25px;
#   color: #fff;
#   font-weight: 600;
# }
#
# .hero .btn-watch-video i {
#   color: rgba(255, 255, 255, 0.5);
#   font-size: 32px;
#   transition: 0.3s;
#   line-height: 0;
#   margin-right: 8px;
# }
#
# .hero .btn-watch-video:hover i {
#   color: #fff;
# }
#
# @media (max-width: 640px) {
#   .hero h2 {
#     font-size: 36px;
#   }
#
#   .hero .btn-get-started,
#   .hero .btn-watch-video {
#     font-size: 14px;
#   }
# }
#
# .hero .icon-boxes {
#   padding-bottom: 60px;
# }
#
# @media (min-width: 1200px) {
#   .hero .icon-boxes:before {
#     content: "";
#     position: absolute;
#     bottom: 0;
#     left: 0;
#     right: 0;
#     height: calc(50% + 20px);
#     background-color: #fff;
#   }
# }
#
# .hero .icon-box {
#   padding: 60px 30px;
#   position: relative;
#   overflow: hidden;
#   background: #008d7d;
#   box-shadow: 0 0 29px 0 rgba(0, 0, 0, 0.08);
#   transition: all 0.3s ease-in-out;
#   border-radius: 8px;
#   z-index: 1;
#   height: 100%;
#   width: 100%;
#   text-align: center;
# }
#
# .hero .icon-box .title {
#   font-weight: 700;
#   margin-bottom: 15px;
#   font-size: 24px;
# }
#
# .hero .icon-box .title a {
#   color: #fff;
#   transition: 0.3s;
# }
#
# .hero .icon-box .icon {
#   margin-bottom: 20px;
#   padding-top: 10px;
#   display: inline-block;
#   transition: all 0.3s ease-in-out;
#   font-size: 48px;
#   line-height: 1;
#   color: rgba(255, 255, 255, 0.6);
# }
#
# .hero .icon-box:hover {
#   background: #009786;
# }
#
# .hero .icon-box:hover .title a,
# .hero .icon-box:hover .icon {
#   color: #fff;
# }
#
# /*--------------------------------------------------------------
# # Blog
# --------------------------------------------------------------*/
# .blog .blog-pagination {
#   margin-top: 30px;
#   color: #555555;
# }
#
# .blog .blog-pagination ul {
#   display: flex;
#   padding: 0;
#   margin: 0;
#   list-style: none;
# }
#
# .blog .blog-pagination li {
#   margin: 0 5px;
#   transition: 0.3s;
#   border-radius: 10px;
# }
#
# .blog .blog-pagination li a {
#   color: var(--color-default);
#   padding: 7px 16px;
#   display: flex;
#   align-items: center;
#   justify-content: center;
# }
#
# .blog .blog-pagination li.active,
# .blog .blog-pagination li:hover {
#   background: var(--color-primary);
#   color: #fff;
# }
#
# .blog .blog-pagination li.active a,
# .blog .blog-pagination li:hover a {
#   color: var(--color-white);
# }
#
# /*--------------------------------------------------------------
# # Blog Posts List
# --------------------------------------------------------------*/
# .blog .posts-list article {
#   box-shadow: 0 4px 16px rgba(0, 0, 0, 0.1);
#   padding: 30px;
#   height: 100%;
#   border-radius: 10px;
#   overflow: hidden;
# }
#
# .blog .posts-list .post-img {
#   max-height: 240px;
#   margin: -30px -30px 15px -30px;
#   overflow: hidden;
# }
#
# .blog .posts-list .post-category {
#   font-size: 16px;
#   color: #555555;
#   margin-bottom: 10px;
# }
#
# .blog .posts-list .title {
#   font-size: 22px;
#   font-weight: 700;
#   padding: 0;
#   margin: 0 0 20px 0;
# }
#
# .blog .posts-list .title a {
#   color: var(--color-default);
#   transition: 0.3s;
# }
#
# .blog .posts-list .title a:hover {
#   color: var(--color-primary);
# }
#
# .blog .posts-list .post-author-img {
#   width: 50px;
#   border-radius: 50%;
#   margin-right: 15px;
# }
#
# .blog .posts-list .post-author-list {
#   font-weight: 600;
#   margin-bottom: 5px;
# }
#
# .blog .posts-list .post-date {
#   font-size: 14px;
#   color: #3c3c3c;
#   margin-bottom: 0;
# }
#
# /*--------------------------------------------------------------
# # Blog Details
# --------------------------------------------------------------*/
# .blog .blog-details {
#   box-shadow: 0 4px 16px rgba(0, 0, 0, 0.1);
#   padding: 30px;
#   border-radius: 10px;
# }
#
# .blog .blog-details .post-img {
#   margin: -30px -30px 20px -30px;
#   overflow: hidden;
#   border-radius: 10px 10px 0 0;
# }
#
# .blog .blog-details .title {
#   font-size: 28px;
#   font-weight: 700;
#   padding: 0;
#   margin: 20px 0 0 0;
#   color: var(--color-default);
# }
#
# .blog .blog-details .content {
#   margin-top: 20px;
# }
#
# .blog .blog-details .content h3 {
#   font-size: 22px;
#   margin-top: 30px;
#   font-weight: bold;
# }
#
# .blog .blog-details .content blockquote {
#   overflow: hidden;
#   background-color: rgba(34, 34, 34, 0.06);
#   padding: 60px;
#   position: relative;
#   text-align: center;
#   margin: 20px 0;
# }
#
# .blog .blog-details .content blockquote p {
#   color: var(--color-default);
#   line-height: 1.6;
#   margin-bottom: 0;
#   font-style: italic;
#   font-weight: 500;
#   font-size: 22px;
# }
#
# .blog .blog-details .content blockquote:after {
#   content: "";
#   position: absolute;
#   left: 0;
#   top: 0;
#   bottom: 0;
#   width: 3px;
#   background-color: var(--color-secondary);
#   margin-top: 20px;
#   margin-bottom: 20px;
# }
#
# .blog .blog-details .meta-top {
#   margin-top: 20px;
#   color: #6c757d;
# }
#
# .blog .blog-details .meta-top ul {
#   display: flex;
#   flex-wrap: wrap;
#   list-style: none;
#   align-items: center;
#   padding: 0;
#   margin: 0;
# }
#
# .blog .blog-details .meta-top ul li+li {
#   padding-left: 20px;
# }
#
# .blog .blog-details .meta-top i {
#   font-size: 16px;
#   margin-right: 8px;
#   line-height: 0;
#   color: var(--color-primary);
# }
#
# .blog .blog-details .meta-top a {
#   color: #6c757d;
#   font-size: 14px;
#   display: inline-block;
#   line-height: 1;
# }
#
# .blog .blog-details .meta-bottom {
#   padding-top: 10px;
#   border-top: 1px solid rgba(34, 34, 34, 0.15);
# }
#
# .blog .blog-details .meta-bottom i {
#   color: #555555;
#   display: inline;
# }
#
# .blog .blog-details .meta-bottom a {
#   color: rgba(34, 34, 34, 0.8);
#   transition: 0.3s;
# }
#
# .blog .blog-details .meta-bottom a:hover {
#   color: var(--color-primary);
# }
#
# .blog .blog-details .meta-bottom .cats {
#   list-style: none;
#   display: inline;
#   padding: 0 20px 0 0;
#   font-size: 14px;
# }
#
# .blog .blog-details .meta-bottom .cats li {
#   display: inline-block;
# }
#
# .blog .blog-details .meta-bottom .tags {
#   list-style: none;
#   display: inline;
#   padding: 0;
#   font-size: 14px;
# }
#
# .blog .blog-details .meta-bottom .tags li {
#   display: inline-block;
# }
#
# .blog .blog-details .meta-bottom .tags li+li::before {
#   padding-right: 6px;
#   color: var(--color-default);
#   content: ",";
# }
#
# .blog .blog-details .meta-bottom .share {
#   font-size: 16px;
# }
#
# .blog .blog-details .meta-bottom .share i {
#   padding-left: 5px;
# }
#
# .blog .post-author {
#   padding: 20px;
#   margin-top: 30px;
#   box-shadow: 0 4px 16px rgba(0, 0, 0, 0.1);
#   border-radius: 10px;
# }
#
# .blog .post-author img {
#   max-width: 120px;
#   margin-right: 20px;
# }
#
# .blog .post-author h4 {
#   font-weight: 600;
#   font-size: 22px;
#   margin-bottom: 0px;
#   padding: 0;
#   color: var(--color-default);
# }
#
# .blog .post-author .social-links {
#   margin: 0 10px 10px 0;
# }
#
# .blog .post-author .social-links a {
#   color: rgba(34, 34, 34, 0.5);
#   margin-right: 5px;
# }
#
# .blog .post-author p {
#   font-style: italic;
#   color: rgba(108, 117, 125, 0.8);
#   margin-bottom: 0;
# }
#
# /*--------------------------------------------------------------
# # Blog Sidebar
# --------------------------------------------------------------*/
# .blog .sidebar {
#   padding: 30px;
#   box-shadow: 0 4px 16px rgba(0, 0, 0, 0.1);
#   border-radius: 10px;
# }
#
# .blog .sidebar .sidebar-title {
#   font-size: 20px;
#   font-weight: 700;
#   padding: 0;
#   margin: 0;
#   color: var(--color-default);
# }
#
# .blog .sidebar .sidebar-item+.sidebar-item {
#   margin-top: 40px;
# }
#
# .blog .sidebar .search-form form {
#   background: #fff;
#   border: 1px solid rgba(34, 34, 34, 0.3);
#   padding: 5px 10px;
#   position: relative;
#   border-radius: 50px;
# }
#
# .blog .sidebar .search-form form input[type=text] {
#   border: 0;
#   padding: 4px;
#   border-radius: 50px;
#   width: calc(100% - 60px);
# }
#
# .blog .sidebar .search-form form input[type=text]:focus {
#   outline: none;
# }
#
# .blog .sidebar .search-form form button {
#   position: absolute;
#   top: 0;
#   right: 0;
#   bottom: 0;
#   border: 0;
#   background: none;
#   font-size: 16px;
#   padding: 0 25px;
#   margin: -1px;
#   background: var(--color-primary);
#   color: #fff;
#   transition: 0.3s;
#   border-radius: 50px;
#   line-height: 0;
# }
#
# .blog .sidebar .search-form form button i {
#   line-height: 0;
# }
#
# .blog .sidebar .search-form form button:hover {
#   background: rgba(0, 131, 116, 0.8);
# }
#
# .blog .sidebar .categories ul {
#   list-style: none;
#   padding: 0;
# }
#
# .blog .sidebar .categories ul li+li {
#   padding-top: 10px;
# }
#
# .blog .sidebar .categories ul a {
#   color: var(--color-default);
#   transition: 0.3s;
# }
#
# .blog .sidebar .categories ul a:hover {
#   color: var(--color-primary);
# }
#
# .blog .sidebar .categories ul a span {
#   padding-left: 5px;
#   color: rgba(34, 34, 34, 0.4);
#   font-size: 14px;
# }
#
# .blog .sidebar .recent-posts .post-item+.post-item {
#   margin-top: 15px;
# }
#
# .blog .sidebar .recent-posts img {
#   width: 80px;
#   float: left;
# }
#
# .blog .sidebar .recent-posts h4 {
#   font-size: 15px;
#   margin-left: 95px;
#   font-weight: bold;
# }
#
# .blog .sidebar .recent-posts h4 a {
#   color: var(--color-default);
#   transition: 0.3s;
# }
#
# .blog .sidebar .recent-posts h4 a:hover {
#   color: var(--color-primary);
# }
#
# .blog .sidebar .recent-posts time {
#   display: block;
#   margin-left: 95px;
#   font-style: italic;
#   font-size: 14px;
#   color: rgba(34, 34, 34, 0.4);
# }
#
# .blog .sidebar .tags {
#   margin-bottom: -10px;
# }
#
# .blog .sidebar .tags ul {
#   list-style: none;
#   padding: 0;
# }
#
# .blog .sidebar .tags ul li {
#   display: inline-block;
# }
#
# .blog .sidebar .tags ul a {
#   color: #555555;
#   font-size: 14px;
#   padding: 6px 20px;
#   margin: 0 6px 8px 0;
#   border: 1px solid #d5d5d5;
#   display: inline-block;
#   transition: 0.3s;
#   border-radius: 50px;
# }
#
# .blog .sidebar .tags ul a:hover {
#   color: #fff;
#   border: 1px solid var(--color-primary);
#   background: var(--color-primary);
# }
#
# .blog .sidebar .tags ul a span {
#   padding-left: 5px;
#   color: rgba(85, 85, 85, 0.8);
#   font-size: 14px;
# }
#
# /*--------------------------------------------------------------
# # Blog Comments
# --------------------------------------------------------------*/
# .blog .comments {
#   margin-top: 30px;
# }
#
# .blog .comments .comments-count {
#   font-weight: bold;
# }
#
# .blog .comments .comment {
#   margin-top: 30px;
#   position: relative;
# }
#
# .blog .comments .comment .comment-img {
#   margin-right: 14px;
# }
#
# .blog .comments .comment .comment-img img {
#   width: 60px;
# }
#
# .blog .comments .comment h5 {
#   font-size: 16px;
#   margin-bottom: 2px;
# }
#
# .blog .comments .comment h5 a {
#   font-weight: bold;
#   color: var(--color-default);
#   transition: 0.3s;
# }
#
# .blog .comments .comment h5 a:hover {
#   color: var(--color-primary);
# }
#
# .blog .comments .comment h5 .reply {
#   padding-left: 10px;
#   color: var(--color-primary);
# }
#
# .blog .comments .comment h5 .reply i {
#   font-size: 20px;
# }
#
# .blog .comments .comment time {
#   display: block;
#   font-size: 14px;
#   color: rgba(34, 34, 34, 0.8);
#   margin-bottom: 5px;
# }
#
# .blog .comments .comment.comment-reply {
#   padding-left: 40px;
# }
#
# .blog .comments .reply-form {
#   margin-top: 30px;
#   padding: 30px;
#   box-shadow: 0 0 16px rgba(0, 0, 0, 0.1);
#   border-radius: 10px;
# }
#
# .blog .comments .reply-form h4 {
#   font-weight: bold;
#   font-size: 22px;
# }
#
# .blog .comments .reply-form p {
#   font-size: 14px;
# }
#
# .blog .comments .reply-form input {
#   border-radius: 4px;
#   padding: 10px 10px;
#   font-size: 14px;
# }
#
# .blog .comments .reply-form input:focus {
#   box-shadow: none;
#   border-color: rgba(0, 131, 116, 0.8);
# }
#
# .blog .comments .reply-form textarea {
#   border-radius: 4px;
#   padding: 10px 10px;
#   font-size: 14px;
# }
#
# .blog .comments .reply-form textarea:focus {
#   box-shadow: none;
#   border-color: rgba(0, 131, 116, 0.8);
# }
#
# .blog .comments .reply-form .form-group {
#   margin-bottom: 25px;
# }
#
# .blog .comments .reply-form .btn-primary {
#   border-radius: 50px;
#   padding: 14px 40px;
#   border: 0;
#   background-color: var(--color-secondary);
# }
#
# .blog .comments .reply-form .btn-primary:hover {
#   background-color: rgba(248, 90, 64, 0.8);
# }
#
# /*--------------------------------------------------------------
# # Footer
# --------------------------------------------------------------*/
# .footer {
#   font-size: 14px;
#   background-color: var(--color-primary);
#   padding: 50px 0;
#   color: white;
# }
#
# .footer .footer-info .logo {
#   line-height: 0;
#   margin-bottom: 25px;
# }
#
# .footer .footer-info .logo img {
#   max-height: 40px;
#   margin-right: 6px;
# }
#
# .footer .footer-info .logo span {
#   font-size: 30px;
#   font-weight: 700;
#   letter-spacing: 1px;
#   color: #fff;
#   font-family: var(--font-primary);
# }
#
# .footer .footer-info p {
#   font-size: 14px;
#   font-family: var(--font-primary);
# }
#
# .footer .social-links a {
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   width: 40px;
#   height: 40px;
#   border-radius: 50%;
#   border: 1px solid rgba(255, 255, 255, 0.2);
#   font-size: 16px;
#   color: rgba(255, 255, 255, 0.7);
#   margin-right: 10px;
#   transition: 0.3s;
# }
#
# .footer .social-links a:hover {
#   color: #fff;
#   border-color: #fff;
# }
#
# .footer h4 {
#   font-size: 16px;
#   font-weight: bold;
#   position: relative;
#   padding-bottom: 12px;
# }
#
# .footer .footer-links {
#   margin-bottom: 30px;
# }
#
# .footer .footer-links ul {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .footer .footer-links ul i {
#   padding-right: 2px;
#   color: rgba(0, 131, 116, 0.8);
#   font-size: 12px;
#   line-height: 0;
# }
#
# .footer .footer-links ul li {
#   padding: 10px 0;
#   display: flex;
#   align-items: center;
# }
#
# .footer .footer-links ul li:first-child {
#   padding-top: 0;
# }
#
# .footer .footer-links ul a {
#   color: rgba(255, 255, 255, 0.7);
#   transition: 0.3s;
#   display: inline-block;
#   line-height: 1;
# }
#
# .footer .footer-links ul a:hover {
#   color: #fff;
# }
#
# .footer .footer-contact p {
#   line-height: 26px;
# }
#
# .footer .copyright {
#   text-align: center;
# }
#
# .footer .credits {
#   padding-top: 4px;
#   text-align: center;
#   font-size: 13px;
# }
#
# .footer .credits a {
#   color: #fff;
# }
#
# Style Tags:
#
# Inline CSS:

# %%
import urllib.parse
from typing import Optional
import requests
from bs4 import BeautifulSoup
import cssutils

def extract_css_from_webpage(url: str, request_kwargs: Optional[dict] = None, verbose: bool = False):
    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def extract_typography_properties(element, css_rules):
    properties = {
        'background-color': None,
        'color': None,
        'font-family': None,
        'font-size': None,
        'font-weight': None,
        'margin': None,
        'padding': None,
        'text-align': None,
        'justify-content': None,
        'align-items': None
    }
    for rule in css_rules:
        if not hasattr(rule, 'selectorText'):
            continue
        if element.name in rule.selectorText:
            for prop in properties.keys():
                if properties[prop] is None and rule.style.getPropertyValue(prop):
                    properties[prop] = rule.style.getPropertyValue(prop)
    return properties

def find_properties(url: str):
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_parser = cssutils.CSSParser()
    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        sheet = css_parser.parseString(css)
        css_rules.extend(sheet.cssRules)

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties = find_properties(url)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING	Property: Unknown Property name. [5:159965: --bs-aspect-ratio]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:159965: --bs-aspect-ratio]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160136: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160136: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160160: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160160: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160210: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160210: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160234: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160234: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160312: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160312: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160336: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160336: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160389: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160389: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160413: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160413: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160492: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160492: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160516: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160516: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160569: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160569: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160593: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160593: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160672: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160672: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160696: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160696: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160749: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160749: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160773: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160773: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160853: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160853: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160877: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160877: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160930: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160930: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160954: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160954: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161035: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161035: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:161059: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:161059: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161113: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161113: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:161137: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:161137: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:161184: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:161184: display]
# WARNING	Property: Unknown Property name. [5:161197: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161197: flex-direction]
# WARNING	Property: Unknown Property name. [5:161216: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161216: align-items]
# WARNING	Property: Unknown Property name. [5:161235: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161235: align-self]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:161262: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:161262: display]
# WARNING	Property: Unknown Property name. [5:161275: flex]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161275: flex]
# WARNING	Property: Unknown Property name. [5:161289: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161289: flex-direction]
# WARNING	Property: Unknown Property name. [5:161311: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161311: align-self]
# WARNING	Property: Unknown Property name. [5:161843: text-overflow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161843: text-overflow]
# WARNING	Property: Unknown Property name. [5:161910: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161910: align-self]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--bs-border-width) [5:161929: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--bs-border-width) [5:161929: width]
# WARNING	Property: Unknown Property name. [5:162423: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162423: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162455: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162455: object-fit]
# WARNING	Property: Unknown Property name. [5:162502: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162502: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162532: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162532: object-fit]
# WARNING	Property: Unknown Property name. [5:162576: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162576: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162605: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162605: object-fit]
# WARNING	Property: Unknown Property name. [5:162649: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162649: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162684: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162684: object-fit]
# WARNING	Property: Unknown Property name. [5:162733: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162733: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162762: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162762: object-fit]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: grid [5:163618: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: grid [5:163618: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: inline-grid [5:163656: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: inline-grid [5:163656: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:163811: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:163811: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: inline-flex [5:163849: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: inline-flex [5:163849: display]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow) [5:163918: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow) [5:163918: box-shadow]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-sm) [5:163971: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-sm) [5:163971: box-shadow]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-lg) [5:164027: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-lg) [5:164027: box-shadow]
# WARNING	Property: Unknown Property name. [5:164131: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164131: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164158)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164158)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164178)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164178)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164233: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164233: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164260)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164260)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164282)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164282)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164335: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164335: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164362)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164362)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164382)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164382)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164432: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164432: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164459)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164459)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164476)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164476)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164529: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164529: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164556)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164556)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164576)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164576)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164628: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164628: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164655)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164655)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164674)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164674)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164725: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164725: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164752)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164752)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164770)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164770)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164820: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164820: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164847)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164847)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164864)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164864)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:165092: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:165092: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:165126: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:165126: position]
# WARNING	Property: Unknown Property name. [5:165511: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165511: transform]
# WARNING	Property: Unknown Property name. [5:165572: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165572: transform]
# WARNING	Property: Unknown Property name. [5:165629: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165629: transform]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165674: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165674: border]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165801: border-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165801: border-top]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165940: border-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165940: border-right]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166086: border-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166086: border-bottom]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166236: border-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166236: border-left]
# WARNING	Property: Unknown Property name. [5:166383: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166383: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166423)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166423)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166443)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166443)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-primary-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-primary-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166499: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166499: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166539)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166539)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166561)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166561)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166615: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166615: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166655)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166655)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166675)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166675)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-success-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-success-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166726: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166726: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166766)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166766)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166783)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166783)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-info-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-info-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166837: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166837: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166877)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166877)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166897)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166897)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-warning-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-warning-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166950: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166950: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166990)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166990)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167009)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167009)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-danger-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-danger-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167061: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167061: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167101)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167101)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167119)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167119)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-light-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-light-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167170: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167170: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167210)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167210)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167227)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167227)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-dark-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-dark-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167279: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167279: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167319)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167319)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167337)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167337)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-black-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-black-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-black-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-black-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167389: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167389: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167429)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167429)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167447)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167447)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-white-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-white-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-white-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-white-rgb),var(--bs-border-opacity))!important
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-primary-border-subtle) [5:167508: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-primary-border-subtle) [5:167508: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-secondary-border-subtle) [5:167588: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-secondary-border-subtle) [5:167588: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-success-border-subtle) [5:167668: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-success-border-subtle) [5:167668: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-info-border-subtle) [5:167743: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-info-border-subtle) [5:167743: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-warning-border-subtle) [5:167818: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-warning-border-subtle) [5:167818: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-danger-border-subtle) [5:167895: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-danger-border-subtle) [5:167895: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-light-border-subtle) [5:167970: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-light-border-subtle) [5:167970: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-dark-border-subtle) [5:168043: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-dark-border-subtle) [5:168043: border-color]
# WARNING	Property: Unknown Property name. [5:168299: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168299: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168342: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168342: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168386: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168386: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168429: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168429: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168474: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168474: --bs-border-opacity]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168672: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168672: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168706: min-width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168706: min-width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168914: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168914: height]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168949: min-height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168949: min-height]
# WARNING	Property: Unknown Property name. [5:168987: flex]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168987: flex]
# WARNING	Property: Unknown Property name. [5:169021: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169021: flex-direction]
# WARNING	Property: Unknown Property name. [5:169063: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169063: flex-direction]
# WARNING	Property: Unknown Property name. [5:169113: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169113: flex-direction]
# WARNING	Property: Unknown Property name. [5:169171: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169171: flex-direction]
# WARNING	Property: Unknown Property name. [5:169224: flex-grow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169224: flex-grow]
# WARNING	Property: Unknown Property name. [5:169259: flex-grow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169259: flex-grow]
# WARNING	Property: Unknown Property name. [5:169296: flex-shrink]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169296: flex-shrink]
# WARNING	Property: Unknown Property name. [5:169335: flex-shrink]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169335: flex-shrink]
# WARNING	Property: Unknown Property name. [5:169370: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169370: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169408: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169408: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169454: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169454: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169510: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169510: justify-content]
# WARNING	Property: Unknown Property name. [5:169568: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169568: justify-content]
# WARNING	Property: Unknown Property name. [5:169627: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169627: justify-content]
# WARNING	Property: Unknown Property name. [5:169685: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169685: justify-content]
# WARNING	Property: Unknown Property name. [5:169749: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169749: justify-content]
# WARNING	Property: Unknown Property name. [5:169812: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169812: justify-content]
# WARNING	Property: Unknown Property name. [5:169870: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169870: align-items]
# WARNING	Property: Unknown Property name. [5:169920: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169920: align-items]
# WARNING	Property: Unknown Property name. [5:169971: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169971: align-items]
# WARNING	Property: Unknown Property name. [5:170022: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170022: align-items]
# WARNING	Property: Unknown Property name. [5:170074: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170074: align-items]
# WARNING	Property: Unknown Property name. [5:170125: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170125: align-content]
# WARNING	Property: Unknown Property name. [5:170179: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170179: align-content]
# WARNING	Property: Unknown Property name. [5:170234: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170234: align-content]
# WARNING	Property: Unknown Property name. [5:170288: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170288: align-content]
# WARNING	Property: Unknown Property name. [5:170348: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170348: align-content]
# WARNING	Property: Unknown Property name. [5:170408: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170408: align-content]
# WARNING	Property: Unknown Property name. [5:170457: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170457: align-self]
# WARNING	Property: Unknown Property name. [5:170501: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170501: align-self]
# WARNING	Property: Unknown Property name. [5:170549: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170549: align-self]
# WARNING	Property: Unknown Property name. [5:170598: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170598: align-self]
# WARNING	Property: Unknown Property name. [5:170647: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170647: align-self]
# WARNING	Property: Unknown Property name. [5:170697: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170697: align-self]
# WARNING	Property: Unknown Property name. [5:170739: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170739: order]
# WARNING	Property: Unknown Property name. [5:170767: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170767: order]
# WARNING	Property: Unknown Property name. [5:170794: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170794: order]
# WARNING	Property: Unknown Property name. [5:170821: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170821: order]
# WARNING	Property: Unknown Property name. [5:170848: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170848: order]
# WARNING	Property: Unknown Property name. [5:170875: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170875: order]
# WARNING	Property: Unknown Property name. [5:170902: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170902: order]
# WARNING	Property: Unknown Property name. [5:170932: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170932: order]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:170979: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:170979: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171008: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171008: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171036: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171036: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171063: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171063: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171092: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171092: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171205: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171205: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171235: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171235: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171270: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171270: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171299: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171299: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171333: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171333: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171361: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171361: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171394: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171394: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171424: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171424: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171459: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171459: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171487: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171487: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171639: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171639: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171667: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171667: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171704: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171704: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171731: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171731: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171767: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171767: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171793: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171793: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171828: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171828: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171856: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171856: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171893: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171893: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171919: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171919: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:172047: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:172047: margin-top]
# ...
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1895:3: font-family]
# WARNING	Property: Unknown Property name. [1902:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1902:3: transition]
# WARNING	Property: Unknown Property name. [1915:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1915:3: transition]
# WARNING	Property: Unknown Property name. [1924:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1924:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1955:5: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1955:5: height]
# WARNING	Property: Unknown Property name. [1966:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1966:3: transition]
# WARNING	Property: Unknown Property name. [1982:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1982:3: transition]
# WARNING	Property: Unknown Property name. [1989:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1989:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2013:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2013:3: display]
# WARNING	Property: Unknown Property name. [2021:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2021:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2026:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2026:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2028:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2028:3: display]
# WARNING	Property: Unknown Property name. [2029:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2029:3: align-items]
# WARNING	Property: Unknown Property name. [2030:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2030:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2035:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2035:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [2041:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [2041:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2075:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2075:3: color]
# WARNING	Property: Unknown Property name. [2076:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2076:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2080:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2080:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2120:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2120:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2143:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2143:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2158:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2158:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2169:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2169:3: display]
# WARNING	Property: Unknown Property name. [2170:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [2170:3: flex-wrap]
# WARNING	Property: Unknown Property name. [2172:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2172:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2185:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2185:3: color]
# WARNING	Property: Unknown Property name. [2207:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2207:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2211:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2211:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2238:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2238:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2267:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2267:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2299:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2299:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2318:3: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2318:3: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2335:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2335:3: background]
# WARNING	Property: Unknown Property name. [2337:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2337:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2360:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2360:3: color]
# WARNING	Property: Unknown Property name. [2361:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2361:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2365:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2365:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2390:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2390:3: color]
# WARNING	Property: Unknown Property name. [2391:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2391:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2395:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2395:3: color]
# WARNING	Property: Unknown Property name. [2426:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2426:3: transition]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 1px solid var(--color-primary) [2432:3: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 1px solid var(--color-primary) [2432:3: border]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2433:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2433:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2473:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2473:3: color]
# WARNING	Property: Unknown Property name. [2474:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2474:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2478:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2478:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2483:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2483:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2547:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2547:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2559:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2559:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2579:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2579:3: font-family]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2584:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2584:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2588:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2588:3: display]
# WARNING	Property: Unknown Property name. [2589:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2589:3: align-items]
# WARNING	Property: Unknown Property name. [2590:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2590:3: justify-content]
# WARNING	Property: Unknown Property name. [2598:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2598:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2632:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2632:3: display]
# WARNING	Property: Unknown Property name. [2633:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2633:3: align-items]
# WARNING	Property: Unknown Property name. [2642:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2642:3: transition]
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: 0.875rem
#   font-weight: 600
#   margin: calc(-0.5 * var(--bs-modal-header-padding-y)) calc(-0.5 * var(--bs-modal-header-padding-x)) calc(-0.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: 0.875rem
#   font-weight: 600
#   margin: calc(-0.5 * var(--bs-modal-header-padding-y)) calc(-0.5 * var(--bs-modal-header-padding-x)) calc(-0.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: var(--bs-font-monospace)
#   font-size: 0.875em
#   font-weight: 300
#   margin: 0
#   padding: 0.1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: #ddd
#   color: var(--color-primary)
#   font-size: 0
#   font-weight: 400
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: 0.875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: 0.25rem 0.5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + 0.9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: var(--bs-font-monospace)
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: 0.75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: 0.25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + 0.3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + 0.6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: 0.375rem 0.75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: 0.875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * 0.5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import urllib.parse
from typing import Optional
import requests
from bs4 import BeautifulSoup
import cssutils
from concurrent.futures import ThreadPoolExecutor

def extract_css_from_webpage(url: str, request_kwargs: Optional[dict] = None, verbose: bool = False):
    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    session = requests.Session()
    session.headers.update(request_kwargs["headers"])
    url_response = session.get(url, timeout=request_kwargs["timeout"])
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "lxml")

    css_urls = [urllib.parse.urljoin(url, link["href"]) for link in soup.find_all("link", rel="stylesheet")]
    if verbose:
        for css_url in css_urls:
            print(f"downloading external CSS stylesheet {css_url}")

    with ThreadPoolExecutor() as executor:
        css_from_external_stylesheets = list(executor.map(lambda css_url: session.get(css_url).text, css_urls))

    css_from_style_tags = [style_tag.string for style_tag in soup.find_all("style")]

    inline_css = [{"tag": str(tag), "css": tag["style"]} for tag in soup.find_all(style=True)]

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def extract_typography_properties(element, css_rules):
    properties = {
        'background-color': None,
        'color': None,
        'font-family': None,
        'font-size': None,
        'font-weight': None,
        'margin': None,
        'padding': None,
        'text-align': None,
        'justify-content': None,
        'align-items': None
    }
    for rule in css_rules:
        if not hasattr(rule, 'selectorText'):
            continue
        if element.name in rule.selectorText:
            for prop in properties.keys():
                if properties[prop] is None and rule.style.getPropertyValue(prop):
                    properties[prop] = rule.style.getPropertyValue(prop)
    return properties

def find_properties(url: str):
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_parser = cssutils.CSSParser()
    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        sheet = css_parser.parseString(css)
        css_rules.extend(sheet.cssRules)

    soup = BeautifulSoup(requests.get(url).content, "lxml")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties = find_properties(url)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING	Property: Unknown Property name. [5:159965: --bs-aspect-ratio]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:159965: --bs-aspect-ratio]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160136: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160136: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160160: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160160: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160210: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160210: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160234: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160234: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160312: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160312: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160336: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160336: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160389: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160389: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160413: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160413: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160492: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160492: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160516: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160516: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160569: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160569: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160593: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160593: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160672: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160672: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160696: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160696: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160749: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160749: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160773: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160773: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160853: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160853: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160877: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160877: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160930: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:160930: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:160954: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:160954: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161035: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161035: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:161059: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:161059: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161113: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:161113: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:161137: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:161137: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:161184: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:161184: display]
# WARNING	Property: Unknown Property name. [5:161197: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161197: flex-direction]
# WARNING	Property: Unknown Property name. [5:161216: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161216: align-items]
# WARNING	Property: Unknown Property name. [5:161235: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161235: align-self]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:161262: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:161262: display]
# WARNING	Property: Unknown Property name. [5:161275: flex]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161275: flex]
# WARNING	Property: Unknown Property name. [5:161289: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161289: flex-direction]
# WARNING	Property: Unknown Property name. [5:161311: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161311: align-self]
# WARNING	Property: Unknown Property name. [5:161843: text-overflow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161843: text-overflow]
# WARNING	Property: Unknown Property name. [5:161910: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:161910: align-self]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--bs-border-width) [5:161929: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--bs-border-width) [5:161929: width]
# WARNING	Property: Unknown Property name. [5:162423: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162423: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162455: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162455: object-fit]
# WARNING	Property: Unknown Property name. [5:162502: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162502: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162532: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162532: object-fit]
# WARNING	Property: Unknown Property name. [5:162576: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162576: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162605: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162605: object-fit]
# WARNING	Property: Unknown Property name. [5:162649: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162649: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162684: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162684: object-fit]
# WARNING	Property: Unknown Property name. [5:162733: -o-object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162733: -o-object-fit]
# WARNING	Property: Unknown Property name. [5:162762: object-fit]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:162762: object-fit]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: grid [5:163618: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: grid [5:163618: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: inline-grid [5:163656: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: inline-grid [5:163656: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [5:163811: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [5:163811: display]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: inline-flex [5:163849: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: inline-flex [5:163849: display]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow) [5:163918: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow) [5:163918: box-shadow]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-sm) [5:163971: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-sm) [5:163971: box-shadow]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-lg) [5:164027: box-shadow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-box-shadow-lg) [5:164027: box-shadow]
# WARNING	Property: Unknown Property name. [5:164131: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164131: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164158)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164158)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164178)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164178)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-primary-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164233: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164233: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164260)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164260)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164282)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164282)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-secondary-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164335: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164335: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164362)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164362)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164382)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164382)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-success-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164432: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164432: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164459)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164459)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164476)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164476)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-info-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164529: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164529: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164556)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164556)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164576)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164576)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-warning-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164628: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164628: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164655)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164655)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164674)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164674)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-danger-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164725: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164725: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164752)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164752)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164770)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164770)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-light-rgb), var(--bs-focus-ring-opacity))
# WARNING	Property: Unknown Property name. [5:164820: --bs-focus-ring-color]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:164820: --bs-focus-ring-color]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164847)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 164847)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 164864)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 164864)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: --bs-focus-ring-color:rgba(var(--bs-dark-rgb), var(--bs-focus-ring-opacity))
# ERROR	Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:165092: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: -webkit-sticky [5:165092: position]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: sticky [5:165126: position]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: sticky [5:165126: position]
# WARNING	Property: Unknown Property name. [5:165511: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165511: transform]
# WARNING	Property: Unknown Property name. [5:165572: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165572: transform]
# WARNING	Property: Unknown Property name. [5:165629: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:165629: transform]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165674: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165674: border]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165801: border-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165801: border-top]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165940: border-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:165940: border-right]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166086: border-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166086: border-bottom]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166236: border-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-border-width) var(--bs-border-style) var(--bs-border-color) [5:166236: border-left]
# WARNING	Property: Unknown Property name. [5:166383: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166383: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166423)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166423)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166443)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166443)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-primary-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-primary-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-primary-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166499: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166499: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166539)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166539)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166561)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166561)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-secondary-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166615: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166615: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166655)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166655)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166675)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166675)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-success-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-success-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-success-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166726: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166726: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166766)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166766)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166783)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166783)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-info-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-info-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-info-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166837: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166837: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166877)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166877)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 166897)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 166897)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-warning-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-warning-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-warning-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:166950: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:166950: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166990)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 166990)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167009)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167009)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-danger-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-danger-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-danger-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167061: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167061: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167101)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167101)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167119)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167119)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-light-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-light-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-light-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167170: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167170: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167210)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167210)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167227)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167227)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-dark-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-dark-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-dark-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167279: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167279: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167319)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167319)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167337)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167337)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-black-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-black-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-black-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-black-rgb),var(--bs-border-opacity))!important
# WARNING	Property: Unknown Property name. [5:167389: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:167389: --bs-border-opacity]
# ERROR	COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167429)
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production Sequence(comma, Choice(unary +-, number, percentage)): ('FUNCTION', 'var(', 5, 167429)
# ERROR	COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR:CSSUTILS:COLOR_VALUE: Missing token for production end FUNC ")"
# ERROR	PropertyValue: No match: ('CHAR', ')', 5, 167447)
# ERROR:CSSUTILS:PropertyValue: No match: ('CHAR', ')', 5, 167447)
# ERROR	PropertyValue: Unknown syntax or no value: rgba(var(--bs-white-rgb),var(--bs-border-opacity))
# ERROR:CSSUTILS:PropertyValue: Unknown syntax or no value: rgba(var(--bs-white-rgb),var(--bs-border-opacity))
# ERROR	CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-white-rgb),var(--bs-border-opacity))!important
# ERROR:CSSUTILS:CSSStyleDeclaration: Syntax Error in Property: border-color:rgba(var(--bs-white-rgb),var(--bs-border-opacity))!important
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-primary-border-subtle) [5:167508: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-primary-border-subtle) [5:167508: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-secondary-border-subtle) [5:167588: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-secondary-border-subtle) [5:167588: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-success-border-subtle) [5:167668: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-success-border-subtle) [5:167668: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-info-border-subtle) [5:167743: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-info-border-subtle) [5:167743: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-warning-border-subtle) [5:167818: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-warning-border-subtle) [5:167818: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-danger-border-subtle) [5:167895: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-danger-border-subtle) [5:167895: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-light-border-subtle) [5:167970: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-light-border-subtle) [5:167970: border-color]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-dark-border-subtle) [5:168043: border-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: var(--bs-dark-border-subtle) [5:168043: border-color]
# WARNING	Property: Unknown Property name. [5:168299: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168299: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168342: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168342: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168386: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168386: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168429: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168429: --bs-border-opacity]
# WARNING	Property: Unknown Property name. [5:168474: --bs-border-opacity]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168474: --bs-border-opacity]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168672: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168672: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168706: min-width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vw [5:168706: min-width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168914: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168914: height]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168949: min-height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 100vh [5:168949: min-height]
# WARNING	Property: Unknown Property name. [5:168987: flex]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:168987: flex]
# WARNING	Property: Unknown Property name. [5:169021: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169021: flex-direction]
# WARNING	Property: Unknown Property name. [5:169063: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169063: flex-direction]
# WARNING	Property: Unknown Property name. [5:169113: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169113: flex-direction]
# WARNING	Property: Unknown Property name. [5:169171: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169171: flex-direction]
# WARNING	Property: Unknown Property name. [5:169224: flex-grow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169224: flex-grow]
# WARNING	Property: Unknown Property name. [5:169259: flex-grow]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169259: flex-grow]
# WARNING	Property: Unknown Property name. [5:169296: flex-shrink]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169296: flex-shrink]
# WARNING	Property: Unknown Property name. [5:169335: flex-shrink]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169335: flex-shrink]
# WARNING	Property: Unknown Property name. [5:169370: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169370: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169408: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169408: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169454: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169454: flex-wrap]
# WARNING	Property: Unknown Property name. [5:169510: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169510: justify-content]
# WARNING	Property: Unknown Property name. [5:169568: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169568: justify-content]
# WARNING	Property: Unknown Property name. [5:169627: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169627: justify-content]
# WARNING	Property: Unknown Property name. [5:169685: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169685: justify-content]
# WARNING	Property: Unknown Property name. [5:169749: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169749: justify-content]
# WARNING	Property: Unknown Property name. [5:169812: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169812: justify-content]
# WARNING	Property: Unknown Property name. [5:169870: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169870: align-items]
# WARNING	Property: Unknown Property name. [5:169920: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169920: align-items]
# WARNING	Property: Unknown Property name. [5:169971: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:169971: align-items]
# WARNING	Property: Unknown Property name. [5:170022: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170022: align-items]
# WARNING	Property: Unknown Property name. [5:170074: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170074: align-items]
# WARNING	Property: Unknown Property name. [5:170125: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170125: align-content]
# WARNING	Property: Unknown Property name. [5:170179: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170179: align-content]
# WARNING	Property: Unknown Property name. [5:170234: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170234: align-content]
# WARNING	Property: Unknown Property name. [5:170288: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170288: align-content]
# WARNING	Property: Unknown Property name. [5:170348: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170348: align-content]
# WARNING	Property: Unknown Property name. [5:170408: align-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170408: align-content]
# WARNING	Property: Unknown Property name. [5:170457: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170457: align-self]
# WARNING	Property: Unknown Property name. [5:170501: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170501: align-self]
# WARNING	Property: Unknown Property name. [5:170549: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170549: align-self]
# WARNING	Property: Unknown Property name. [5:170598: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170598: align-self]
# WARNING	Property: Unknown Property name. [5:170647: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170647: align-self]
# WARNING	Property: Unknown Property name. [5:170697: align-self]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170697: align-self]
# WARNING	Property: Unknown Property name. [5:170739: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170739: order]
# WARNING	Property: Unknown Property name. [5:170767: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170767: order]
# WARNING	Property: Unknown Property name. [5:170794: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170794: order]
# WARNING	Property: Unknown Property name. [5:170821: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170821: order]
# WARNING	Property: Unknown Property name. [5:170848: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170848: order]
# WARNING	Property: Unknown Property name. [5:170875: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170875: order]
# WARNING	Property: Unknown Property name. [5:170902: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170902: order]
# WARNING	Property: Unknown Property name. [5:170932: order]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:170932: order]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:170979: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:170979: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171008: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171008: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171036: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171036: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171063: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171063: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171092: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171092: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171205: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171205: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171235: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171235: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171270: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171270: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171299: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171299: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171333: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171333: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171361: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171361: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171394: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171394: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171424: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171424: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171459: margin-right]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171459: margin-right]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171487: margin-left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171487: margin-left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171639: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171639: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171667: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:171667: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171704: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171704: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171731: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.5rem [5:171731: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171767: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171767: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171793: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1rem [5:171793: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171828: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171828: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171856: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 1.5rem [5:171856: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171893: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171893: margin-top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171919: margin-bottom]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 3rem [5:171919: margin-bottom]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:172047: margin-top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0.25rem [5:172047: margin-top]
# ...
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1895:3: font-family]
# WARNING	Property: Unknown Property name. [1902:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1902:3: transition]
# WARNING	Property: Unknown Property name. [1915:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1915:3: transition]
# WARNING	Property: Unknown Property name. [1924:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1924:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1955:5: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1955:5: height]
# WARNING	Property: Unknown Property name. [1966:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1966:3: transition]
# WARNING	Property: Unknown Property name. [1982:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1982:3: transition]
# WARNING	Property: Unknown Property name. [1989:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1989:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2013:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2013:3: display]
# WARNING	Property: Unknown Property name. [2021:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2021:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2026:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2026:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2028:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2028:3: display]
# WARNING	Property: Unknown Property name. [2029:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2029:3: align-items]
# WARNING	Property: Unknown Property name. [2030:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2030:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2035:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2035:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [2041:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [2041:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2075:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2075:3: color]
# WARNING	Property: Unknown Property name. [2076:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2076:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2080:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2080:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2120:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2120:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2143:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2143:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2158:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2158:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2169:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2169:3: display]
# WARNING	Property: Unknown Property name. [2170:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [2170:3: flex-wrap]
# WARNING	Property: Unknown Property name. [2172:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2172:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2185:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2185:3: color]
# WARNING	Property: Unknown Property name. [2207:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2207:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2211:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2211:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2238:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2238:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2267:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2267:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2299:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2299:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2318:3: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2318:3: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2335:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2335:3: background]
# WARNING	Property: Unknown Property name. [2337:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2337:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2360:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2360:3: color]
# WARNING	Property: Unknown Property name. [2361:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2361:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2365:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2365:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2390:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2390:3: color]
# WARNING	Property: Unknown Property name. [2391:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2391:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2395:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2395:3: color]
# WARNING	Property: Unknown Property name. [2426:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2426:3: transition]
# ERROR	Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 1px solid var(--color-primary) [2432:3: border]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Backgrounds and Borders Module Level 3" property: 1px solid var(--color-primary) [2432:3: border]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2433:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2433:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2473:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2473:3: color]
# WARNING	Property: Unknown Property name. [2474:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2474:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2478:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2478:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2483:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2483:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2547:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2547:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2559:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2559:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2579:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2579:3: font-family]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2584:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2584:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2588:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2588:3: display]
# WARNING	Property: Unknown Property name. [2589:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2589:3: align-items]
# WARNING	Property: Unknown Property name. [2590:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2590:3: justify-content]
# WARNING	Property: Unknown Property name. [2598:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2598:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2632:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2632:3: display]
# WARNING	Property: Unknown Property name. [2633:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2633:3: align-items]
# WARNING	Property: Unknown Property name. [2642:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2642:3: transition]
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: 0.875rem
#   font-weight: 600
#   margin: calc(-0.5 * var(--bs-modal-header-padding-y)) calc(-0.5 * var(--bs-modal-header-padding-x)) calc(-0.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: 0.875rem
#   font-weight: 600
#   margin: calc(-0.5 * var(--bs-modal-header-padding-y)) calc(-0.5 * var(--bs-modal-header-padding-x)) calc(-0.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: var(--bs-font-monospace)
#   font-size: 0.875em
#   font-weight: 300
#   margin: 0
#   padding: 0.1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: #ddd
#   color: var(--color-primary)
#   font-size: 0
#   font-weight: 400
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: 0.875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: 0.25rem 0.5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + 0.9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: var(--bs-font-monospace)
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: 0.75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: 0.25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + 0.3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + 0.6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: 0.375rem 0.75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: 0.875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * 0.5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import logging
import urllib.parse
from typing import Optional
import requests
from bs4 import BeautifulSoup
import cssutils
from concurrent.futures import ThreadPoolExecutor

# Set up logging to suppress cssutils warnings and errors
logging.getLogger('cssutils').setLevel(logging.CRITICAL)

def extract_css_from_webpage(url: str, request_kwargs: Optional[dict] = None, verbose: bool = False):
    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    session = requests.Session()
    session.headers.update(request_kwargs["headers"])
    url_response = session.get(url, timeout=request_kwargs["timeout"])
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "lxml")

    css_urls = [urllib.parse.urljoin(url, link["href"]) for link in soup.find_all("link", rel="stylesheet")]
    if verbose:
        for css_url in css_urls:
            print(f"downloading external CSS stylesheet {css_url}")

    with ThreadPoolExecutor() as executor:
        css_from_external_stylesheets = list(executor.map(lambda css_url: session.get(css_url).text, css_urls))

    css_from_style_tags = [style_tag.string for style_tag in soup.find_all("style")]

    inline_css = [{"tag": str(tag), "css": tag["style"]} for tag in soup.find_all(style=True)]

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def filter_css(css):
    filtered_css = []
    for line in css.splitlines():
        if not any(prop in line for prop in ['-ms-flex-order', 'order', '97vh', '-webkit-zoom-in', 'zoom-in']):
            filtered_css.append(line)
    return '\n'.join(filtered_css)

def extract_typography_properties(element, css_rules):
    properties = {
        'background-color': None,
        'color': None,
        'font-family': None,
        'font-size': None,
        'font-weight': None,
        'margin': None,
        'padding': None,
        'text-align': None,
        'justify-content': None,
        'align-items': None
    }
    for rule in css_rules:
        if not hasattr(rule, 'selectorText'):
            continue
        if element.name in rule.selectorText:
            for prop in properties.keys():
                if properties[prop] is None and rule.style.getPropertyValue(prop):
                    properties[prop] = rule.style.getPropertyValue(prop)
    return properties

def find_properties(url: str):
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_parser = cssutils.CSSParser()
    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        filtered_css = filter_css(css)
        sheet = css_parser.parseString(filtered_css)
        css_rules.extend(sheet.cssRules)

    soup = BeautifulSoup(requests.get(url).content, "lxml")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules)
        elements_properties[element.name] = properties
        # Debugging information
        print(f"Element: {element.name}, Properties: {properties}")

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties = find_properties(url)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# WARNING	Property: Unknown Property name. [5:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:3: font-display]
# WARNING	Property: Unknown Property name. [12:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [12:3: font-display]
# WARNING	Property: Unknown Property name. [19:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [19:3: font-display]
# WARNING	Property: Unknown Property name. [26:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [26:3: font-display]
# WARNING	Property: Unknown Property name. [33:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [33:3: font-display]
# WARNING	Property: Unknown Property name. [40:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [40:3: font-display]
# WARNING	Property: Unknown Property name. [47:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [47:3: font-display]
# WARNING	Property: Unknown Property name. [54:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [54:3: font-display]
# WARNING	Property: Unknown Property name. [61:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [61:3: font-display]
# WARNING	Property: Unknown Property name. [68:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [68:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [75:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [75:3: font-stretch]
# WARNING	Property: Unknown Property name. [76:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [76:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [83:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [83:3: font-stretch]
# WARNING	Property: Unknown Property name. [84:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [84:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [91:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [91:3: font-stretch]
# WARNING	Property: Unknown Property name. [92:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [92:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [99:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [99:3: font-stretch]
# WARNING	Property: Unknown Property name. [100:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [100:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [107:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [107:3: font-stretch]
# WARNING	Property: Unknown Property name. [108:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [108:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [115:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [115:3: font-stretch]
# WARNING	Property: Unknown Property name. [116:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [116:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [123:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [123:3: font-stretch]
# WARNING	Property: Unknown Property name. [124:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [124:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [131:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [131:3: font-stretch]
# WARNING	Property: Unknown Property name. [132:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [132:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [139:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [139:3: font-stretch]
# WARNING	Property: Unknown Property name. [140:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [140:3: font-display]
# WARNING	Property: Unknown Property name. [147:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [147:3: font-display]
# WARNING	Property: Unknown Property name. [154:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [154:3: font-display]
# WARNING	Property: Unknown Property name. [161:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [161:3: font-display]
# WARNING	Property: Unknown Property name. [168:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [168:3: font-display]
# WARNING	Property: Unknown Property name. [175:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [175:3: font-display]
# WARNING	Property: Unknown Property name. [182:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [182:3: font-display]
# WARNING	Property: Unknown Property name. [189:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [189:3: font-display]
# WARNING	Property: Unknown Property name. [196:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [196:3: font-display]
# WARNING	Property: Unknown Property name. [203:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [203:3: font-display]
# WARNING	Property: Unknown Property name. [210:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [210:3: font-display]
# WARNING	Property: Unknown Property name. [8:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [8:3: font-display]
# WARNING	Property: Unknown Property name. [25:3: -webkit-font-smoothing]
# WARNING:CSSUTILS:Property: Unknown Property name. [25:3: -webkit-font-smoothing]
# WARNING	Property: Unknown Property name. [26:3: -moz-osx-font-smoothing]
# WARNING:CSSUTILS:Property: Unknown Property name. [26:3: -moz-osx-font-smoothing]
# WARNING	Property: Unknown Property name. [15:3: --font-default]
# WARNING:CSSUTILS:Property: Unknown Property name. [15:3: --font-default]
# WARNING	Property: Unknown Property name. [16:3: --font-primary]
# WARNING:CSSUTILS:Property: Unknown Property name. [16:3: --font-primary]
# WARNING	Property: Unknown Property name. [17:3: --font-secondary]
# WARNING:CSSUTILS:Property: Unknown Property name. [17:3: --font-secondary]
# WARNING	Property: Unknown Property name. [22:3: --color-default]
# WARNING:CSSUTILS:Property: Unknown Property name. [22:3: --color-default]
# WARNING	Property: Unknown Property name. [23:3: --color-primary]
# WARNING:CSSUTILS:Property: Unknown Property name. [23:3: --color-primary]
# WARNING	Property: Unknown Property name. [24:3: --color-secondary]
# WARNING:CSSUTILS:Property: Unknown Property name. [24:3: --color-secondary]
# WARNING	Property: Unknown Property name. [29:3: scroll-behavior]
# WARNING:CSSUTILS:Property: Unknown Property name. [29:3: scroll-behavior]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-default) [36:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-default) [36:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [37:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [37:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [41:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [41:3: color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [56:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [56:3: font-family]
# WARNING	Property: Unknown Property name. [65:3: scroll-margin-top]
# WARNING:CSSUTILS:Property: Unknown Property name. [65:3: scroll-margin-top]
# ERROR	Property: Invalid value for "CSS Box Module Level 3/CSS Level 2.1" property: clip [66:3: overflow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Box Module Level 3/CSS Level 2.1" property: clip [66:3: overflow]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [92:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [92:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 20vh [109:3: min-height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 20vh [109:3: min-height]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [111:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [111:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [118:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [118:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [131:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [131:3: display]
# WARNING	Property: Unknown Property name. [132:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [132:3: flex-wrap]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [138:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [138:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [142:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [142:3: color]
# WARNING	Property: Unknown Property name. [143:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [143:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [157:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [157:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [171:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [171:3: background]
# WARNING	Property: Unknown Property name. [174:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [174:3: transition]
# WARNING	Property: Unknown Property name. [199:3: inset]
# WARNING:CSSUTILS:Property: Unknown Property name. [199:3: inset]
# WARNING	Property: Unknown Property name. [203:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [203:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [209:3: top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [209:3: top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [210:3: left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [210:3: left]
# WARNING	Property: Unknown Property name. [213:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [213:3: animation]
# WARNING	CSSStylesheet: Unknown @rule found. [216:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [216:1: @keyframes]
# WARNING	Property: Unknown Property name. [231:5: transition-delay]
# WARNING:CSSUTILS:Property: Unknown Property name. [231:5: transition-delay]
# WARNING	Property: Unknown Property name. [242:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [242:3: transition]
# WARNING	Property: Unknown Property name. [269:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [269:3: transition]
# WARNING	Property: Unknown Property name. [280:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [280:3: transition]
# WARNING	Property: Unknown Property name. [289:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [289:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [292:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [292:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [315:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [315:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [337:5: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [337:5: display]
# WARNING	Property: Unknown Property name. [339:5: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [339:5: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [353:5: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [353:5: display]
# WARNING	Property: Unknown Property name. [354:5: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [354:5: align-items]
# WARNING	Property: Unknown Property name. [355:5: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [355:5: justify-content]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [357:5: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [357:5: font-family]
# WARNING	Property: Unknown Property name. [362:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [362:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [380:5: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [380:5: background-color]
# WARNING	Property: Unknown Property name. [383:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [383:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% + 30px) [404:5: top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% + 30px) [404:5: top]
# WARNING	Property: Unknown Property name. [412:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [412:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [434:5: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [434:5: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 30px) [445:5: left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 30px) [445:5: left]
# WARNING	Property: Unknown Property name. [486:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [486:5: transition]
# WARNING	Property: Unknown Property name. [492:5: inset]
# WARNING:CSSUTILS:Property: Unknown Property name. [492:5: inset]
# WARNING	Property: Unknown Property name. [497:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [497:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [503:5: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [503:5: display]
# WARNING	Property: Unknown Property name. [504:5: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [504:5: align-items]
# WARNING	Property: Unknown Property name. [505:5: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [505:5: justify-content]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [507:5: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [507:5: font-family]
# WARNING	Property: Unknown Property name. [512:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [512:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [531:5: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [531:5: background]
# WARNING	Property: Unknown Property name. [549:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [549:5: transition]
# WARNING	Property: Unknown Property name. [563:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [563:5: transition]
# WARNING	Property: Unknown Property name. [573:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [573:5: transition]
# WARNING	Property: Unknown Property name. [591:5: inset]
# WARNING:CSSUTILS:Property: Unknown Property name. [591:5: inset]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [604:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [604:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [626:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [626:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [644:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [644:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [654:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [654:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [657:3: left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [657:3: left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [658:3: top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [658:3: top]
# WARNING	Property: Unknown Property name. [667:3: animation-delay]
# WARNING:CSSUTILS:Property: Unknown Property name. [667:3: animation-delay]
# WARNING	Property: Unknown Property name. [668:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [668:3: animation]
# WARNING	Property: Unknown Property name. [669:3: animation-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [669:3: animation-direction]
# WARNING	Property: Unknown Property name. [670:3: animation-iteration-count]
# WARNING:CSSUTILS:Property: Unknown Property name. [670:3: animation-iteration-count]
# WARNING	Property: Unknown Property name. [671:3: animation-timing-function]
# WARNING:CSSUTILS:Property: Unknown Property name. [671:3: animation-timing-function]
# WARNING	Property: Unknown Property name. [683:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [683:3: transform]
# WARNING	Property: Unknown Property name. [687:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [687:3: transition]
# WARNING	Property: Unknown Property name. [695:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [695:3: transform]
# WARNING	Property: Unknown Property name. [699:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [699:3: animation]
# WARNING	Property: Unknown Property name. [703:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [703:3: transform]
# WARNING	CSSStylesheet: Unknown @rule found. [706:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [706:1: @keyframes]
# WARNING	Property: Unknown Property name. [730:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [730:3: transition]
# WARNING	Property: Unknown Property name. [734:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [734:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [751:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [751:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [780:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [780:3: color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [786:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [786:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: linear-gradient(rgba(0, 0, 0, 0.5), rgba(0, 0, 0, 0.5)), url(../img/cta-bg.jpg) center center [794:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: linear-gradient(rgba(0, 0, 0, 0.5), rgba(0, 0, 0, 0.5)), url(../img/cta-bg.jpg) center center [794:3: background]
# WARNING	Property: Unknown Property name. [795:3: background-size]
# WARNING:CSSUTILS:Property: Unknown Property name. [795:3: background-size]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [816:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [816:3: background]
# WARNING	Property: Unknown Property name. [827:3: animation-delay]
# WARNING:CSSUTILS:Property: Unknown Property name. [827:3: animation-delay]
# WARNING	Property: Unknown Property name. [828:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [828:3: animation]
# WARNING	Property: Unknown Property name. [829:3: animation-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [829:3: animation-direction]
# WARNING	Property: Unknown Property name. [830:3: animation-iteration-count]
# WARNING:CSSUTILS:Property: Unknown Property name. [830:3: animation-iteration-count]
# WARNING	Property: Unknown Property name. [831:3: animation-timing-function]
# WARNING:CSSUTILS:Property: Unknown Property name. [831:3: animation-timing-function]
# WARNING	Property: Unknown Property name. [843:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [843:3: transform]
# WARNING	Property: Unknown Property name. [847:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [847:3: transition]
# WARNING	Property: Unknown Property name. [855:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [855:3: transform]
# WARNING	Property: Unknown Property name. [859:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [859:3: animation]
# WARNING	Property: Unknown Property name. [863:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [863:3: transform]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [867:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [867:3: font-family]
# WARNING	Property: Unknown Property name. [873:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [873:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [879:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [879:3: background]
# WARNING	CSSStylesheet: Unknown @rule found. [882:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [882:1: @keyframes]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [915:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [915:3: color]
# WARNING	Property: Unknown Property name. [917:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [917:3: transition]
# WARNING	Property: Unknown Property name. [931:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [931:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [935:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [935:3: color]
# WARNING	Property: Unknown Property name. [942:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [942:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [954:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [954:3: color]
# WARNING	Property: Unknown Property name. [1025:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1025:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1046:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1046:3: background-color]
# WARNING	Property: Unknown Property name. [1083:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1083:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1088:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1088:3: color]
# WARNING	Property: Unknown Property name. [1113:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1113:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1132:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1132:3: color]
# WARNING	Property: Unknown Property name. [1133:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1133:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1137:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1137:3: color]
# WARNING	Property: Unknown Property name. [1148:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1148:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1166:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1166:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1182:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1182:3: display]
# WARNING	Property: Unknown Property name. [1183:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1183:3: align-items]
# WARNING	Property: Unknown Property name. [1184:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1184:3: justify-content]
# WARNING	Property: Unknown Property name. [1185:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1185:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1215:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1215:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1227:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1227:3: display]
# WARNING	Property: Unknown Property name. [1228:3: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [1228:3: flex-direction]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1242:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1242:3: background]
# WARNING	Property: Unknown Property name. [1244:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1244:3: transition]
# WARNING	Property: Unknown Property name. [1306:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1306:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0 0 15px 0 0 0 [1311:3: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0 0 15px 0 0 0 [1311:3: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1358:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1358:3: display]
# WARNING	Property: Unknown Property name. [1359:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1359:3: align-items]
# WARNING	Property: Unknown Property name. [1360:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1360:3: justify-content]
# WARNING	Property: Unknown Property name. [1365:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1365:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1368:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1368:3: display]
# WARNING	Property: Unknown Property name. [1369:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1369:3: align-items]
# WARNING	Property: Unknown Property name. [1370:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1370:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1374:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1374:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1405:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1405:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1406:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1406:3: display]
# WARNING	Property: Unknown Property name. [1407:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1407:3: align-items]
# WARNING	Property: Unknown Property name. [1408:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1408:3: justify-content]
# WARNING	Property: Unknown Property name. [1409:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1409:3: transition]
# WARNING	Property: Unknown Property name. [1410:3: transform-style]
# WARNING:CSSUTILS:Property: Unknown Property name. [1410:3: transform-style]
# WARNING	Property: Unknown Property name. [1416:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1416:3: transition]
# WARNING	Property: Unknown Property name. [1426:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1426:3: transition]
# WARNING	Property: Unknown Property name. [1427:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1427:3: transform]
# WARNING	Property: Unknown Property name. [1436:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1436:3: transition]
# WARNING	Property: Unknown Property name. [1437:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1437:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [1442:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [1442:3: color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [1444:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [1444:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1469:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1469:3: display]
# WARNING	Property: Unknown Property name. [1470:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1470:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1494:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1494:3: color]
# WARNING	Property: Unknown Property name. [1495:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1495:3: transition]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1498:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1498:3: font-family]
# WARNING	Property: Unknown Property name. [1499:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1499:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1503:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1503:3: background]
# WARNING	Property: Unknown Property name. [1513:5: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1513:5: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1553:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1553:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1563:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1563:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1567:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1567:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1614:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1614:3: color]
# WARNING	Property: Unknown Property name. [1615:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1615:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1619:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1619:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1642:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1642:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1667:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1667:3: display]
# WARNING	Property: Unknown Property name. [1668:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1668:3: justify-content]
# WARNING	Property: Unknown Property name. [1669:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1669:3: align-items]
# WARNING	Property: Unknown Property name. [1670:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1670:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1689:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1689:3: color]
# WARNING	Property: Unknown Property name. [1739:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [1739:3: animation]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1764:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1764:3: background]
# WARNING	Property: Unknown Property name. [1767:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1767:3: transition]
# WARNING	CSSStylesheet: Unknown @rule found. [1774:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [1774:1: @keyframes]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1790:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1790:3: background]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1814:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1814:3: font-family]
# WARNING	Property: Unknown Property name. [1820:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1820:3: transition]
# WARNING	Property: Unknown Property name. [1831:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1831:3: transition]
# WARNING	Property: Unknown Property name. [1840:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1840:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1871:5: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1871:5: height]
# WARNING	Property: Unknown Property name. [1882:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1882:3: transition]
# WARNING	Property: Unknown Property name. [1897:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1897:3: transition]
# WARNING	Property: Unknown Property name. [1904:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1904:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1928:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1928:3: display]
# WARNING	Property: Unknown Property name. [1936:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1936:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1940:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1940:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1942:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1942:3: display]
# WARNING	Property: Unknown Property name. [1943:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1943:3: align-items]
# WARNING	Property: Unknown Property name. [1944:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1944:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1949:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1949:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [1955:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [1955:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1988:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1988:3: color]
# WARNING	Property: Unknown Property name. [1989:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1989:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1993:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1993:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2030:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2030:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2053:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2053:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2068:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2068:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2079:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2079:3: display]
# WARNING	Property: Unknown Property name. [2080:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [2080:3: flex-wrap]
# WARNING	Property: Unknown Property name. [2082:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2082:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2095:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2095:3: color]
# WARNING	Property: Unknown Property name. [2116:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2116:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2120:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2120:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2147:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2147:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2175:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2175:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2206:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2206:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2221:3: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2221:3: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2237:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2237:3: background]
# WARNING	Property: Unknown Property name. [2239:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2239:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2261:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2261:3: color]
# WARNING	Property: Unknown Property name. [2262:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2262:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2266:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2266:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2291:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2291:3: color]
# WARNING	Property: Unknown Property name. [2292:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2292:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2296:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2296:3: color]
# WARNING	Property: Unknown Property name. [2326:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2326:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2331:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2331:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2371:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2371:3: color]
# WARNING	Property: Unknown Property name. [2372:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2372:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2376:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2376:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2381:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2381:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2438:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2438:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2450:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2450:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2470:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2470:3: font-family]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2475:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2475:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2479:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2479:3: display]
# WARNING	Property: Unknown Property name. [2480:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2480:3: align-items]
# WARNING	Property: Unknown Property name. [2481:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2481:3: justify-content]
# WARNING	Property: Unknown Property name. [2487:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2487:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2520:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2520:3: display]
# WARNING	Property: Unknown Property name. [2521:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2521:3: align-items]
# WARNING	Property: Unknown Property name. [2530:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2530:3: transition]
# ...
# Element: span, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '40px', 'font-weight': '700', 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: h3, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '28px', 'font-weight': '700', 'margin': '0 0 20px 0', 'padding': None, 'text-align': 'center', 'justify-content': None, 'align-items': None}
# Element: button, Properties: {'background-color': 'rgba(0, 0, 0, 0.2)', 'color': 'rgba(255, 255, 255, 0.8)', 'font-family': None, 'font-size': '24px', 'font-weight': '600', 'margin': '-1px', 'padding': '20px 50px 20px 20px', 'text-align': 'left', 'justify-content': 'center', 'align-items': 'center'}
# Element: span, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '40px', 'font-weight': '700', 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: h3, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '28px', 'font-weight': '700', 'margin': '0 0 20px 0', 'padding': None, 'text-align': 'center', 'justify-content': None, 'align-items': None}
# Element: button, Properties: {'background-color': 'rgba(0, 0, 0, 0.2)', 'color': 'rgba(255, 255, 255, 0.8)', 'font-family': None, 'font-size': '24px', 'font-weight': '600', 'margin': '-1px', 'padding': '20px 50px 20px 20px', 'text-align': 'left', 'justify-content': 'center', 'align-items': 'center'}
# Element: span, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '40px', 'font-weight': '700', 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: a, Properties: {'background-color': 'var(--color-primary)', 'color': 'var(--color-primary)', 'font-family': 'bootstrap-icons', 'font-size': '32px', 'font-weight': 'normal', 'margin': 'auto', 'padding': '60px 0 60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: footer, Properties: {'background-color': 'var(--color-primary)', 'color': 'white', 'font-family': 'var(--font-primary)', 'font-size': '14px', 'font-weight': '700', 'margin': '0', 'padding': '50px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: a, Properties: {'background-color': 'var(--color-primary)', 'color': 'var(--color-primary)', 'font-family': 'bootstrap-icons', 'font-size': '32px', 'font-weight': 'normal', 'margin': 'auto', 'padding': '60px 0 60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: span, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '40px', 'font-weight': '700', 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: p, Properties: {'background-color': 'var(--color-primary)', 'color': '#6f6f6f', 'font-family': 'var(--font-secondary)', 'font-size': '56px', 'font-weight': '500', 'margin': '0', 'padding': '60px 0 60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: br, Properties: {'background-color': 'var(--color-primary)', 'color': '#fff', 'font-family': 'var(--font-secondary)', 'font-size': '56px', 'font-weight': '500', 'margin': '0', 'padding': '60px 0 60px 0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: ul, Properties: {'background-color': '#ddd', 'color': 'var(--color-primary)', 'font-family': None, 'font-size': '20px', 'font-weight': '400', 'margin': '0', 'padding': '0', 'text-align': 'left', 'justify-content': None, 'align-items': 'center'}
# Element: li, Properties: {'background-color': '#ddd', 'color': 'var(--color-secondary)', 'font-family': None, 'font-size': '18px', 'font-weight': '500', 'margin': '0 auto', 'padding': '0 0 10px 30px', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: br, Properties: {'background-color': 'var(--color-primary)', 'color': '#fff', 'font-family': 'var(--font-secondary)', 'font-size': '56px', 'font-weight': '500', 'margin': '0', 'padding': '60px 0 60px 0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: li, Properties: {'background-color': '#ddd', 'color': 'var(--color-secondary)', 'font-family': None, 'font-size': '18px', 'font-weight': '500', 'margin': '0 auto', 'padding': '0 0 10px 30px', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: a, Properties: {'background-color': 'var(--color-primary)', 'color': 'var(--color-primary)', 'font-family': 'bootstrap-icons', 'font-size': '32px', 'font-weight': 'normal', 'margin': 'auto', 'padding': '60px 0 60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: strong, Properties: {'background-color': None, 'color': '#9c9c9c', 'font-family': None, 'font-size': '12px', 'font-weight': '400', 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: span, Properties: {'background-color': None, 'color': '#fff', 'font-family': 'var(--font-primary)', 'font-size': '40px', 'font-weight': '700', 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: a, Properties: {'background-color': 'var(--color-primary)', 'color': 'var(--color-primary)', 'font-family': 'bootstrap-icons', 'font-size': '32px', 'font-weight': 'normal', 'margin': 'auto', 'padding': '60px 0 60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: a, Properties: {'background-color': 'var(--color-primary)', 'color': 'var(--color-primary)', 'font-family': 'bootstrap-icons', 'font-size': '32px', 'font-weight': 'normal', 'margin': 'auto', 'padding': '60px 0 60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: i, Properties: {'background-color': '#f6f6f6', 'color': '#6f6f6f', 'font-family': 'bootstrap-icons', 'font-size': '32px', 'font-weight': 'normal', 'margin': 'auto', 'padding': '60px 0', 'text-align': 'center', 'justify-content': 'center', 'align-items': 'center'}
# Element: div, Properties: {'background-color': None, 'color': None, 'font-family': None, 'font-size': None, 'font-weight': None, 'margin': None, 'padding': None, 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: script, Properties: {'background-color': None, 'color': '#6c757d', 'font-family': None, 'font-size': '26px', 'font-weight': '700', 'margin': '0 10px 0 0', 'padding': '0', 'text-align': None, 'justify-content': None, 'align-items': None}
# Element: html
# Element: head
#   background-color: var(--color-primary)
#   color: #6f6f6f
#   font-family: var(--font-secondary)
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0 60px 0
#   text-align: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--color-default)
#   font-size: 22px
#   font-weight: 700
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   color: rgba(255, 255, 255, 0.7)
#   font-size: 16px
#   margin: 0 10px 10px 0
#   padding: 0
#   justify-content: center
#   align-items: center
# Element: body
#   color: var(--color-default)
#   font-family: var(--font-default)
#   padding: 0 40px 30px 45px
# Element: header
#   background-color: var(--color-primary)
#   color: #6f6f6f
#   font-family: var(--font-secondary)
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0 60px 0
#   text-align: center
# Element: div
# Element: a
#   background-color: var(--color-primary)
#   color: var(--color-primary)
#   font-family: bootstrap-icons
#   font-size: 32px
#   font-weight: normal
#   margin: auto
#   padding: 60px 0 60px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: h1
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 30px
#   font-weight: 600
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: #f6f6f6
#   color: var(--color-default)
#   font-size: 16px
#   font-weight: 600
#   margin: 0
#   padding: 20px 0
# Element: ul
#   background-color: #ddd
#   color: var(--color-primary)
#   font-size: 20px
#   font-weight: 400
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #ddd
#   color: var(--color-secondary)
#   font-size: 18px
#   font-weight: 500
#   margin: 0 auto
#   padding: 0 0 10px 30px
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-family: bootstrap-icons
#   font-size: 32px
#   font-weight: normal
#   margin: auto
#   padding: 60px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 32px
#   font-weight: 600
#   margin: auto
# Element: font
# Element: p
#   background-color: var(--color-primary)
#   color: #6f6f6f
#   font-family: var(--font-secondary)
#   font-size: 56px
#   font-weight: 500
#   margin: 0
#   padding: 60px 0 60px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: br
#   background-color: var(--color-primary)
#   color: #fff
#   font-family: var(--font-secondary)
#   font-size: 56px
#   font-weight: 500
#   margin: 0
#   padding: 60px 0 60px 0
# Element: img
#   margin: 0 10px 0 0
# Element: h4
#   color: #999
#   font-family: var(--font-primary)
#   font-size: 24px
#   font-weight: 700
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
# Element: h3
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 28px
#   font-weight: 700
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: 400
# Element: button
#   background-color: rgba(0, 0, 0, 0.2)
#   color: rgba(255, 255, 255, 0.8)
#   font-size: 24px
#   font-weight: 600
#   margin: -1px
#   padding: 20px 50px 20px 20px
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--color-primary)
#   color: white
#   font-family: var(--font-primary)
#   font-size: 14px
#   font-weight: 700
#   margin: 0
#   padding: 50px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 10px 0 0
#   padding: 0

# %%
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup
import cssutils
from concurrent.futures import ThreadPoolExecutor

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def filter_css(css: str) -> str:
    filtered_css = []
    for line in css.splitlines():
        if not any(prop in line for prop in ['-ms-flex-order', 'order', '97vh', '-webkit-zoom-in', 'zoom-in']):
            filtered_css.append(line)
    return '\n'.join(filtered_css)

def extract_typography_properties(element, css_rules) -> Dict[str, Optional[str]]:
    properties = {
        'background-color': None,
        'color': None,
        'font-family': None,
        'font-size': None,
        'font-weight': None,
        'margin': None,
        'padding': None,
        'text-align': None,
        'justify-content': None,
        'align-items': None
    }
    for rule in css_rules:
        if not hasattr(rule, 'selectorText'):
            continue
        if element.name in rule.selectorText:
            for prop in properties.keys():
                if properties[prop] is None and rule.style.getPropertyValue(prop):
                    properties[prop] = rule.style.getPropertyValue(prop)
    return properties

def find_properties(url: str) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_parser = cssutils.CSSParser()
    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        filtered_css = filter_css(css)
        sheet = css_parser.parseString(filtered_css)
        css_rules.extend(sheet.cssRules)

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties = find_properties(url)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# WARNING	Property: Unknown Property name. [5:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [5:3: font-display]
# WARNING	Property: Unknown Property name. [12:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [12:3: font-display]
# WARNING	Property: Unknown Property name. [19:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [19:3: font-display]
# WARNING	Property: Unknown Property name. [26:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [26:3: font-display]
# WARNING	Property: Unknown Property name. [33:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [33:3: font-display]
# WARNING	Property: Unknown Property name. [40:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [40:3: font-display]
# WARNING	Property: Unknown Property name. [47:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [47:3: font-display]
# WARNING	Property: Unknown Property name. [54:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [54:3: font-display]
# WARNING	Property: Unknown Property name. [61:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [61:3: font-display]
# WARNING	Property: Unknown Property name. [68:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [68:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [75:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [75:3: font-stretch]
# WARNING	Property: Unknown Property name. [76:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [76:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [83:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [83:3: font-stretch]
# WARNING	Property: Unknown Property name. [84:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [84:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [91:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [91:3: font-stretch]
# WARNING	Property: Unknown Property name. [92:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [92:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [99:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [99:3: font-stretch]
# WARNING	Property: Unknown Property name. [100:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [100:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [107:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [107:3: font-stretch]
# WARNING	Property: Unknown Property name. [108:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [108:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [115:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [115:3: font-stretch]
# WARNING	Property: Unknown Property name. [116:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [116:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [123:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [123:3: font-stretch]
# WARNING	Property: Unknown Property name. [124:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [124:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [131:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [131:3: font-stretch]
# WARNING	Property: Unknown Property name. [132:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [132:3: font-display]
# WARNING	Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [139:3: font-stretch]
# WARNING:CSSUTILS:Property: Not valid for profile "['CSS Fonts Module Level 3 @font-face properties']" but valid "CSS Fonts Module Level 3" value: normal  [139:3: font-stretch]
# WARNING	Property: Unknown Property name. [140:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [140:3: font-display]
# WARNING	Property: Unknown Property name. [147:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [147:3: font-display]
# WARNING	Property: Unknown Property name. [154:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [154:3: font-display]
# WARNING	Property: Unknown Property name. [161:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [161:3: font-display]
# WARNING	Property: Unknown Property name. [168:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [168:3: font-display]
# WARNING	Property: Unknown Property name. [175:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [175:3: font-display]
# WARNING	Property: Unknown Property name. [182:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [182:3: font-display]
# WARNING	Property: Unknown Property name. [189:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [189:3: font-display]
# WARNING	Property: Unknown Property name. [196:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [196:3: font-display]
# WARNING	Property: Unknown Property name. [203:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [203:3: font-display]
# WARNING	Property: Unknown Property name. [210:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [210:3: font-display]
# WARNING	Property: Unknown Property name. [8:3: font-display]
# WARNING:CSSUTILS:Property: Unknown Property name. [8:3: font-display]
# WARNING	Property: Unknown Property name. [25:3: -webkit-font-smoothing]
# WARNING:CSSUTILS:Property: Unknown Property name. [25:3: -webkit-font-smoothing]
# WARNING	Property: Unknown Property name. [26:3: -moz-osx-font-smoothing]
# WARNING:CSSUTILS:Property: Unknown Property name. [26:3: -moz-osx-font-smoothing]
# WARNING	Property: Unknown Property name. [15:3: --font-default]
# WARNING:CSSUTILS:Property: Unknown Property name. [15:3: --font-default]
# WARNING	Property: Unknown Property name. [16:3: --font-primary]
# WARNING:CSSUTILS:Property: Unknown Property name. [16:3: --font-primary]
# WARNING	Property: Unknown Property name. [17:3: --font-secondary]
# WARNING:CSSUTILS:Property: Unknown Property name. [17:3: --font-secondary]
# WARNING	Property: Unknown Property name. [22:3: --color-default]
# WARNING:CSSUTILS:Property: Unknown Property name. [22:3: --color-default]
# WARNING	Property: Unknown Property name. [23:3: --color-primary]
# WARNING:CSSUTILS:Property: Unknown Property name. [23:3: --color-primary]
# WARNING	Property: Unknown Property name. [24:3: --color-secondary]
# WARNING:CSSUTILS:Property: Unknown Property name. [24:3: --color-secondary]
# WARNING	Property: Unknown Property name. [29:3: scroll-behavior]
# WARNING:CSSUTILS:Property: Unknown Property name. [29:3: scroll-behavior]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-default) [36:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-default) [36:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [37:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [37:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [41:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [41:3: color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [56:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [56:3: font-family]
# WARNING	Property: Unknown Property name. [65:3: scroll-margin-top]
# WARNING:CSSUTILS:Property: Unknown Property name. [65:3: scroll-margin-top]
# ERROR	Property: Invalid value for "CSS Box Module Level 3/CSS Level 2.1" property: clip [66:3: overflow]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Box Module Level 3/CSS Level 2.1" property: clip [66:3: overflow]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [92:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [92:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 20vh [109:3: min-height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 20vh [109:3: min-height]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [111:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [111:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [118:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [118:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [131:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [131:3: display]
# WARNING	Property: Unknown Property name. [132:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [132:3: flex-wrap]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [138:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [138:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [142:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [142:3: color]
# WARNING	Property: Unknown Property name. [143:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [143:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [157:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [157:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [171:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [171:3: background]
# WARNING	Property: Unknown Property name. [174:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [174:3: transition]
# WARNING	Property: Unknown Property name. [199:3: inset]
# WARNING:CSSUTILS:Property: Unknown Property name. [199:3: inset]
# WARNING	Property: Unknown Property name. [203:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [203:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [209:3: top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [209:3: top]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [210:3: left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 30px) [210:3: left]
# WARNING	Property: Unknown Property name. [213:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [213:3: animation]
# WARNING	CSSStylesheet: Unknown @rule found. [216:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [216:1: @keyframes]
# WARNING	Property: Unknown Property name. [231:5: transition-delay]
# WARNING:CSSUTILS:Property: Unknown Property name. [231:5: transition-delay]
# WARNING	Property: Unknown Property name. [242:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [242:3: transition]
# WARNING	Property: Unknown Property name. [269:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [269:3: transition]
# WARNING	Property: Unknown Property name. [280:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [280:3: transition]
# WARNING	Property: Unknown Property name. [289:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [289:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [292:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [292:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [315:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [315:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [337:5: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [337:5: display]
# WARNING	Property: Unknown Property name. [339:5: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [339:5: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [353:5: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [353:5: display]
# WARNING	Property: Unknown Property name. [354:5: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [354:5: align-items]
# WARNING	Property: Unknown Property name. [355:5: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [355:5: justify-content]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [357:5: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [357:5: font-family]
# WARNING	Property: Unknown Property name. [362:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [362:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [380:5: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [380:5: background-color]
# WARNING	Property: Unknown Property name. [383:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [383:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% + 30px) [404:5: top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% + 30px) [404:5: top]
# WARNING	Property: Unknown Property name. [412:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [412:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [434:5: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [434:5: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 30px) [445:5: left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 30px) [445:5: left]
# WARNING	Property: Unknown Property name. [486:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [486:5: transition]
# WARNING	Property: Unknown Property name. [492:5: inset]
# WARNING:CSSUTILS:Property: Unknown Property name. [492:5: inset]
# WARNING	Property: Unknown Property name. [497:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [497:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [503:5: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [503:5: display]
# WARNING	Property: Unknown Property name. [504:5: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [504:5: align-items]
# WARNING	Property: Unknown Property name. [505:5: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [505:5: justify-content]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [507:5: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [507:5: font-family]
# WARNING	Property: Unknown Property name. [512:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [512:5: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [531:5: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [531:5: background]
# WARNING	Property: Unknown Property name. [549:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [549:5: transition]
# WARNING	Property: Unknown Property name. [563:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [563:5: transition]
# WARNING	Property: Unknown Property name. [573:5: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [573:5: transition]
# WARNING	Property: Unknown Property name. [591:5: inset]
# WARNING:CSSUTILS:Property: Unknown Property name. [591:5: inset]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [604:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [604:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [626:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [626:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [644:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [644:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [654:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [654:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [657:3: left]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [657:3: left]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [658:3: top]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% - 47px) [658:3: top]
# WARNING	Property: Unknown Property name. [667:3: animation-delay]
# WARNING:CSSUTILS:Property: Unknown Property name. [667:3: animation-delay]
# WARNING	Property: Unknown Property name. [668:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [668:3: animation]
# WARNING	Property: Unknown Property name. [669:3: animation-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [669:3: animation-direction]
# WARNING	Property: Unknown Property name. [670:3: animation-iteration-count]
# WARNING:CSSUTILS:Property: Unknown Property name. [670:3: animation-iteration-count]
# WARNING	Property: Unknown Property name. [671:3: animation-timing-function]
# WARNING:CSSUTILS:Property: Unknown Property name. [671:3: animation-timing-function]
# WARNING	Property: Unknown Property name. [683:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [683:3: transform]
# WARNING	Property: Unknown Property name. [687:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [687:3: transition]
# WARNING	Property: Unknown Property name. [695:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [695:3: transform]
# WARNING	Property: Unknown Property name. [699:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [699:3: animation]
# WARNING	Property: Unknown Property name. [703:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [703:3: transform]
# WARNING	CSSStylesheet: Unknown @rule found. [706:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [706:1: @keyframes]
# WARNING	Property: Unknown Property name. [730:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [730:3: transition]
# WARNING	Property: Unknown Property name. [734:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [734:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [751:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [751:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [780:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [780:3: color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [786:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [786:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: linear-gradient(rgba(0, 0, 0, 0.5), rgba(0, 0, 0, 0.5)), url(../img/cta-bg.jpg) center center [794:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: linear-gradient(rgba(0, 0, 0, 0.5), rgba(0, 0, 0, 0.5)), url(../img/cta-bg.jpg) center center [794:3: background]
# WARNING	Property: Unknown Property name. [795:3: background-size]
# WARNING:CSSUTILS:Property: Unknown Property name. [795:3: background-size]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [816:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: radial-gradient(var(--color-primary) 50%, rgba(0, 131, 116, 0.4) 52%) [816:3: background]
# WARNING	Property: Unknown Property name. [827:3: animation-delay]
# WARNING:CSSUTILS:Property: Unknown Property name. [827:3: animation-delay]
# WARNING	Property: Unknown Property name. [828:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [828:3: animation]
# WARNING	Property: Unknown Property name. [829:3: animation-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [829:3: animation-direction]
# WARNING	Property: Unknown Property name. [830:3: animation-iteration-count]
# WARNING:CSSUTILS:Property: Unknown Property name. [830:3: animation-iteration-count]
# WARNING	Property: Unknown Property name. [831:3: animation-timing-function]
# WARNING:CSSUTILS:Property: Unknown Property name. [831:3: animation-timing-function]
# WARNING	Property: Unknown Property name. [843:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [843:3: transform]
# WARNING	Property: Unknown Property name. [847:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [847:3: transition]
# WARNING	Property: Unknown Property name. [855:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [855:3: transform]
# WARNING	Property: Unknown Property name. [859:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [859:3: animation]
# WARNING	Property: Unknown Property name. [863:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [863:3: transform]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [867:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [867:3: font-family]
# WARNING	Property: Unknown Property name. [873:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [873:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [879:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [879:3: background]
# WARNING	CSSStylesheet: Unknown @rule found. [882:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [882:1: @keyframes]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [915:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [915:3: color]
# WARNING	Property: Unknown Property name. [917:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [917:3: transition]
# WARNING	Property: Unknown Property name. [931:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [931:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [935:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [935:3: color]
# WARNING	Property: Unknown Property name. [942:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [942:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [954:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [954:3: color]
# WARNING	Property: Unknown Property name. [1025:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1025:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1046:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1046:3: background-color]
# WARNING	Property: Unknown Property name. [1083:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1083:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1088:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1088:3: color]
# WARNING	Property: Unknown Property name. [1113:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1113:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1132:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1132:3: color]
# WARNING	Property: Unknown Property name. [1133:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1133:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1137:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1137:3: color]
# WARNING	Property: Unknown Property name. [1148:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1148:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1166:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1166:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1182:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1182:3: display]
# WARNING	Property: Unknown Property name. [1183:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1183:3: align-items]
# WARNING	Property: Unknown Property name. [1184:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1184:3: justify-content]
# WARNING	Property: Unknown Property name. [1185:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1185:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1215:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1215:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1227:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1227:3: display]
# WARNING	Property: Unknown Property name. [1228:3: flex-direction]
# WARNING:CSSUTILS:Property: Unknown Property name. [1228:3: flex-direction]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1242:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1242:3: background]
# WARNING	Property: Unknown Property name. [1244:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1244:3: transition]
# WARNING	Property: Unknown Property name. [1306:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1306:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: 0 0 15px 0 0 0 [1311:3: margin]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: 0 0 15px 0 0 0 [1311:3: margin]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1358:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1358:3: display]
# WARNING	Property: Unknown Property name. [1359:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1359:3: align-items]
# WARNING	Property: Unknown Property name. [1360:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1360:3: justify-content]
# WARNING	Property: Unknown Property name. [1365:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1365:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1368:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1368:3: display]
# WARNING	Property: Unknown Property name. [1369:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1369:3: align-items]
# WARNING	Property: Unknown Property name. [1370:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1370:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1374:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1374:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1405:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1405:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1406:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1406:3: display]
# WARNING	Property: Unknown Property name. [1407:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1407:3: align-items]
# WARNING	Property: Unknown Property name. [1408:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1408:3: justify-content]
# WARNING	Property: Unknown Property name. [1409:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1409:3: transition]
# WARNING	Property: Unknown Property name. [1410:3: transform-style]
# WARNING:CSSUTILS:Property: Unknown Property name. [1410:3: transform-style]
# WARNING	Property: Unknown Property name. [1416:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1416:3: transition]
# WARNING	Property: Unknown Property name. [1426:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1426:3: transition]
# WARNING	Property: Unknown Property name. [1427:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1427:3: transform]
# WARNING	Property: Unknown Property name. [1436:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1436:3: transition]
# WARNING	Property: Unknown Property name. [1437:3: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1437:3: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [1442:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [1442:3: color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [1444:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-secondary) [1444:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1469:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1469:3: display]
# WARNING	Property: Unknown Property name. [1470:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1470:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1494:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1494:3: color]
# WARNING	Property: Unknown Property name. [1495:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1495:3: transition]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1498:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1498:3: font-family]
# WARNING	Property: Unknown Property name. [1499:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1499:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1503:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1503:3: background]
# WARNING	Property: Unknown Property name. [1513:5: transform]
# WARNING:CSSUTILS:Property: Unknown Property name. [1513:5: transform]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1553:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1553:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1563:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1563:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1567:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1567:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1614:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1614:3: color]
# WARNING	Property: Unknown Property name. [1615:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1615:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1619:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1619:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1642:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1642:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1667:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1667:3: display]
# WARNING	Property: Unknown Property name. [1668:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1668:3: justify-content]
# WARNING	Property: Unknown Property name. [1669:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1669:3: align-items]
# WARNING	Property: Unknown Property name. [1670:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1670:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1689:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1689:3: color]
# WARNING	Property: Unknown Property name. [1739:3: animation]
# WARNING:CSSUTILS:Property: Unknown Property name. [1739:3: animation]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1764:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1764:3: background]
# WARNING	Property: Unknown Property name. [1767:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1767:3: transition]
# WARNING	CSSStylesheet: Unknown @rule found. [1774:1: @keyframes]
# WARNING:CSSUTILS:CSSStylesheet: Unknown @rule found. [1774:1: @keyframes]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1790:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1790:3: background]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1814:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [1814:3: font-family]
# WARNING	Property: Unknown Property name. [1820:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1820:3: transition]
# WARNING	Property: Unknown Property name. [1831:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1831:3: transition]
# WARNING	Property: Unknown Property name. [1840:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1840:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1871:5: height]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(50% + 20px) [1871:5: height]
# WARNING	Property: Unknown Property name. [1882:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1882:3: transition]
# WARNING	Property: Unknown Property name. [1897:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1897:3: transition]
# WARNING	Property: Unknown Property name. [1904:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1904:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1928:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1928:3: display]
# WARNING	Property: Unknown Property name. [1936:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1936:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1940:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1940:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [1942:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [1942:3: display]
# WARNING	Property: Unknown Property name. [1943:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [1943:3: align-items]
# WARNING	Property: Unknown Property name. [1944:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [1944:3: justify-content]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1949:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1949:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [1955:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-white) [1955:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1988:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [1988:3: color]
# WARNING	Property: Unknown Property name. [1989:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [1989:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1993:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [1993:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2030:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2030:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2053:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2053:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2068:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2068:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2079:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2079:3: display]
# WARNING	Property: Unknown Property name. [2080:3: flex-wrap]
# WARNING:CSSUTILS:Property: Unknown Property name. [2080:3: flex-wrap]
# WARNING	Property: Unknown Property name. [2082:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2082:3: align-items]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2095:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2095:3: color]
# WARNING	Property: Unknown Property name. [2116:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2116:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2120:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2120:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2147:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2147:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2175:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2175:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2206:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2206:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2221:3: width]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: calc(100% - 60px) [2221:3: width]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2237:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2237:3: background]
# WARNING	Property: Unknown Property name. [2239:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2239:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2261:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2261:3: color]
# WARNING	Property: Unknown Property name. [2262:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2262:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2266:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2266:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2291:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2291:3: color]
# WARNING	Property: Unknown Property name. [2292:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2292:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2296:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2296:3: color]
# WARNING	Property: Unknown Property name. [2326:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2326:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2331:3: background]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2331:3: background]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2371:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-default) [2371:3: color]
# WARNING	Property: Unknown Property name. [2372:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2372:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2376:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2376:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2381:3: color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2381:3: color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2438:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-secondary) [2438:3: background-color]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2450:3: background-color]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: var(--color-primary) [2450:3: background-color]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2470:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2470:3: font-family]
# ERROR	Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2475:3: font-family]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Fonts Module Level 3 @font-face properties/CSS Level 2.1" property: var(--font-primary) [2475:3: font-family]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2479:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2479:3: display]
# WARNING	Property: Unknown Property name. [2480:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2480:3: align-items]
# WARNING	Property: Unknown Property name. [2481:3: justify-content]
# WARNING:CSSUTILS:Property: Unknown Property name. [2481:3: justify-content]
# WARNING	Property: Unknown Property name. [2487:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2487:3: transition]
# ERROR	Property: Invalid value for "CSS Level 2.1" property: flex [2520:3: display]
# ERROR:CSSUTILS:Property: Invalid value for "CSS Level 2.1" property: flex [2520:3: display]
# WARNING	Property: Unknown Property name. [2521:3: align-items]
# WARNING:CSSUTILS:Property: Unknown Property name. [2521:3: align-items]
# WARNING	Property: Unknown Property name. [2530:3: transition]
# WARNING:CSSUTILS:Property: Unknown Property name. [2530:3: transition]
# Element: html
# Element: head
#   background-color: var(--color-primary)
#   color: #6f6f6f
#   font-family: var(--font-secondary)
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0 60px 0
#   text-align: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--color-default)
#   font-size: 22px
#   font-weight: 700
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   color: rgba(255, 255, 255, 0.7)
#   font-size: 16px
#   margin: 0 10px 10px 0
#   padding: 0
#   justify-content: center
#   align-items: center
# Element: body
#   color: var(--color-default)
#   font-family: var(--font-default)
#   padding: 0 40px 30px 45px
# Element: header
#   background-color: var(--color-primary)
#   color: #6f6f6f
#   font-family: var(--font-secondary)
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0 60px 0
#   text-align: center
# Element: div
# Element: a
#   background-color: var(--color-primary)
#   color: var(--color-primary)
#   font-family: bootstrap-icons
#   font-size: 32px
#   font-weight: normal
#   margin: auto
#   padding: 60px 0 60px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: h1
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 30px
#   font-weight: 600
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: #f6f6f6
#   color: var(--color-default)
#   font-size: 16px
#   font-weight: 600
#   margin: 0
#   padding: 20px 0
# Element: ul
#   background-color: #ddd
#   color: var(--color-primary)
#   font-size: 20px
#   font-weight: 400
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #ddd
#   color: var(--color-secondary)
#   font-size: 18px
#   font-weight: 500
#   margin: 0 auto
#   padding: 0 0 10px 30px
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-family: bootstrap-icons
#   font-size: 32px
#   font-weight: normal
#   margin: auto
#   padding: 60px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 32px
#   font-weight: 600
#   margin: auto
# Element: font
# Element: p
#   background-color: var(--color-primary)
#   color: #6f6f6f
#   font-family: var(--font-secondary)
#   font-size: 56px
#   font-weight: 500
#   margin: 0
#   padding: 60px 0 60px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: br
#   background-color: var(--color-primary)
#   color: #fff
#   font-family: var(--font-secondary)
#   font-size: 56px
#   font-weight: 500
#   margin: 0
#   padding: 60px 0 60px 0
# Element: img
#   margin: 0 10px 0 0
# Element: h4
#   color: #999
#   font-family: var(--font-primary)
#   font-size: 24px
#   font-weight: 700
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
# Element: h3
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 28px
#   font-weight: 700
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: 400
# Element: button
#   background-color: rgba(0, 0, 0, 0.2)
#   color: rgba(255, 255, 255, 0.8)
#   font-size: 24px
#   font-weight: 600
#   margin: -1px
#   padding: 20px 50px 20px 20px
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--color-primary)
#   color: white
#   font-family: var(--font-primary)
#   font-size: 14px
#   font-weight: 700
#   margin: 0
#   padding: 50px 0
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 10px 0 0
#   padding: 0

# %%
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    for line in css.split('}'):
        if '{' in line:
            selector, properties = line.split('{')
            properties = properties.strip().split(';')
            rule = {'selector': selector.strip(), 'properties': {}}
            for prop in properties:
                if ':' in prop:
                    name, value = prop.split(':')
                    rule['properties'][name.strip()] = value.strip()
            rules.append(rule)
    return rules

def extract_typography_properties(element, css_rules) -> Dict[str, Optional[str]]:
    properties = {
        'background-color': None,
        'color': None,
        'font-family': None,
        'font-size': None,
        'font-weight': None,
        'margin': None,
        'padding': None,
        'text-align': None,
        'justify-content': None,
        'align-items': None
    }
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    return properties

def find_properties(url: str) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties = find_properties(url)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-7051b743581f> in <cell line: 113>()
#     111 # Example usage
#     112 url = 'https://bekushal.com'
# --> 113 properties = find_properties(url)
#     114 for element, props in properties.items():
#     115     print(f"Element: {element}")
#
# <ipython-input-5-7051b743581f> in find_properties(url)
#      99     css_rules = []
#     100     for css in css_from_external_stylesheets + css_from_style_tags:
# --> 101         css_rules.extend(parse_css_rules(css))
#     102
#     103     soup = BeautifulSoup(requests.get(url).content, "html.parser")
#
# <ipython-input-5-7051b743581f> in parse_css_rules(css)
#      69             for prop in properties:
#      70                 if ':' in prop:
# ---> 71                     name, value = prop.split(':')
#      72                     rule['properties'][name.strip()] = value.strip()
#      73             rules.append(rule)
#
# ValueError: too many values to unpack (expected 2)

# %%
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    for line in css.split('}'):
        if '{' in line:
            selector, properties = line.split('{')
            properties = properties.strip().split(';')
            rule = {'selector': selector.strip(), 'properties': {}}
            for prop in properties:
                if ':' in prop:
                    name, value = prop.split(':', 1)  # Split only on the first colon
                    rule['properties'][name.strip()] = value.strip()
            rules.append(rule)
    return rules

def extract_typography_properties(element, css_rules) -> Dict[str, Optional[str]]:
    properties = {
        'background-color': None,
        'color': None,
        'font-family': None,
        'font-size': None,
        'font-weight': None,
        'margin': None,
        'padding': None,
        'text-align': None,
        'justify-content': None,
        'align-items': None
    }
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    return properties

def find_properties(url: str) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties = find_properties(url)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b218eef24906> in <cell line: 113>()
#     111 # Example usage
#     112 url = 'https://bekushal.com'
# --> 113 properties = find_properties(url)
#     114 for element, props in properties.items():
#     115     print(f"Element: {element}")
#
# <ipython-input-9-b218eef24906> in find_properties(url)
#      99     css_rules = []
#     100     for css in css_from_external_stylesheets + css_from_style_tags:
# --> 101         css_rules.extend(parse_css_rules(css))
#     102
#     103     soup = BeautifulSoup(requests.get(url).content, "html.parser")
#
# <ipython-input-9-b218eef24906> in parse_css_rules(css)
#      64     for line in css.split('}'):
#      65         if '{' in line:
# ---> 66             selector, properties = line.split('{')
#      67             properties = properties.strip().split(';')
#      68             rule = {'selector': selector.strip(), 'properties': {}}
#
# ValueError: too many values to unpack (expected 2)

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def extract_typography_properties(element, css_rules, properties_to_extract: List[str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)
    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract)
        elements_properties[element.name] = properties
    return elements_properties

url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties = rule['properties']
            print(root_properties)
            break

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# {'--swiper-theme-color': '#007aff'}
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties = rule['properties']
            break

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def replace_vars_with_values(properties: Dict[str, Optional[str]], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    for prop, value in properties.items():
        while value and value.startswith('var('):
            var_name = value[4:-1].strip()
            if var_name in root_properties:
                value = root_properties[var_name]
            else:
                break
        properties[prop] = value
    return properties

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    # Replace var() with actual values from :root
    properties = replace_vars_with_values(properties, root_properties)
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties = rule['properties']
            break

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def replace_vars_with_values(properties: Dict[str, Optional[str]], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    for prop, value in properties.items():
        while value and value.startswith('var('):
            var_name = value[4:-1].strip()
            if var_name in root_properties:
                value = root_properties[var_name]
            else:
                break
        properties[prop] = value
    return properties

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    # Replace var() with actual values from :root
    properties = replace_vars_with_values(properties, root_properties)
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties.update(rule['properties'])

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def replace_vars_with_values(properties: Dict[str, Optional[str]], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    for prop, value in properties.items():
        while value and value.startswith('var('):
            var_name = value[4:-1].strip()
            if var_name in root_properties:
                value = root_properties[var_name]
            else:
                break
        properties[prop] = value
    return properties

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    # Replace var() with actual values from :root
    properties = replace_vars_with_values(properties, root_properties)
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties.update(rule['properties'])

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def resolve_nested_vars(value: str, root_properties: Dict[str, str]) -> str:
    while value.startswith('var('):
        var_name = value[4:-1].strip()
        if var_name in root_properties:
            value = root_properties[var_name]
        else:
            break
    return value

def replace_vars_with_values(properties: Dict[str, Optional[str]], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    for prop, value in properties.items():
        if value:
            properties[prop] = resolve_nested_vars(value, root_properties)
    return properties

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    # Replace var() with actual values from :root
    properties = replace_vars_with_values(properties, root_properties)
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties.update(rule['properties'])

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
import re
import urllib.parse
from typing import Optional, List, Dict, Tuple
import requests
from bs4 import BeautifulSoup

def extract_css_from_webpage(
    url: str, request_kwargs: Optional[dict] = None, verbose: bool = False
) -> Tuple[List[str], List[str], List[Dict[str, str]]]:
    """Extracts CSS from webpage

    Args:
        url (str): Webpage URL
        request_kwargs (dict): These arguments are passed to requests.get() (when
                                fetching webpage HTML and external stylesheets)
        verbose (bool): Print diagnostic information

    Returns:
        tuple[ list[str], list[str], list[dict] ]: css_from_external_stylesheets, css_from_style_tags, inline_css
    """

    if not request_kwargs:
        request_kwargs = {
            "timeout": 10,
            "headers": {"User-Agent": "Definitely not an Automated Script"},
        }
    url_response = requests.get(url, **request_kwargs)
    if url_response.status_code != 200:
        raise requests.exceptions.HTTPError(
            f"received response [{url_response.status_code}] from [{url}]"
        )

    soup = BeautifulSoup(url_response.content, "html.parser")

    css_from_external_stylesheets: List[str] = []
    for link in soup.find_all("link", rel="stylesheet"):
        css_url = urllib.parse.urljoin(url, link["href"])
        if verbose:
            print(f"downloading external CSS stylesheet {css_url}")
        css_content: str = requests.get(css_url, **request_kwargs).text
        css_from_external_stylesheets.append(css_content)

    css_from_style_tags: List[str] = []
    for style_tag in soup.find_all("style"):
        css_from_style_tags.append(style_tag.string)

    inline_css: List[Dict[str, str]] = []
    for tag in soup.find_all(style=True):
        inline_css.append({"tag": str(tag), "css": tag["style"]})

    if verbose:
        print(
            f"""Extracted the following CSS from [{url}]:
    1. {len(css_from_external_stylesheets):,} external stylesheets (total {len("".join(css_from_external_stylesheets)):,} characters of text)
    2. {len(css_from_style_tags):,} style tags (total {len("".join(css_from_style_tags)):,} characters of text)
    3. {len(inline_css):,} tags with inline CSS (total {len("".join( (x["css"] for x in inline_css) )):,} characters of text)

"""
        )

    return css_from_external_stylesheets, css_from_style_tags, inline_css

def parse_css_rules(css: str) -> List[Dict[str, str]]:
    rules = []
    pattern = re.compile(r'([^{]+)\{([^}]+)\}')
    for match in pattern.finditer(css):
        selector = match.group(1).strip()
        properties = match.group(2).strip().split(';')
        rule = {'selector': selector, 'properties': {}}
        for prop in properties:
            if ':' in prop:
                name, value = prop.split(':', 1)  # Split only on the first colon
                rule['properties'][name.strip()] = value.strip()
        rules.append(rule)
    return rules

def resolve_nested_vars(value: str, root_properties: Dict[str, str]) -> str:
    while value.startswith('var('):
        var_name = value[4:-1].strip()
        if var_name in root_properties:
            value = root_properties[var_name]
        else:
            break
    return value

def replace_vars_with_values(properties: Dict[str, Optional[str]], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    for prop, value in properties.items():
        if value:
            properties[prop] = resolve_nested_vars(value, root_properties)
    return properties

def extract_typography_properties(element, css_rules, properties_to_extract: List[str], root_properties: Dict[str, str]) -> Dict[str, Optional[str]]:
    properties = {prop: None for prop in properties_to_extract}
    for rule in css_rules:
        if element.name in rule['selector']:
            for prop in properties.keys():
                if properties[prop] is None and prop in rule['properties']:
                    properties[prop] = rule['properties'][prop]
    # Apply :root properties if not already set
    for prop in properties.keys():
        if properties[prop] is None and prop in root_properties:
            properties[prop] = root_properties[prop]
    # Replace var() with actual values from :root
    properties = replace_vars_with_values(properties, root_properties)
    return properties

def find_properties(url: str, properties_to_extract: List[str]) -> Dict[str, Dict[str, Optional[str]]]:
    css_from_external_stylesheets, css_from_style_tags, inline_css = extract_css_from_webpage(url)

    css_rules = []
    for css in css_from_external_stylesheets + css_from_style_tags:
        css_rules.extend(parse_css_rules(css))

    # Extract :root properties
    root_properties = {}
    for rule in css_rules:
        if rule['selector'] == ':root':
            root_properties.update(rule['properties'])

    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    elements_properties = {}
    for element in soup.find_all(True):
        properties = extract_typography_properties(element, css_rules, properties_to_extract, root_properties)
        elements_properties[element.name] = properties

    return elements_properties

# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   color: var(--bs-card-title-color)
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-btn-color)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: var(--bs-body-bg)
#   color: var(--bs-body-color)
#   font-family: var(--bs-body-font-family)
#   font-size: var(--bs-body-font-size)
#   font-weight: var(--bs-body-font-weight)
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: var(--bs-card-cap-bg)
#   color: var(--bs-dropdown-header-color)
#   font-family: var(--font-secondary)
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: var(--bs-highlight-bg)
#   color: var(--bs-highlight-color)
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: var(--font-primary)
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: var(--bs-nav-tabs-link-active-bg)
#   color: var(--bs-nav-link-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-nav-link-font-size)
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: var(--color-secondary)
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: var(--bs-table-color)
#   font-family: arial
#   font-size: .875em
#   font-weight: var(--bs-nav-link-font-weight)
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: var(--bs-body-bg)
#   color: var(--bs-secondary-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: var(--bs-table-bg)
#   color: inherit
#   font-family: var(--bs-font-monospace)
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   background-color: var(--bs-breadcrumb-bg)
#   color: var(--bs-navbar-brand-color)
#   font-family: var(--font-secondary)
#   font-size: var(--bs-navbar-brand-font-size)
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: var(--bs-body-bg)
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: var(--bs-heading-color)
#   font-family: var(--font-primary)
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: var(--bs-tertiary-bg)
#   color: var(--bs-body-color)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: var(--bs-card-cap-bg)
#   color: #6c757d
#   font-family: var(--font-primary)
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px

# %%
# Example usage
url = 'https://bekushal.com'
properties_to_extract = [
    'background-color', 'color', 'font-family', 'font-size', 'font-weight',
    'margin', 'padding', 'text-align', 'justify-content', 'align-items'
]
properties = find_properties(url, properties_to_extract)
for element, props in properties.items():
    print(f"Element: {element}")
    for prop, value in props.items():
        if value:
            print(f"  {prop}: {value}")
# Out:
# Element: html
# Element: head
#   background-color: rgba(var(--bs-body-color-rgb), 0.03)
#   color: #adb5bd
#   font-family: "Poppins", sans-serif
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: meta
#   color: #6c757d
#   font-size: 16px
#   margin: 0
#   padding: 0
#   align-items: center
# Element: title
#   font-family: arial
#   font-size: 1em
#   font-weight: 400
#   margin: 0 0 20px 0
#   padding: 0
# Element: link
#   background-color: #212529
#   color: #6ea8fe
#   font-size: var(--bs-nav-link-font-size)
#   margin: 0 10px 10px 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: body
#   background-color: #212529
#   color: #dee2e6
#   font-family: system-ui,-apple-system,"Segoe UI",Roboto,"Helvetica Neue","Noto Sans","Liberation Sans",Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"
#   font-size: 1rem
#   font-weight: 400
#   margin: 0
#   padding: 0
#   text-align: var(--bs-body-text-align)
# Element: header
#   background-color: rgba(var(--bs-body-color-rgb), 0.03)
#   color: #adb5bd
#   font-family: "Poppins", sans-serif
#   font-size: .875rem
#   font-weight: 600
#   margin: calc(-.5 * var(--bs-modal-header-padding-y)) calc(-.5 * var(--bs-modal-header-padding-x)) calc(-.5 * var(--bs-modal-header-padding-y)) auto
#   padding: var(--bs-dropdown-header-padding-y) var(--bs-dropdown-header-padding-x)
#   text-align: center
#   align-items: center
# Element: div
#   margin: var(--bs-dropdown-divider-margin-y) 0
# Element: a
#   background-color: #664d03
#   color: #dee2e6
#   font-family: 'Montserrat'
#   font-size: .875em
#   font-weight: 300
#   margin: 0
#   padding: .1875em
#   text-align: left
#   justify-content: flex-start
#   align-items: flex-start
# Element: h1
#   color: inherit
#   font-family: "Montserrat", sans-serif
#   font-size: calc(1.375rem + 1.5vw)
#   font-weight: 500
#   margin: 0
# Element: span
#   color: #fff
#   font-family: "Montserrat", sans-serif
#   font-size: 40px
#   font-weight: 700
# Element: nav
#   background-color: #212529
#   color: rgba(255, 255, 255, 0.55)
#   font-family: "Poppins", sans-serif
#   font-size: var(--bs-nav-link-font-size)
#   margin: 0
#   padding: var(--bs-nav-link-padding-y) var(--bs-nav-link-padding-x)
#   text-align: center
#   justify-content: space-between
#   align-items: center
# Element: ul
#   background-color: #f85a40
#   color: #006a5d
#   font-size: 0
#   font-weight: 600
#   margin: 0
#   padding: 0
#   text-align: left
#   align-items: center
# Element: li
#   background-color: #0d6efd
#   color: #fff
#   font-family: arial
#   font-size: .875em
#   margin: auto
#   padding: .25rem .5rem
#   text-align: center
#   justify-content: center
#   align-items: center
# Element: i
#   background-color: #212529
#   color: rgba(222, 226, 230, 0.75)
#   font-family: inherit
#   font-size: inherit
#   font-weight: 300
#   margin: 0 0 1rem
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: section
#   background-color: #f6f6f6
#   color: #6f6f6f
#   font-size: 32px
#   font-weight: 600
#   margin: auto
#   padding: 60px 0
#   text-align: center
# Element: h2
#   color: inherit
#   font-family: "Montserrat", sans-serif
#   font-size: calc(1.325rem + .9vw)
#   font-weight: 500
#   margin: auto
# Element: font
#   font-family: 'Montserrat'
#   font-weight: 300
# Element: p
#   background-color: #212529
#   color: inherit
#   font-family: SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace
#   font-size: .75em
#   font-weight: 300
#   margin: 0
#   padding: 0
#   text-align: left
#   justify-content: center
#   align-items: stretch
# Element: br
#   color: #fff
#   font-family: "Poppins", sans-serif
#   font-size: 1.25rem
#   font-weight: 500
#   margin: 0
#   padding: var(--bs-breadcrumb-padding-y) var(--bs-breadcrumb-padding-x)
# Element: img
#   background-color: #212529
#   margin: auto
#   padding: .25rem
# Element: h4
#   color: inherit
#   font-family: "Montserrat", sans-serif
#   font-size: calc(1.275rem + .3vw)
#   font-weight: 500
#   margin: 0
#   padding: 0
#   text-align: center
# Element: main
#   font-family: "bootstrap-icons"
# Element: h3
#   color: inherit
#   font-family: "Montserrat", sans-serif
#   font-size: calc(1.3rem + .6vw)
#   font-weight: 500
#   margin: 0 0 20px 0
#   text-align: center
# Element: strong
#   color: #9c9c9c
#   font-size: 12px
#   font-weight: bolder
# Element: button
#   background-color: #2b3035
#   color: #dee2e6
#   font-family: inherit
#   font-size: inherit
#   font-weight: 600
#   margin: 0
#   padding: .375rem .75rem
#   text-align: left
#   justify-content: center
#   align-items: center
# Element: footer
#   background-color: rgba(var(--bs-body-color-rgb), 0.03)
#   color: #6c757d
#   font-family: "Montserrat", sans-serif
#   font-size: .875em
#   font-weight: 700
#   margin: calc(var(--bs-modal-footer-gap) * .5)
#   padding: var(--bs-card-cap-padding-y) var(--bs-card-cap-padding-x)
#   text-align: center
#   justify-content: flex-end
#   align-items: center
# Element: script
#   color: #6c757d
#   font-size: 26px
#   font-weight: 700
#   margin: 0 auto
#   padding: 19px 11px
