# %%
! pip install cssutils
# Out:
# Collecting cssutils
#   Downloading cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cssutils) (10.5.0)
# Downloading cssutils-2.11.1-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: cssutils
# Successfully installed cssutils-2.11.1

# %%
from colorsys import rgb_to_hsv

def hex_to_rgb(hex_color):
    hex_color = hex_color.lstrip('#')
    return tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))

def luminance(r, g, b):
    a = [v / 255.0 for v in (r, g, b)]
    a = [v / 12.92 if v <= 0.03928 else ((v + 0.055) / 1.055) ** 2.4 for v in a]
    return 0.2126 * a[0] + 0.7152 * a[1] + 0.0722 * a[2]

def contrast_ratio(color1, color2):
    L1 = luminance(*color1)
    L2 = luminance(*color2)
    if L1 > L2:
        return (L1 + 0.05) / (L2 + 0.05)
    else:
        return (L2 + 0.05) / (L1 + 0.05)

text_color_hex = '#576EAF'
background_color_hex = '#000000'

text_color_rgb = hex_to_rgb(text_color_hex)
print(text_color_rgb)
background_color_rgb = hex_to_rgb(background_color_hex)
print(background_color_rgb)

ratio = contrast_ratio(text_color_rgb, background_color_rgb)
print(f"Contrast Ratio: {ratio:.2f}")
# Out:
# (87, 110, 175)
# (0, 0, 0)
# Contrast Ratio: 4.25

# %%
import requests
from bs4 import BeautifulSoup
import cssutils

def extract_colors_from_css(css_content):
    parser = cssutils.CSSParser()
    stylesheet = parser.parseString(css_content)
    colors = {}
    for rule in stylesheet:
        if rule.type == rule.STYLE_RULE:
            for property in rule.style:
                if property.name in ['color', 'background-color']:
                    selector = rule.selectorText
                    if selector not in colors:
                        colors[selector] = {}
                    colors[selector][property.name] = property.value
    return colors

def extract_colors_from_html(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    colors = {}
    for tag in soup.find_all(style=True):
        style = tag['style']
        tag_name = tag.name
        if tag_name not in colors:
            colors[tag_name] = {}
        if 'color' in style:
            colors[tag_name]['color'] = style.split('color:')[1].split(';')[0].strip()
        if 'background-color' in style:
            colors[tag_name]['background_color'] = style.split('background-color:')[1].split(';')[0].strip()
    return colors

def scrape_colors(url):
    response = requests.get(url)
    html_content = response.text

    html_colors = extract_colors_from_html(html_content)

    css_content = response.content.decode('utf-8')
    css_colors = extract_colors_from_css(css_content)

    return html_colors, css_colors

url = 'https://google.com'
html_colors, css_colors = scrape_colors(url)

print("HTML Colors:")
for tag, styles in html_colors.items():
    print(f"Tag: {tag}, Styles: {styles}")

print("\nCSS Colors:")
for selector, styles in css_colors.items():
    print(f"Selector: {selector}, Styles: {styles}")

colors_data = {
    'body': {
        'text_color': html_colors.get('body', {}).get('color', ''),
        'background_color': html_colors.get('body', {}).get('background_color', '')
    },
    'h1': {
        'text_color': css_colors.get('h1', {}).get('color', '')
    },
    'mark': {
        'highlight_color': css_colors.get('.mark', {}).get('color', ''),
        'highlight_bg': css_colors.get('.mark', {}).get('background-color', '')
    },
    'a': {
        'link_color': css_colors.get('a', {}).get('color', ''),
        'hover_color': css_colors.get('a:hover', {}).get('color', '')
    }
    # Add more elements as needed
}

for element, styles in colors_data.items():
    print(f"{element}: {styles}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ERROR	Selector: Unexpected CHAR. [12:220: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:220: =]
# ERROR	Selector: Unexpected NUMBER. [12:221: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:221: 0]
# ERROR	Selector: Unexpected CHAR. [12:222: ?]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:222: ?]
# ERROR	Selector: Unexpected IDENT. [12:223: window]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:223: window]
# ERROR	Selector: Unexpected class. [12:230: .google]
# ERROR:CSSUTILS:Selector: Unexpected class. [12:230: .google]
# ERROR	Selector: Unexpected class. [12:237: .kOPI]
# ERROR:CSSUTILS:Selector: Unexpected class. [12:237: .kOPI]
# ERROR	Selector: Unexpected start of pseudo. [12:242: :null]
# ERROR:CSSUTILS:Selector: Unexpected start of pseudo. [12:242: :null]
# ERROR	Selector: Unexpected CHAR. [12:246: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:246: ;]
# ERROR	Selector: Unexpected IDENT. [12:247: l]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:247: l]
# ERROR	Selector: Unexpected CHAR. [12:248: !]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:248: !]
# ERROR	Selector: Unexpected CHAR. [12:249: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:249: =]
# ERROR	Selector: Unexpected IDENT. [12:250: null]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:250: null]
# ERROR	Selector: Unexpected CHAR. [12:254: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:254: &]
# ERROR	Selector: Unexpected CHAR. [12:255: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:255: &]
# ERROR	Selector: Unexpected IDENT. [12:256: k]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:256: k]
# ERROR	Selector: Unexpected CHAR. [12:257: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:257: .]
# ERROR	Unexpected token (FUNCTION, push(, 12, 258)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, push(, 12, 258)
# ERROR	Selector: Unexpected CHAR. [12:263: []
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:263: []
# ERROR	Selector: Unexpected STRING. [12:264: "opi"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:264: "opi"]
# ERROR	Selector: Single selector only. [12:269: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:269: ,]
# ERROR	Selector: Unexpected IDENT. [12:270: l]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:270: l]
# ERROR	Selector: Unexpected CHAR. [12:271: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:271: .]
# ERROR	Unexpected token (FUNCTION, toString(, 12, 272)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, toString(, 12, 272)
# ERROR	Selector: Unexpected CHAR. [12:281: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:281: )]
# ERROR	Selector: Unexpected CHAR. [12:283: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:283: )]
# ERROR	Selector: Unexpected CHAR. [12:284: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:284: ;]
# ERROR	Unexpected token (FUNCTION, for(, 12, 285)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, for(, 12, 285)
# ERROR	Selector: Unexpected IDENT. [12:289: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:289: var]
# ERROR	Selector: Unexpected CHAR. [12:294: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:294: =]
# ERROR	Selector: Unexpected NUMBER. [12:295: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:295: 0]
# ERROR	Selector: Unexpected CHAR. [12:296: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:296: ;]
# ERROR	Selector: Unexpected IDENT. [12:297: m]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:297: m]
# ERROR	Selector: Unexpected CHAR. [12:298: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:298: <]
# ERROR	Selector: Unexpected IDENT. [12:299: k]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:299: k]
# ERROR	Selector: Unexpected CHAR. [12:307: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:307: ;]
# ERROR	Selector: Unexpected IDENT. [12:308: m]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:308: m]
# ERROR	Selector: Unexpected CHAR. [12:310: +]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:310: +]
# ERROR	Selector: Unexpected CHAR. [12:311: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:311: )]
# ERROR	Selector: Unexpected CHAR. [12:312: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:312: {]
# ERROR	Unexpected token (FUNCTION, if(, 12, 313)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, if(, 12, 313)
# ERROR	Selector: Unexpected CHAR. [12:317: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:317: =]
# ERROR	Selector: Unexpected CHAR. [12:318: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:318: =]
# ERROR	Selector: Unexpected CHAR. [12:319: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:319: =]
# ERROR	Selector: Unexpected NUMBER. [12:320: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:320: 0]
# ERROR	Selector: Unexpected namespace prefix. [12:321: |]
# ERROR:CSSUTILS:Selector: Unexpected namespace prefix. [12:321: |]
# ERROR	Selector: Unexpected namespace prefix. [12:322: |]
# ERROR:CSSUTILS:Selector: Unexpected namespace prefix. [12:322: |]
# ERROR	Selector: Unexpected IDENT. [12:323: m]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:323: m]
# ERROR	Selector: Unexpected NUMBER. [12:325: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:325: 0]
# ERROR	Selector: Unexpected CHAR. [12:326: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:326: )]
# ERROR	Selector: Unexpected CHAR. [12:329: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:329: =]
# ERROR	Selector: Unexpected STRING. [12:330: "&"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:330: "&"]
# ERROR	Selector: Unexpected CHAR. [12:333: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:333: ;]
# ERROR	Selector: Unexpected CHAR. [12:336: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:336: =]
# ERROR	Selector: Unexpected NUMBER. [12:342: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:342: 0]
# ERROR	Selector: Unexpected CHAR. [12:343: ]]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:343: ]]
# ERROR	Selector: Unexpected CHAR. [12:344: +]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:344: +]
# ERROR	Selector: Unexpected STRING. [12:345: "="]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:345: "="]
# ERROR	Selector: Unexpected CHAR. [12:348: +]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:348: +]
# ERROR	Selector: Unexpected CHAR. [12:350: []
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:350: []
# ERROR	Selector: Unexpected IDENT. [12:351: m]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:351: m]
# ERROR	Selector: Unexpected NUMBER. [12:354: 1]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:354: 1]
# ERROR	Selector: Unexpected CHAR. [12:355: ]]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:355: ]]
# ERROR	Selector: Unexpected CHAR. [12:356: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:356: }]
# ERROR	Selector: Unexpected CHAR. [12:358: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:358: .]
# ERROR	Unexpected token (FUNCTION, call(, 12, 359)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, call(, 12, 359)
# ERROR	Selector: Unexpected IDENT. [12:364: e]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:364: e]
# ERROR	Selector: Single selector only. [12:365: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:365: ,]
# ERROR	Selector: Unexpected STRING. [12:366: ""]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:366: ""]
# ERROR	Selector: Single selector only. [12:368: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:368: ,]
# ERROR	Selector: Unexpected STRING. [12:369: ""]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:369: ""]
# ERROR	Selector: Single selector only. [12:371: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:371: ,]
# ERROR	Selector: Unexpected IDENT. [12:372: g]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:372: g]
# ERROR	Selector: Unexpected CHAR. [12:375: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:375: )]
# ERROR	Selector: Unexpected CHAR. [12:376: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:376: }]
# ERROR	Selector: Unexpected CHAR. [12:377: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:377: ;]
# ERROR	Selector: Unexpected CHAR. [12:378: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:378: }]
# ERROR	Selector: Unexpected CHAR. [12:379: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:379: )]
# ERROR	Selector: Unexpected CHAR. [12:380: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:380: .]
# ERROR	Unexpected token (FUNCTION, call(, 12, 381)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, call(, 12, 381)
# ERROR	Selector: Unexpected IDENT. [12:386: this]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:386: this]
# ERROR	Selector: Unexpected CHAR. [12:390: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:390: )]
# ERROR	Selector: Unexpected CHAR. [12:391: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:391: ;]
# ERROR	Selector: Unexpected CHAR. [12:392: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:392: }]
# ERROR	Selector: Unexpected CHAR. [12:393: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:393: )]
# ERROR	Selector: Unexpected CHAR. [12:394: (]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:394: (]
# ERROR	Selector: Unexpected CHAR. [12:395: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:395: )]
# ERROR	Selector: Invalid or incomplete selector: 2024 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}
# if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null;l!=null&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(m===0||m>0)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})()
# ERROR:CSSUTILS:Selector: Invalid or incomplete selector: 2024 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}
# if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null;l!=null&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(m===0||m>0)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})()
# ERROR	SelectorList: Invalid Selector: 2024 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}
# if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null;l!=null&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(m===0||m>0)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})()
# ERROR:CSSUTILS:SelectorList: Invalid Selector: 2024 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}
# if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null;l!=null&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(m===0||m>0)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})()
# ERROR	CSSStyleRule: No style declaration or "}" found: '2024 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}\nif(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null;l!=null&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(m===0||m>0)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})();'
# ERROR:CSSUTILS:CSSStyleRule: No style declaration or "}" found: '2024 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}\nif(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=[],l=window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null;l!=null&&k.push(["opi",l.toString()]);for(var m=0;m<k.length;m++){if(m===0||m>0)h+="&";h+=k[m][0]+"="+k[m][1]}f.call(e,"","",g+h)};}).call(this);})();'
# ERROR	CSSStyleRule: No start { of style declaration found: '</script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\\x3d1/ed\\x3d1/dg\\x3d0/ujg\\x3d1/rs\\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA\',basecss:\'/xjs/_/ss/k\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ\',basejs:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\\x3d0/rs\\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ\',excm:[]};})();' [12:1147: ;]
# ERROR:CSSUTILS:CSSStyleRule: No start { of style declaration found: '</script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\\x3d1/ed\\x3d1/dg\\x3d0/ujg\\x3d1/rs\\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA\',basecss:\'/xjs/_/ss/k\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ\',basejs:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\\x3d0/rs\\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ\',excm:[]};})();' [12:1147: ;]
# ERROR	Selector: Unexpected CHAR. [12:397: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:397: <]
# ERROR	Selector: Unexpected CHAR. [12:398: /]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:398: /]
# ERROR	Selector: Unexpected CHAR. [12:408: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:408: <]
# ERROR	Selector: Unexpected CHAR. [12:421: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:421: =]
# ERROR	Selector: Unexpected STRING. [12:422: "rMVx5O0qAX71XmlHRSEWqg"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:422: "rMVx5O0qAX71XmlHRSEWqg"]
# ERROR	Selector: Unexpected CHAR. [12:447: (]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:447: (]
# ERROR	Unexpected token (FUNCTION, function(, 12, 448)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, function(, 12, 448)
# ERROR	Selector: Unexpected CHAR. [12:457: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:457: )]
# ERROR	Selector: Unexpected CHAR. [12:458: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:458: {]
# ERROR	Selector: Unexpected CHAR. [12:469: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:469: =]
# ERROR	Selector: Unexpected CHAR. [12:470: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:470: {]
# ERROR	Selector: Unexpected IDENT. [12:471: basecomb]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:471: basecomb]
# ERROR	Selector: Unexpected CHAR. [12:479: :]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:479: :]
# ERROR	Selector: Unexpected STRING. [12:480: '/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA']
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:480: '/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA']
# ERROR	Selector: Single selector only. [12:738: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:738: ,]
# ERROR	Selector: Unexpected IDENT. [12:739: basecss]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:739: basecss]
# ERROR	Selector: Unexpected CHAR. [12:746: :]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:746: :]
# ERROR	Selector: Unexpected STRING. [12:747: '/xjs/_/ss/k\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ']
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:747: '/xjs/_/ss/k\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ']
# ERROR	Selector: Single selector only. [12:922: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:922: ,]
# ERROR	Selector: Unexpected IDENT. [12:923: basejs]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:923: basejs]
# ERROR	Selector: Unexpected CHAR. [12:929: :]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:929: :]
# ERROR	Selector: Unexpected STRING. [12:930: '/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\x3d0/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ']
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:930: '/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\x3d0/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ']
# ERROR	Selector: Single selector only. [12:1133: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1133: ,]
# ERROR	Selector: Unexpected IDENT. [12:1134: excm]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1134: excm]
# ERROR	Selector: Unexpected CHAR. [12:1138: :]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1138: :]
# ERROR	Selector: Unexpected CHAR. [12:1140: ]]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1140: ]]
# ERROR	Selector: Unexpected CHAR. [12:1141: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1141: }]
# ERROR	Selector: Unexpected CHAR. [12:1142: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1142: ;]
# ERROR	Selector: Unexpected CHAR. [12:1143: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1143: }]
# ERROR	Selector: Unexpected CHAR. [12:1144: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1144: )]
# ERROR	Selector: Unexpected CHAR. [12:1145: (]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1145: (]
# ERROR	Selector: Unexpected CHAR. [12:1146: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1146: )]
# ERROR	Selector: Invalid or incomplete selector: </script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA',basecss:'/xjs/_/ss/k\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ',basejs:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\x3d0/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ',excm:[]};})()
# ERROR:CSSUTILS:Selector: Invalid or incomplete selector: </script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA',basecss:'/xjs/_/ss/k\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ',basejs:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\x3d0/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ',excm:[]};})()
# ERROR	SelectorList: Invalid Selector: </script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA',basecss:'/xjs/_/ss/k\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ',basejs:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\x3d0/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ',excm:[]};})()
# ERROR:CSSUTILS:SelectorList: Invalid Selector: </script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA',basecss:'/xjs/_/ss/k\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ',basejs:'/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\x3d0/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ',excm:[]};})()
# ERROR	CSSStyleRule: No style declaration or "}" found: '</script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\\x3d1/ed\\x3d1/dg\\x3d0/ujg\\x3d1/rs\\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA\',basecss:\'/xjs/_/ss/k\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ\',basejs:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\\x3d0/rs\\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ\',excm:[]};})();'
# ERROR:CSSUTILS:CSSStyleRule: No style declaration or "}" found: '</script>  <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){google.xjs={basecomb:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/ck\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAQAgAAAAAAAAAAAwAIAcAAIAAAAEBAAAAAAcAAAAAAAAGEAEAKAAIEwDAgfiOAEAALAIAwAs/d\\x3d1/ed\\x3d1/dg\\x3d0/ujg\\x3d1/rs\\x3dACT90oF5dmEDXmZdsYEWU8zzuMy_RGXUPA\',basecss:\'/xjs/_/ss/k\\x3dxjs.hp.bd2xGp0CA8s.L.X.O/am\\x3dAQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/rs\\x3dACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ\',basejs:\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/dg\\x3d0/rs\\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ\',excm:[]};})();'
# ERROR	CSSStyleRule: No start { of style declaration found: '</script>  <link href="/xjs/_/ss/k=xjs.hp.bd2xGp0CA8s.L.X.O/am=AQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/d=1/ed=1/rs=ACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ/m=sb_he,d" rel="stylesheet" nonce="rMVx5O0qAX71XmlHRSEWqg">      <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){var u=\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/d\\x3d1/ed\\x3d1/dg\\x3d3/rs\\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ/m\\x3dsb_he,d\';var st=1;var amd=1000;var mmd=0;var pod=true;var f=typeof Object.defineProperties=="function"?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a},g=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("a");},h=g(this),k=function(a,b){if(b)a:{var c=h;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];if(!(e in\nc))break a;c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&b!=null&&f(c,a,{configurable:!0,writable:!0,value:b})}};k("globalThis",function(a){return a||h});\nvar l=this||self;function m(){var a,b,c;return(a=(b=window.google)==null?void 0:(c=b.ia)==null?void 0:c.r.B2Jtyd)&&a.m===1&&a.cbfd!=null&&a.cbvi!=null?a:void 0};\nvar n=globalThis.trustedTypes,p;function q(){var a=null;if(!n)return a;try{var b=function(c){return c};a=n.createPolicy("goog#html",{createHTML:b,createScript:b,createScriptURL:b})}catch(c){}return a};var r=function(a){this.g=a};r.prototype.toString=function(){return this.g+""};function t(a){if(a instanceof r)return a.g;throw Error("b");};var w=/^\\s*(?!javascript:)(?:[\\w+.-]+:|[^:/?#]*(?:[/?#]|$))/i;var x="alternate author bookmark canonical cite help icon license modulepreload next prefetch dns-prefetch prerender preconnect preload prev search subresource".split(" ");function y(a,b){a.src=t(b);var c,d;(c=(b=(d=(c=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)==null?void 0:d.call(c,"script[nonce]"))?b.nonce||b.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",c)};var z=function(a){var b=document;a=String(a);b.contentType==="application/xhtml+xml"&&(a=a.toLowerCase());return b.createElement(a)};function A(a){a=a===null?"null":a===void 0?"undefined":a;p===void 0&&(p=q());var b=p;return new r(b?b.createScriptURL(a):a)};google.ps===void 0&&(google.ps=[]);function B(){var a=u,b=function(){};google.lx=google.stvsc?b:function(){C(a);google.lx=b};google.bx||google.lx()}function D(a,b){b&&y(a,A(b));var c=a.onload;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(e){return a!==e})};google.ps.push(a);document.body.appendChild(a)}google.as=D;function C(a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=z("SCRIPT");b.onerror=function(){google.ple=1};b.onload=function(){google.ple=0};google.xjsus=void 0;D(b,a);google.aple=-1;google.dp=!0}\nfunction E(){var a=[u];if(!google.dp){for(var b=0;b<a.length;b++){var c=z("LINK"),d=c,e=A(a[b]);if(e instanceof r)d.href=t(e).toString(),d.rel="preload";else{if(x.indexOf("preload")===-1)throw Error("c`preload");e=w.test(e)?e:void 0;e!==void 0&&(d.href=e,d.rel="preload")}c.setAttribute("as","script");document.body.appendChild(c)}google.dp=!0}};function F(a){var b=a.getAttribute("jscontroller");return(b==="UBXHI"||b==="R3fhkb"||b==="TSZEqd")&&a.hasAttribute("data-src")}function G(){for(var a=document.getElementsByTagName("img"),b=0,c=a.length;b<c;b++){var d=a[b];if(d.hasAttribute("data-lzy_")&&Number(d.getAttribute("data-atf"))&1&&!F(d))return!0}return!1}for(var H=document.getElementsByTagName("img"),I=0,J=H.length;I<J;++I){var K=H[I];Number(K.getAttribute("data-atf"))&1&&F(K)&&(K.src=K.getAttribute("data-src"))};var L,M,N,O,P,Q;function R(){google.xjsu=u;l._ ...
# ERROR:CSSUTILS:CSSStyleRule: No start { of style declaration found: '</script>  <link href="/xjs/_/ss/k=xjs.hp.bd2xGp0CA8s.L.X.O/am=AQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/d=1/ed=1/rs=ACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ/m=sb_he,d" rel="stylesheet" nonce="rMVx5O0qAX71XmlHRSEWqg">      <script nonce="rMVx5O0qAX71XmlHRSEWqg">(function(){var u=\'/xjs/_/js/k\\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/d\\x3d1/ed\\x3d1/dg\\x3d3/rs\\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ/m\\x3dsb_he,d\';var st=1;var amd=1000;var mmd=0;var pod=true;var f=typeof Object.defineProperties=="function"?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a},g=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("a");},h=g(this),k=function(a,b){if(b)a:{var c=h;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];if(!(e in\nc))break a;c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&b!=null&&f(c,a,{configurable:!0,writable:!0,value:b})}};k("globalThis",function(a){return a||h});\nvar l=this||self;function m(){var a,b,c;return(a=(b=window.google)==null?void 0:(c=b.ia)==null?void 0:c.r.B2Jtyd)&&a.m===1&&a.cbfd!=null&&a.cbvi!=null?a:void 0};\nvar n=globalThis.trustedTypes,p;function q(){var a=null;if(!n)return a;try{var b=function(c){return c};a=n.createPolicy("goog#html",{createHTML:b,createScript:b,createScriptURL:b})}catch(c){}return a};var r=function(a){this.g=a};r.prototype.toString=function(){return this.g+""};function t(a){if(a instanceof r)return a.g;throw Error("b");};var w=/^\\s*(?!javascript:)(?:[\\w+.-]+:|[^:/?#]*(?:[/?#]|$))/i;var x="alternate author bookmark canonical cite help icon license modulepreload next prefetch dns-prefetch prerender preconnect preload prev search subresource".split(" ");function y(a,b){a.src=t(b);var c,d;(c=(b=(d=(c=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)==null?void 0:d.call(c,"script[nonce]"))?b.nonce||b.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",c)};var z=function(a){var b=document;a=String(a);b.contentType==="application/xhtml+xml"&&(a=a.toLowerCase());return b.createElement(a)};function A(a){a=a===null?"null":a===void 0?"undefined":a;p===void 0&&(p=q());var b=p;return new r(b?b.createScriptURL(a):a)};google.ps===void 0&&(google.ps=[]);function B(){var a=u,b=function(){};google.lx=google.stvsc?b:function(){C(a);google.lx=b};google.bx||google.lx()}function D(a,b){b&&y(a,A(b));var c=a.onload;a.onload=function(d){c&&c(d);google.ps=google.ps.filter(function(e){return a!==e})};google.ps.push(a);document.body.appendChild(a)}google.as=D;function C(a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=z("SCRIPT");b.onerror=function(){google.ple=1};b.onload=function(){google.ple=0};google.xjsus=void 0;D(b,a);google.aple=-1;google.dp=!0}\nfunction E(){var a=[u];if(!google.dp){for(var b=0;b<a.length;b++){var c=z("LINK"),d=c,e=A(a[b]);if(e instanceof r)d.href=t(e).toString(),d.rel="preload";else{if(x.indexOf("preload")===-1)throw Error("c`preload");e=w.test(e)?e:void 0;e!==void 0&&(d.href=e,d.rel="preload")}c.setAttribute("as","script");document.body.appendChild(c)}google.dp=!0}};function F(a){var b=a.getAttribute("jscontroller");return(b==="UBXHI"||b==="R3fhkb"||b==="TSZEqd")&&a.hasAttribute("data-src")}function G(){for(var a=document.getElementsByTagName("img"),b=0,c=a.length;b<c;b++){var d=a[b];if(d.hasAttribute("data-lzy_")&&Number(d.getAttribute("data-atf"))&1&&!F(d))return!0}return!1}for(var H=document.getElementsByTagName("img"),I=0,J=H.length;I<J;++I){var K=H[I];Number(K.getAttribute("data-atf"))&1&&F(K)&&(K.src=K.getAttribute("data-src"))};var L,M,N,O,P,Q;function R(){google.x ...
# ERROR	Selector: Unexpected CHAR. [12:1148: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1148: <]
# ERROR	Selector: Unexpected CHAR. [12:1149: /]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1149: /]
# ERROR	Selector: Unexpected CHAR. [12:1159: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1159: <]
# ERROR	Selector: Unexpected CHAR. [12:1169: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1169: =]
# ERROR	Selector: Unexpected STRING. [12:1170: "/xjs/_/ss/k=xjs.hp.bd2xGp0CA8s.L.X.O/am=AQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/d=1/ed=1/rs=ACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ/m=sb_he,d"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1170: "/xjs/_/ss/k=xjs.hp.bd2xGp0CA8s.L.X.O/am=AQAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAAAAIAAAAIAAAAEBAAAAAAAAAAAAAAAGEAEAKAAIEw/d=1/ed=1/rs=ACT90oH_T8aJP-wlKoo4KCkWznYcL_51rQ/m=sb_he,d"]
# ERROR	Selector: Unexpected CHAR. [12:1359: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1359: =]
# ERROR	Selector: Unexpected STRING. [12:1360: "stylesheet"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1360: "stylesheet"]
# ERROR	Selector: Unexpected CHAR. [12:1378: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1378: =]
# ERROR	Selector: Unexpected STRING. [12:1379: "rMVx5O0qAX71XmlHRSEWqg"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1379: "rMVx5O0qAX71XmlHRSEWqg"]
# ERROR	Selector: Unexpected CHAR. [12:1410: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1410: <]
# ERROR	Selector: Unexpected CHAR. [12:1423: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1423: =]
# ERROR	Selector: Unexpected STRING. [12:1424: "rMVx5O0qAX71XmlHRSEWqg"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1424: "rMVx5O0qAX71XmlHRSEWqg"]
# ERROR	Selector: Unexpected CHAR. [12:1449: (]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1449: (]
# ERROR	Unexpected token (FUNCTION, function(, 12, 1450)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, function(, 12, 1450)
# ERROR	Selector: Unexpected CHAR. [12:1459: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1459: )]
# ERROR	Selector: Unexpected CHAR. [12:1460: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1460: {]
# ERROR	Selector: Unexpected CHAR. [12:1466: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1466: =]
# ERROR	Selector: Unexpected STRING. [12:1467: '/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d3/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ/m\x3dsb_he,d']
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1467: '/xjs/_/js/k\x3dxjs.hp.en.pVGq0axs-aI.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAAAAAAAAAAAAAwAAAcAAAAAAAAAAAAAAAcAAAAAAAAAAAAAAAAAAADAgfiOAEAALAIAwAs/d\x3d1/ed\x3d1/dg\x3d3/rs\x3dACT90oEF36ZKgJBAhHfgPt5y7PhcoHI0LQ/m\x3dsb_he,d']
# ERROR	Selector: Unexpected CHAR. [12:1698: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1698: ;]
# ERROR	Selector: Unexpected IDENT. [12:1699: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1699: var]
# ERROR	Selector: Unexpected CHAR. [12:1705: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1705: =]
# ERROR	Selector: Unexpected NUMBER. [12:1706: 1]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:1706: 1]
# ERROR	Selector: Unexpected CHAR. [12:1707: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1707: ;]
# ERROR	Selector: Unexpected IDENT. [12:1708: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1708: var]
# ERROR	Selector: Unexpected CHAR. [12:1715: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1715: =]
# ERROR	Selector: Unexpected NUMBER. [12:1716: 1000]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:1716: 1000]
# ERROR	Selector: Unexpected CHAR. [12:1720: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1720: ;]
# ERROR	Selector: Unexpected IDENT. [12:1721: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1721: var]
# ERROR	Selector: Unexpected CHAR. [12:1728: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1728: =]
# ERROR	Selector: Unexpected NUMBER. [12:1729: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:1729: 0]
# ERROR	Selector: Unexpected CHAR. [12:1730: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1730: ;]
# ERROR	Selector: Unexpected IDENT. [12:1731: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1731: var]
# ERROR	Selector: Unexpected CHAR. [12:1738: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1738: =]
# ERROR	Selector: Unexpected IDENT. [12:1739: true]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1739: true]
# ERROR	Selector: Unexpected CHAR. [12:1743: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1743: ;]
# ERROR	Selector: Unexpected IDENT. [12:1744: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1744: var]
# ERROR	Selector: Unexpected CHAR. [12:1749: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1749: =]
# ERROR	Selector: Unexpected IDENT. [12:1750: typeof]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1750: typeof]
# ERROR	Selector: Unexpected CHAR. [12:1780: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1780: =]
# ERROR	Selector: Unexpected CHAR. [12:1781: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1781: =]
# ERROR	Selector: Unexpected STRING. [12:1782: "function"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1782: "function"]
# ERROR	Selector: Unexpected CHAR. [12:1792: ?]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1792: ?]
# ERROR	Selector: Unexpected IDENT. [12:1793: Object]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1793: Object]
# ERROR	Selector: Single selector only. [12:1825: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1825: ,]
# ERROR	Selector: Single selector only. [12:1827: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1827: ,]
# ERROR	Selector: Unexpected CHAR. [12:1830: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1830: {]
# ERROR	Unexpected token (FUNCTION, if(, 12, 1831)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, if(, 12, 1831)
# ERROR	Selector: Unexpected CHAR. [12:1835: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1835: =]
# ERROR	Selector: Unexpected CHAR. [12:1836: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1836: =]
# ERROR	Selector: Unexpected IDENT. [12:1837: Array]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1837: Array]
# ERROR	Selector: Unexpected namespace prefix. [12:1852: |]
# ERROR:CSSUTILS:Selector: Unexpected namespace prefix. [12:1852: |]
# ERROR	Selector: Unexpected namespace prefix. [12:1853: |]
# ERROR:CSSUTILS:Selector: Unexpected namespace prefix. [12:1853: |]
# ERROR	Selector: Unexpected IDENT. [12:1854: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1854: a]
# ERROR	Selector: Unexpected CHAR. [12:1855: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1855: =]
# ERROR	Selector: Unexpected CHAR. [12:1856: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1856: =]
# ERROR	Selector: Unexpected IDENT. [12:1857: Object]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1857: Object]
# ERROR	Selector: Unexpected CHAR. [12:1873: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1873: )]
# ERROR	Selector: Unexpected IDENT. [12:1874: return]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1874: return]
# ERROR	Selector: Unexpected CHAR. [12:1882: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1882: ;]
# ERROR	Selector: Unexpected IDENT. [12:1883: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1883: a]
# ERROR	Selector: Unexpected CHAR. [12:1887: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1887: =]
# ERROR	Selector: Unexpected IDENT. [12:1888: c]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1888: c]
# ERROR	Selector: Unexpected CHAR. [12:1895: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1895: ;]
# ERROR	Selector: Unexpected IDENT. [12:1896: return]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1896: return]
# ERROR	Selector: Unexpected CHAR. [12:1904: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1904: }]
# ERROR	Selector: Single selector only. [12:1905: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1905: ,]
# ERROR	Selector: Unexpected IDENT. [12:1906: g]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1906: g]
# ERROR	Selector: Unexpected CHAR. [12:1907: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1907: =]
# ERROR	Unexpected token (FUNCTION, function(, 12, 1908)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, function(, 12, 1908)
# ERROR	Selector: Unexpected IDENT. [12:1917: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1917: a]
# ERROR	Selector: Unexpected CHAR. [12:1918: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1918: )]
# ERROR	Selector: Unexpected CHAR. [12:1919: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1919: {]
# ERROR	Selector: Unexpected IDENT. [12:1920: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1920: a]
# ERROR	Selector: Unexpected CHAR. [12:1921: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1921: =]
# ERROR	Selector: Unexpected STRING. [12:1923: "object"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1923: "object"]
# ERROR	Selector: Unexpected CHAR. [12:1931: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1931: =]
# ERROR	Selector: Unexpected CHAR. [12:1932: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1932: =]
# ERROR	Selector: Unexpected IDENT. [12:1940: globalThis]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1940: globalThis]
# ERROR	Selector: Unexpected CHAR. [12:1950: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1950: &]
# ERROR	Selector: Unexpected CHAR. [12:1951: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1951: &]
# ERROR	Selector: Unexpected IDENT. [12:1952: globalThis]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1952: globalThis]
# ERROR	Selector: Single selector only. [12:1962: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1962: ,]
# ERROR	Selector: Unexpected IDENT. [12:1963: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1963: a]
# ERROR	Selector: Single selector only. [12:1964: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1964: ,]
# ERROR	Selector: Unexpected STRING. [12:1965: "object"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1965: "object"]
# ERROR	Selector: Unexpected CHAR. [12:1974: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1974: =]
# ERROR	Selector: Unexpected IDENT. [12:1982: window]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1982: window]
# ERROR	Selector: Unexpected CHAR. [12:1988: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1988: &]
# ERROR	Selector: Unexpected CHAR. [12:1989: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:1989: &]
# ERROR	Selector: Unexpected IDENT. [12:1990: window]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:1990: window]
# ERROR	Selector: Single selector only. [12:1996: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:1996: ,]
# ERROR	Selector: Unexpected STRING. [12:1997: "object"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:1997: "object"]
# ERROR	Selector: Unexpected CHAR. [12:2005: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2005: =]
# ERROR	Selector: Unexpected CHAR. [12:2006: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2006: =]
# ERROR	Selector: Unexpected IDENT. [12:2007: typeof]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2007: typeof]
# ERROR	Selector: Unexpected IDENT. [12:2014: self]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2014: self]
# ERROR	Selector: Unexpected CHAR. [12:2018: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2018: &]
# ERROR	Selector: Unexpected CHAR. [12:2019: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2019: &]
# ERROR	Selector: Unexpected IDENT. [12:2020: self]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2020: self]
# ERROR	Selector: Single selector only. [12:2024: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [12:2024: ,]
# ERROR	Selector: Unexpected STRING. [12:2025: "object"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [12:2025: "object"]
# ERROR	Selector: Unexpected CHAR. [12:2033: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2033: =]
# ERROR	Selector: Unexpected CHAR. [12:2034: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2034: =]
# ERROR	Selector: Unexpected IDENT. [12:2035: typeof]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2035: typeof]
# ERROR	Selector: Unexpected IDENT. [12:2042: global]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2042: global]
# ERROR	Selector: Unexpected CHAR. [12:2048: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2048: &]
# ERROR	Selector: Unexpected CHAR. [12:2049: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2049: &]
# ERROR	Selector: Unexpected IDENT. [12:2050: global]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2050: global]
# ERROR	Selector: Unexpected CHAR. [12:2057: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2057: ;]
# ERROR	Unexpected token (FUNCTION, for(, 12, 2058)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, for(, 12, 2058)
# ERROR	Selector: Unexpected IDENT. [12:2062: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2062: var]
# ERROR	Selector: Unexpected CHAR. [12:2067: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2067: =]
# ERROR	Selector: Unexpected NUMBER. [12:2068: 0]
# ERROR:CSSUTILS:Selector: Unexpected NUMBER. [12:2068: 0]
# ERROR	Selector: Unexpected CHAR. [12:2069: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2069: ;]
# ERROR	Selector: Unexpected IDENT. [12:2070: b]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2070: b]
# ERROR	Selector: Unexpected CHAR. [12:2071: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2071: <]
# ERROR	Selector: Unexpected IDENT. [12:2072: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2072: a]
# ERROR	Selector: Unexpected CHAR. [12:2080: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2080: ;]
# ERROR	Selector: Unexpected CHAR. [12:2082: +]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2082: +]
# ERROR	Selector: Unexpected CHAR. [12:2084: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2084: )]
# ERROR	Selector: Unexpected CHAR. [12:2085: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2085: {]
# ERROR	Selector: Unexpected IDENT. [12:2086: var]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2086: var]
# ERROR	Selector: Unexpected CHAR. [12:2091: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2091: =]
# ERROR	Selector: Unexpected IDENT. [12:2092: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2092: a]
# ERROR	Selector: Unexpected CHAR. [12:2096: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2096: ;]
# ERROR	Unexpected token (FUNCTION, if(, 12, 2097)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, if(, 12, 2097)
# ERROR	Selector: Unexpected IDENT. [12:2100: c]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2100: c]
# ERROR	Selector: Unexpected CHAR. [12:2101: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2101: &]
# ERROR	Selector: Unexpected CHAR. [12:2102: &]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2102: &]
# ERROR	Selector: Unexpected IDENT. [12:2103: c]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [12:2103: c]
# ERROR	Selector: Unexpected CHAR. [12:2109: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2109: =]
# ERROR	Selector: Unexpected CHAR. [12:2110: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [12:2110: =]
# ...
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:178: google]
# ERROR	Selector: Unexpected CHAR. [19:184: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:184: .]
# ERROR	Unexpected token (FUNCTION, log(, 19, 185)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, log(, 19, 185)
# ERROR	Selector: Unexpected STRING. [19:189: "rcm"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:189: "rcm"]
# ERROR	Selector: Single selector only. [19:194: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [19:194: ,]
# ERROR	Selector: Unexpected STRING. [19:195: "&ei="]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:195: "&ei="]
# ERROR	Selector: Unexpected STRING. [19:204: "&tgtved="]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:204: "&tgtved="]
# ERROR	Selector: Unexpected CHAR. [19:214: +]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:214: +]
# ERROR	Selector: Unexpected STRING. [19:217: "&jsname="]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:217: "&jsname="]
# ERROR	Selector: Unexpected CHAR. [19:227: +]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:227: +]
# ERROR	Selector: Unexpected CHAR. [19:228: (]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:228: (]
# ERROR	Selector: Unexpected namespace prefix. [19:231: |]
# ERROR:CSSUTILS:Selector: Unexpected namespace prefix. [19:231: |]
# ERROR	Selector: Unexpected STRING. [19:232: ""]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:232: ""]
# ERROR	Selector: Unexpected CHAR. [19:234: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:234: )]
# ERROR	Selector: Unexpected CHAR. [19:235: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:235: )]
# ERROR	Selector: Unexpected CHAR. [19:236: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:236: }]
# ERROR	Selector: Unexpected CHAR. [19:237: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:237: }]
# ERROR	Prefix a not found.
# ERROR:CSSUTILS:Prefix a not found.
# ERROR	Selector: No namespaceURI found for prefix 'a' [19:238: else]
# ERROR:CSSUTILS:Selector: No namespaceURI found for prefix 'a' [19:238: else]
# ERROR	Selector: Unexpected CHAR. [19:244: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:244: =]
# ERROR	Selector: Unexpected IDENT. [19:245: a]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:245: a]
# ERROR	Selector: Single selector only. [19:246: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [19:246: ,]
# ERROR	Selector: Unexpected IDENT. [19:247: E]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:247: E]
# ERROR	Selector: Unexpected CHAR. [19:248: =]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:248: =]
# ERROR	Selector: Unexpected CHAR. [19:252: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:252: }]
# ERROR	Selector: Unexpected IDENT. [19:253: window]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:253: window]
# ERROR	Selector: Unexpected CHAR. [19:268: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:268: .]
# ERROR	Unexpected token (FUNCTION, addEventListener(, 19, 269)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, addEventListener(, 19, 269)
# ERROR	Selector: Unexpected STRING. [19:286: "DOMContentLoaded"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:286: "DOMContentLoaded"]
# ERROR	Selector: Single selector only. [19:304: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [19:304: ,]
# ERROR	Unexpected token (FUNCTION, function(, 19, 305)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, function(, 19, 305)
# ERROR	Selector: Unexpected CHAR. [19:314: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:314: )]
# ERROR	Selector: Unexpected CHAR. [19:315: {]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:315: {]
# ERROR	Selector: Unexpected IDENT. [19:316: document]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:316: document]
# ERROR	Selector: Unexpected CHAR. [19:329: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:329: .]
# ERROR	Unexpected token (FUNCTION, addEventListener(, 19, 330)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, addEventListener(, 19, 330)
# ERROR	Selector: Unexpected STRING. [19:347: "click"]
# ERROR:CSSUTILS:Selector: Unexpected STRING. [19:347: "click"]
# ERROR	Selector: Single selector only. [19:354: ,]
# ERROR:CSSUTILS:Selector: Single selector only. [19:354: ,]
# ERROR	Selector: Unexpected IDENT. [19:355: G]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:355: G]
# ERROR	Selector: Unexpected CHAR. [19:356: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:356: )]
# ERROR	Selector: Unexpected CHAR. [19:357: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:357: }]
# ERROR	Selector: Unexpected CHAR. [19:358: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:358: )]
# ERROR	Selector: Unexpected CHAR. [19:359: ;]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:359: ;]
# ERROR	Selector: Unexpected CHAR. [19:360: }]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:360: }]
# ERROR	Selector: Unexpected CHAR. [19:361: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:361: )]
# ERROR	Selector: Unexpected CHAR. [19:362: .]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:362: .]
# ERROR	Unexpected token (FUNCTION, call(, 19, 363)
# ERROR:CSSUTILS:Unexpected token (FUNCTION, call(, 19, 363)
# ERROR	Selector: Unexpected IDENT. [19:368: this]
# ERROR:CSSUTILS:Selector: Unexpected IDENT. [19:368: this]
# ERROR	Selector: Unexpected CHAR. [19:372: )]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:372: )]
# ERROR	SelectorList: Invalid Selector: (function(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,value:a[c++]}:{done:!0}}};
# var e=this||self;var g,h;a:{for(var k=["CLOSURE_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],l==null){h=null;break a}h=l}var p=h&&h[610401301];g=p!=null?p:!1;var q,r=e.navigator;q=r?r.userAgentData||null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.brand)&&c.indexOf(a)!=-1}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.userAgent)break a;c=""}return c.indexOf(a)!=-1};function v(){return g?!!q&&q.brands.length>0:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast"))||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/"))||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Android"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox")||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u("MSIE");y();x();w();var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if(A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;return a===void 0?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=performance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m=typeof Symbol!="undefined"&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if(typeof d.length=="number")d={next:b(d)};else throw Error("b`"+String(d));for(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a instanceof HTMLElement)if(a===F){if(c=E.length>=4)c=(E[E.length-1]-E[E.length-4])/1E3<5;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":"":f=(f=
# a.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute("jsname"))a=a.getAttribute("jsname");else{var C;a=(C=a.closest("[jsname]"))==null?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&tgtved="+f+"&jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMContentLoaded",function(){document.body.addEventListener("click",G)});}).call(this)
# ERROR:CSSUTILS:SelectorList: Invalid Selector: (function(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,value:a[c++]}:{done:!0}}};
# var e=this||self;var g,h;a:{for(var k=["CLOSURE_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],l==null){h=null;break a}h=l}var p=h&&h[610401301];g=p!=null?p:!1;var q,r=e.navigator;q=r?r.userAgentData||null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.brand)&&c.indexOf(a)!=-1}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.userAgent)break a;c=""}return c.indexOf(a)!=-1};function v(){return g?!!q&&q.brands.length>0:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast"))||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/"))||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Android"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox")||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u("MSIE");y();x();w();var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if(A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;return a===void 0?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=performance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m=typeof Symbol!="undefined"&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if(typeof d.length=="number")d={next:b(d)};else throw Error("b`"+String(d));for(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a instanceof HTMLElement)if(a===F){if(c=E.length>=4)c=(E[E.length-1]-E[E.length-4])/1E3<5;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":"":f=(f=
# a.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute("jsname"))a=a.getAttribute("jsname");else{var C;a=(C=a.closest("[jsname]"))==null?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&tgtved="+f+"&jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMContentLoaded",function(){document.body.addEventListener("click",G)});}).call(this)
# ERROR	CSSStyleRule: No style declaration or "}" found: '(function(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,value:a[c++]}:{done:!0}}};\nvar e=this||self;var g,h;a:{for(var k=["CLOSURE_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],l==null){h=null;break a}h=l}var p=h&&h[610401301];g=p!=null?p:!1;var q,r=e.navigator;q=r?r.userAgentData||null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.brand)&&c.indexOf(a)!=-1}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.userAgent)break a;c=""}return c.indexOf(a)!=-1};function v(){return g?!!q&&q.brands.length>0:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast"))||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/"))||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Android"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox")||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u("MSIE");y();x();w();var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if(A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;return a===void 0?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=performance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m=typeof Symbol!="undefined"&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if(typeof d.length=="number")d={next:b(d)};else throw Error("b`"+String(d));for(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a instanceof HTMLElement)if(a===F){if(c=E.length>=4)c=(E[E.length-1]-E[E.length-4])/1E3<5;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":"":f=(f=\na.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute("jsname"))a=a.getAttribute("jsname");else{var C;a=(C=a.closest("[jsname]"))==null?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&tgtved="+f+"&jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMContentLoaded",function(){document.body.addEventListener("click",G)});}).call(this);'
# ERROR:CSSUTILS:CSSStyleRule: No style declaration or "}" found: '(function(){var b=function(a){var c=0;return function(){return c<a.length?{done:!1,value:a[c++]}:{done:!0}}};\nvar e=this||self;var g,h;a:{for(var k=["CLOSURE_FLAGS"],l=e,n=0;n<k.length;n++)if(l=l[k[n]],l==null){h=null;break a}h=l}var p=h&&h[610401301];g=p!=null?p:!1;var q,r=e.navigator;q=r?r.userAgentData||null:null;function t(a){return g?q?q.brands.some(function(c){return(c=c.brand)&&c.indexOf(a)!=-1}):!1:!1}function u(a){var c;a:{if(c=e.navigator)if(c=c.userAgent)break a;c=""}return c.indexOf(a)!=-1};function v(){return g?!!q&&q.brands.length>0:!1}function w(){return u("Safari")&&!(x()||(v()?0:u("Coast"))||(v()?0:u("Opera"))||(v()?0:u("Edge"))||(v()?t("Microsoft Edge"):u("Edg/"))||(v()?t("Opera"):u("OPR"))||u("Firefox")||u("FxiOS")||u("Silk")||u("Android"))}function x(){return v()?t("Chromium"):(u("Chrome")||u("CriOS"))&&!(v()?0:u("Edge"))||u("Silk")}function y(){return u("Android")&&!(x()||u("Firefox")||u("FxiOS")||(v()?0:u("Opera"))||u("Silk"))};var z=v()?!1:u("Trident")||u("MSIE");y();x();w();var A=!z&&!w(),D=function(a){if(/-[a-z]/.test("ved"))return null;if(A&&a.dataset){if(y()&&!("ved"in a.dataset))return null;a=a.dataset.ved;return a===void 0?null:a}return a.getAttribute("data-"+"ved".replace(/([A-Z])/g,"-$1").toLowerCase())};var E=[],F=null;function G(a){a=a.target;var c=performance.now(),f=[],H=f.concat,d=E;if(!(d instanceof Array)){var m=typeof Symbol!="undefined"&&Symbol.iterator&&d[Symbol.iterator];if(m)d=m.call(d);else if(typeof d.length=="number")d={next:b(d)};else throw Error("b`"+String(d));for(var B=[];!(m=d.next()).done;)B.push(m.value);d=B}E=H.call(f,d,[c]);if(a&&a instanceof HTMLElement)if(a===F){if(c=E.length>=4)c=(E[E.length-1]-E[E.length-4])/1E3<5;if(c){c=google.getEI(a);a.hasAttribute("data-ved")?f=a?D(a)||"":"":f=(f=\na.closest("[data-ved]"))?D(f)||"":"";f=f||"";if(a.hasAttribute("jsname"))a=a.getAttribute("jsname");else{var C;a=(C=a.closest("[jsname]"))==null?void 0:C.getAttribute("jsname")}google.log("rcm","&ei="+c+"&tgtved="+f+"&jsname="+(a||""))}}else F=a,E=[c]}window.document.addEventListener("DOMContentLoaded",function(){document.body.addEventListener("click",G)});}).call(this);'
# ERROR	CSSStyleRule: No start { of style declaration found: '</script></body></html>' [19:397: ]
# ERROR:CSSUTILS:CSSStyleRule: No start { of style declaration found: '</script></body></html>' [19:397: ]
# ERROR	Selector: Unexpected CHAR. [19:374: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:374: <]
# ERROR	Selector: Unexpected CHAR. [19:375: /]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:375: /]
# ERROR	Selector: Unexpected CHAR. [19:383: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:383: <]
# ERROR	Selector: Unexpected CHAR. [19:384: /]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:384: /]
# ERROR	Selector: Unexpected CHAR. [19:390: <]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:390: <]
# ERROR	Selector: Unexpected CHAR. [19:391: /]
# ERROR:CSSUTILS:Selector: Unexpected CHAR. [19:391: /]
# ERROR	Selector: Cannot end with combinator: </script></body></html>
# ERROR:CSSUTILS:Selector: Cannot end with combinator: </script></body></html>
# ERROR	SelectorList: Invalid Selector: </script></body></html>
# ERROR:CSSUTILS:SelectorList: Invalid Selector: </script></body></html>
# ERROR	CSSStyleRule: No style declaration or "}" found: '</script></body></html>'
# ERROR:CSSUTILS:CSSStyleRule: No style declaration or "}" found: '</script></body></html>'
# HTML Colors:
# Tag: a, Styles: {}
# Tag: div, Styles: {}
# Tag: img, Styles: {}
# Tag: input, Styles: {'color': '#000'}
# Tag: br, Styles: {}
# Tag: p, Styles: {'color': '#70757a'}
#
# CSS Colors:
# Selector: a.gb1, a.gb4, Styles: {'color': '#00c'}
# Selector: .gbi .gb4, Styles: {'color': '#dd8e27'}
# Selector: .gbf .gb4, Styles: {'color': '#900'}
# Selector: .h, Styles: {'color': '#1967d2'}
# Selector: body, Styles: {'color': '#000'}
# Selector: a, Styles: {'color': '#681da8'}
# Selector: .fl a, Styles: {'color': '#1967d2'}
# Selector: a:visited, Styles: {'color': '#681da8'}
# Selector: .lsb, Styles: {'color': '#000'}
# body: {'text_color': '', 'background_color': ''}
# h1: {'text_color': ''}
# mark: {'highlight_color': '', 'highlight_bg': ''}
# a: {'link_color': '#681da8', 'hover_color': ''}
